# %% [markdown]
# 1. Webscraping (HTML in pre-Tag)
# 2. b-Tags (und andere Tags) löschen d.h. alles zwischen Spitzklammern <>
# 3. Aufsplitten des Texts in Textblöcke anhand von Leerzeilen (2x \n nacheinander), Textblöcke als Array speichern
# 4. Textblöcke kategorisieren, typische Merkmale identifizieren, Verarbeitungsanweisungen für die einzelnen Textblöcke definieren
# 5. in CSV umwandeln, dabei die Verarbeitungsanweisungen als if-Bedingungen umsetzen (jeden Textblocktyp einzeln verarbeiten)
# 6. weitere automatisierte Datenbereinigungsschritte: Fragezeichen ersetzen, bestimmte Textteile löschen z.B. (V.O.) etc.
# 7. händische Datenbereinigung (restliche Fragezeichen ersetzen, Regieanweisungen die direkt am Sprechertext kleben ausfindig machen und in eine eigene Regie-Zeile auslagern
# 8. Zusammenführen der 3 CSV-Dateien in eine (zusätzliche Spalte für Film-Nummer)

# %% [markdown]
# Beispiel für Textblöcke:

# %% [markdown]
# **1.) Textblock vom Typ "Sprechertext"**

# %% [markdown]
# >**GALADRIEL (V.O.) (CONT'D)**
#
#           But the power of the Ring could not be
#           undone.

# %% [markdown]
# typisches Merkmal: beginnt mittig (x Leerzeichen Abstand vom Rand, genaue Anzahl der Leerzeichen variiert je nach Filmskritpt!)

# %% [markdown]
# Verarbeitung: Text in erster Zeile (Name des Sprechers) wird in linke Spalte gepackt, Text ab zweiter Zeile wird in rechte Spalte gepackt

# %% [markdown]
# **2.) Textblock vom Typ "Regieanweisung"** (Skript 1 und 3)

# %% [markdown]
# >IMAGES: THE HUGE, DARK FIGURE OF SARURON, bearing the ONE
# RING on his finger, looms over the field of battle...

# %% [markdown]
# typisches Merkmal: beginnt linksbündig (! ausgenommen Textblöcke, in denen nur **CONTINUED:** steht)

# %% [markdown]
# Verarbeitung: in linke Spalte wird "Regie" geschrieben, Text kommt in rechte Spalte, (Wörter vorm Doppelpunkt werden später gelöscht)

# %% [markdown]
# **3.) Textblock vom Typ "Regieanweisung"** (Skript 2)

# %% [markdown]
# >[The hall is shown to be filled with
#                          light again, as everyone marvels at
#                          the rejuvenation of the king.]

# %% [markdown]
# typisches Merkmal: steht in []

# %% [markdown]
# Verarbeitung: wie 2. (linke Spalte: "Regie", rechte Spalte: Text ohne Klammern)

# %% [markdown]
# **Vorteil: alle Textteile, für die keine Verarbeitungsanweisung definiert wird, werden auch nicht mit ins CSV aufgenommen.** Man zieht sich nur die Teile raus, die man braucht. z.B. werden Seitenzahlen nicht berücksichtigt, weil sie rechtsbündig stehen

# %% [markdown]
# ## Ziel: CSV-Datei in folgendem Format

# %% [markdown]
# | Nr. | Regie/Sprecher | Text | Film-Nr. |
#
#
# | 1 | Gollum | My precious! | 1 |
#
# | 2 | Regie | Gollum looks at the ring. | 1 |

# %% [markdown]
# ## 1.) Regieanweisungen aus Skript 1 und 3

# %% [markdown]
# **Datenquelle:** Webscraping von imsdb.com

# %%
from bs4 import BeautifulSoup
import requests
import os
import re
import pandas as pd
import numpy as np
from textblob import TextBlob
import spacy
from spacytextblob.spacytextblob import SpacyTextBlob

# %%
lotr_1 = requests.get('https://imsdb.com/scripts/Lord-of-the-Rings-Fellowship-of-the-Ring,-The.html')
lotr_3 = requests.get('https://imsdb.com/scripts/Lord-of-the-Rings-Return-of-the-King.html')

# %%
# Liste mit Regieanweisungen, die im Sprechertext vorkommen
# ToDo: weitere ergänzen
regieInSpeakertext= ["Bilbo stands gazing out of the kitchen window."]

# %%
def get_regieanweisungen(script, filmNr):
            # webscrape text
            soup = BeautifulSoup(script.text, 'lxml')
            all_character_tags = soup.find('pre')

            # convert scraped bs4 element tags to string
            text = str(all_character_tags)

            # delete all tags
            text = re.sub(r'</?[a-zA-Z]+>', '', text)       

            # whitespace in names
            text = re.sub(r'A RW EN','ARWEN', text)
            text = re.sub(r'DEN ETH OR','DENETHOR', text)
            text = re.sub(r'SME AGO L', 'SMEAGOL', text)

            # split to text blocs (Trenner: Leerzeilen = 2x new line = \r\n\r\n)
            blocs = re.split(r'\r\n\r\n', text)

            # Dateiname festlegen
            filename = f'lotr_skript_{filmNr}_regie.csv'

            # Datei löschen, falls sie existiert:
            if os.path.exists(f'data/{filename}'):
                os.remove(f'data/{filename}')

            # TO CSV

            with open(f'data/{filename}', 'a') as f:
                # Spaltenüberschriften
                f.write(f'Nr.|Sprecher/Regie|Text|Filmnr.\n')
                print(f'Nr.|Sprecher/Regie|Text|Filmnr.\n')

                # Blöcke durchgehen
                for num, bloc in enumerate(blocs):
                    # Leerzeichen entfernen und Fragezeichen/Asterisk ersetzen (in Skript 1 und 3 können alle Fragezeichen durch Leerzeichen ersetzt werden)
                    bloc = bloc.replace("�", " ")
                    bloc = bloc.replace("*", " ")

                    # match Sprechertext (wenn mehr als ein Leerzeichen am Anfang des Blocks)
                    if(re.match(r'^\s+[A-Z]', bloc)):    
                        sprechertext = bloc
                        # remove whitespace
                        sprechertext = re.sub(r'\r\n', ' ', sprechertext) # Zeilenumbrüche innerhalb des Texts
                        sprechertext = re.sub(r'\s+', ' ', sprechertext) # mehrfache Leerzeichen werden zu einem

                        # wenn in einem Block ein Satz aus der Liste regieInSpeakertext vorkommt, dann wird der Satz ausgegeben (nur! der Satz)
                        for count, regietext in enumerate(regieInSpeakertext):
                            if (regietext in sprechertext):
                                print(f'{num}|Regie aus Sprechertext|{regietext}|Filmnr.\n')
                                #print(num, sprechertext)

                    # match Regieanweisungen (wenn kein Leerzeichen am Anfang des Blocks)
                    elif (not re.match(r'^\s+[A-Z]', bloc)):
                        # remove whitespace
                        regietext = bloc.strip()
                        regietext = re.sub(r'\r\n', ' ', regietext) # Zeilenumbrüche innerhalb des Texts
                        regietext = re.sub(r'\s+', ' ', regietext) # mehrfache Leerzeichen werden zu einem

                        # löschen bestimmter Blöcke (Blöcke mit CONTINUED, mit Ortsangaben Int. oder Ext.)
                        if ('CONTINUED' in regietext):
                            regietext = ''
                        elif('EXT.' in regietext):
                            regietext = ''
                        elif('EX.' in regietext):
                            regietext = ''
                        elif('INT.' in regietext):
                            regietext = ''
                        elif('CUT TO' in regietext):
                            regietext = ''


                        # löschen von Kameraanweisungen und Ähnlichem
                        regietext = re.sub(r'We SLOWLY FADE TO BLACK ...', '', regietext)
                        regietext = re.sub(r'FADE TO BLACK.?', '', regietext)
                        regietext = re.sub(r'FADE UP:', '', regietext)

                        regietext = re.sub(r'ANGLE ON::', '', regietext)
                        regietext = re.sub(r'ANGLES ON:', '', regietext)
                        regietext = re.sub(r'ANGLE ON:', '', regietext)

                        regietext = re.sub(r'IMAGES:', '', regietext)
                        regietext = re.sub(r'IMAGE:', '', regietext)

                        regietext = re.sub(r'CLOSE ON:', '', regietext)
                        regietext = re.sub(r'Close on:', '', regietext)

                        regietext = re.sub(r'\sSUPER:\s.+TRACKS\sTO:', '', regietext)

                        regietext = re.sub(r'TEASING SHOTS:', '', regietext)

                        regietext = re.sub(r'WIDE ON:', '', regietext)
                        regietext = re.sub(r'Wide on:', '', regietext)

                        regietext = re.sub(r'MONTAGE:', '', regietext)

                        regietext = re.sub(r'SLOW MOTION:?', '', regietext)
                        regietext = re.sub(r'NORMAL SPEED', '', regietext)

                        regietext = re.sub(r'ON THE SOUNDTRACK:', '', regietext)
                        regietext = re.sub(r'ON SOUNDTRACK:', '', regietext)
                        regietext = re.sub(r'SOUNDTRACK:', '', regietext)           

                        regietext = re.sub(r'TILT DOWN:', '', regietext)

                        regietext = re.sub(r'Low angle:', '', regietext)
                        regietext = re.sub(r'QUICK ANGLES:', '', regietext)
                        regietext = re.sub(r'LOW ANGLE:', '', regietext)
                        regietext = re.sub(r'HIGH WIDE ANGLE:', '', regietext)
                        regietext = re.sub(r'HIGH ANGLE:', '', regietext)


                        regietext = re.sub(r'HIGH WIDE:', '', regietext)
                        regietext = re.sub(r'WIDER:', '', regietext)
                        regietext = re.sub(r'Wider:', '', regietext)
                        regietext = re.sub(r'WIDE SHOT:', '', regietext)
                        regietext = re.sub(r'WIDE PROFILE:?', '', regietext)
                        regietext = re.sub(r'WIDE:', '', regietext) 

                        regietext = re.sub(r'QUICK INSERT:', '', regietext)
                        regietext = re.sub(r'FLASH INSERT:', '', regietext)
                        regietext = re.sub(r'INSERTS:', '', regietext)
                        regietext = re.sub(r'INSERT:', '', regietext)

                        regietext = re.sub(r'Aerial on:', '', regietext)
                        regietext = re.sub(r'AERIAL SHOT:', '', regietext)
                        regietext = re.sub(r'AERIAL:', '', regietext)

                        regietext = re.sub(r'SAM POV:', '', regietext)
                        regietext = re.sub(r'LOW ANGLE POV:', '', regietext)
                        regietext = re.sub(r'ARAGORN POV', '', regietext)
                        regietext = re.sub(r'ARWEN\'S POV:', '', regietext)
                        regietext = re.sub(r'Frodo\'s half- conscious POV:', '', regietext)
                        regietext = re.sub(r'Frodo\'s POV:', '', regietext)
                        regietext = re.sub(r'SURREAL SLOW MOTION POV:', '', regietext)
                        regietext = re.sub(r'SPEEDING POV:', '', regietext)
                        regietext = re.sub(r'Rushing POV:', '', regietext)
                        regietext = re.sub(r'LOW ANGLE POV:', '', regietext)
                        regietext = re.sub(r'POV:', '', regietext)

                        regietext = re.sub(r'CAMERA CIRCLES SUMMIT:', '', regietext)
                        regietext = re.sub(r'CAMERA CRANES to REVEAL:', '', regietext)

                        regietext = re.sub(r'PAN ONTO:', '', regietext)
                        regietext = re.sub(r'PAN OFF:', '', regietext)

                        regietext = re.sub(r'CRANE DOWN:', '', regietext)

                        regietext = re.sub(r'Slow motion:', '', regietext)

                        regietext = re.sub(r'QUICK CUTS:', '', regietext)

                        regietext = re.sub(r'BLACK SCREEN:', '', regietext)
                        regietext = re.sub(r'BLACK SCREEN . . .', '', regietext)
                        regietext = re.sub(r'BLACK SCREEN', '', regietext)

                        regietext = re.sub(r'SETTLE ON:', '', regietext)
                        regietext = re.sub(r'PUSH IN:', '', regietext)
                        regietext = re.sub(r'PULL BACK:', '', regietext)
                        regietext = re.sub(r'QUICK BEAT:', '', regietext)
                        regietext = re.sub(r'TRACKING BACK:', '', regietext)
                        regietext = re.sub(r'TRACKING:', '', regietext)
                        regietext = re.sub(r'REVEAL ON:', '', regietext)
                        regietext = re.sub(r'SOARING UP:', '', regietext)
                        regietext = re.sub(r'MATCHING MOVE:', '', regietext)
                        regietext = re.sub(r'Screenplay by: Fran Walsh, Philippa Boyens, Peter Jackson', '', regietext)

                        regietext = re.sub(r'\(CON TINUED \)', '', regietext)
                        regietext = re.sub(r'\(C ON T IN U ED \)', '', regietext)
                        regietext = re.sub(r'\(C O N TI N U ED \)', '', regietext)


                        # Seitenzahlen löschen
                        regietext = re.sub(r'\d+\.', '', regietext)
                        
                        # auf dem Bildschirm eingeblendeten Text löschen
                        if ('SUPER:' in regietext):
                            regietext = ''

                        # Sonstige Texte löschen, die keine Regieanweisungen sind
                        regietext = re.sub(r'MRS. SACKVILLE BAGGINS \(O.S.\)', '', regietext)
                        regietext = re.sub(r'SAURON \(V.O.\)', '', regietext)
                        regietext = re.sub(r'\(IN BLACK SPEECH\)', '', regietext)

                        # Sätze mit zu viel Whitespace
                        regietext = re.sub(r'A s t h e G R E A T B O U LD E R S l a n d a m o ng t h em \^ t he O R C s t a rt t o P A N IC ', 'As the great bloulders land among them the Orc start to panic', regietext)

                        # komische Zeichenfolgen löschen
                        regietext = re.sub(r'::\.\. \. \. \.', '.', regietext) # GOLLUM quickly turns and BOLTS::.. . . .
                        regietext = re.sub(r';?:?', '', regietext)               # H e looks up as GOLLUM lunges at him. ;:
                        regietext = re.sub(r'\/', '', regietext)
                        regietext = re.sub(r"\. \. ' '", '', regietext)

                        # Zeichen ersetzen
                        # &amp durch and
                        regietext = re.sub(r'&amp', 'and', regietext)
                        # ! durch .
                        regietext = re.sub(r'!', '.', regietext)

                        # remove whitespace
                        regietext = regietext.strip()
                        regietext = re.sub(r'\s+', ' ', regietext) # mehrfache Leerzeichen werden zu einem

                        # Auslassungspunkte
                        # am Anfang: löschen 
                        # am Ende: durch einfachen Punkt ersetzen
                        # in der Mitte: durch Leerzeichen ersetzen (passt leider nicht immer, aber keine bessere Möglichkeit)
                        # Anfang
                        regietext = re.sub(r'^\s?\.\.\.*\s', '', regietext) # ohne Leerzeichen zwischen Punkten
                        regietext = re.sub(r'^\s?\. \.( \.)*\s?', '', regietext) # mit Leerzeichen zwischen Punkten
                        # Ende
                        regietext = re.sub(r'\s?\.\.(\.)*$', '.', regietext)
                        regietext = re.sub(r'\s?\. \.( \.)*$', '.', regietext)
                        # Mitte (alle, die jetzt noch übrig sind, müssen in der Mitte stehen)
                        regietext = re.sub(r'\s?\. \.( \.)*\s?', ' ', regietext)
                        regietext = re.sub(r'\s?\.\.(\.)*\s?', ' ', regietext)

                        # write to csv (only if text column not empty)
                        if(regietext != ""):
                            f.write(f'{num}|Regie|{regietext}|{filmNr}\n')
                        # print
                        if(regietext != ""):
                            print(f'{num}|Regie|{regietext}|{filmNr}\n')

get_regieanweisungen(lotr_1, 1)
get_regieanweisungen(lotr_3, 3)
# Out:
# Nr.|Sprecher/Regie|Text|Filmnr.
#
# 3|Regie|BLACK CONTINUES ELVISH SINGING A WOMAN'S VOICE IS whispering, tinged with SADNESS and REGRET|1
#
# 7|Regie|FLICKERING FIRELIGHT. The NOLDORIN FORGE in EREGION. MOLTEN GOLD POURS from the lip of an IRON LADLE.|1
#
# 9|Regie|THREE RINGS, each set with a single GEM, are received by the HIGH ELVES-GALADRIEL, GIL-GALAD and CIRDAN.|1
#
# 11|Regie|SEVEN RINGS held aloft in triumph by the DWARF LORDS.|1
#
# 13|Regie|NINE RINGS clutched tightly by the KINGS OF MEN as if holding-close a precious secret.|1
#
# 20|Regie|An ancient PARCHMENT MAP of MIDDLE EARTH moving slowly across the MAP as if drawn by an unseen force the CAMERA closes in on a PLACE NAME MORDOR.|1
#
# 22|Regie|SAURON forging the ONE RING in the CHAMBERS of SAMMATH NAUR.|1
#
# 26|Regie|THE ONE RING falls through SPACE and into flames.|1
#
# 28|Regie|A GREAT SHADOW falls across the MAP closing in around the realm of GONDOR.|1
#
# 29|Regie|SCREAMING VILLAGERS, MEN, WOMEN, AND CHILDREN, RUN|1
#
# 30|Regie|from their homes, pursued by ARMIES OF HIDEOUS ORCS.|1
#
# 39|Regie|THE BATTLE OF DAGORLAD THE ELF LORD, ELROND,|1
#
# 40|Regie|commands rank after rank of ELVEN ARCHERS ORCS RETREATING before the ARMY of the LAST ALLIANCE ELENDIL holds aloft the great sword NARSIL.|1
#
# 42|Regie|THE HUGE, DARK FIGURE OF SARURON, bearing the ONE RING on his finger, looms over the field of battle.|1
#
# 44|Regie|SAURON lays waste to the armies of the LAST ALLIANCE. With desperate courage, ELENDIL leads a charge THE BLACK MACE OF SAURON LASHES OUT ELENDIL'S body falls like a crumpled rag doll ISILDUR cradles the body of his father in his arms. The SHADOW OF SAURON falls over him.|1
#
# 46|Regie|ISILDUR snatches up the BROKEN BLADE OF NARSIL The BLADE severs SAURON'S FINGERS AND THE ONE RING FLIES from his body.|1
#
# 48|Regie|GONE VAPORIZED. ISILDUR picks up the SEVERED FINGER and removes the ONE RING transfixed.|1
#
# 54|Regie|SUDDENLY. ARROWS FLY. They are ambushed by ORCS ISILDUR SCREAMS.|1
#
# 56|Regie|ISILDUR MATERIALIZES UNDER WATER as THE RING slips slowly from his finger. Ripples of LIGHT play across ISILDUR'S PALE FACE he is DEAD.|1
#
# 58|Regie|THE RING falls through the MURKY WATERS of the RIVER ANDUIN.|1
#
# 62|Regie|The waters of the ANDUIN RIVER lie dark and undisturbed.|1
#
# 64|Regie|SILT SWIRLS A THIN WHITE HAND reaches down grasping the RING.|1
#
# 66|Regie|THE THIN WHITE HAND opens to reveal one ring.|1
#
# 70|Regie|MIST SHROUDED MOUNTAINS.|1
#
# 72|Regie|THE GLOOM of a MOUNTAIN CAVERN a MURKY POOL of WATER in the DARKNESS the SHADOWY OUTLINE of an EMACIATED FIGURE.|1
#
# 78|Regie|Bathed in COLD MOONLIGHT, the WORLD lies DARK and STILL the unsettled quiet before the storm.|1
#
# 80|Regie|unseen by its KEEPER THE RING falls to the MUDDY FLOOR of a MOUNTAIN TUNNEL.|1
#
# 83|Regie|FUMBLING in the dark, a SMALL HAND closes over the|1
#
# 86|Regie|RING.|1
#
# 89|Regie|A YOUNGISH LOOKING BILBO BAGGINS peers down at what lies in his hand PERPLEXED by what he has found.|1
#
# 92|Regie|SUDDENLY. A VOICE SCREAMS ITS ANGUISH RINGING through the|1
#
# 93|Regie|COLD, DANK TUNNELS.|1
#
# 95|Regie|Frightened Bilbo quickly POCKETS the ONE RING and hurries on.|1
#
# 97|Regie|THE CAMERA SOARS AWAY FROM THE MOUNTAINS. MOVING|1
#
# 98|Regie|FASTER AND FASTER THEIR DARK GREEN FORESTS AND JAGGED|1
#
# 99|Regie|WHITE PEAKS RECEDING INTO THE SHROUD OF MIST|1
#
# 104|Regie|TWO HOBBIT FEET|1
#
# 105|Regie|resting on a small rock rising out of the LONG, OVERGROWN GRASSES a Figure lies beneath the dappled sunlight of an old tree.|1
#
# 108|Regie|White flowers are scattered among the Well seeded grasses. An idyllic setting at the end of a long hot summer the figure is reading a book. In the distance, growing louder over the Gentle clip clop of an approaching cart and horse can be heard the HUMMING OF A DEEP VOICE to the tune of "The Road Goes Ever On and On "|1
#
# 109|Regie|SUDDENLY. The figure in the grass sits up looking straight at camera is a handsome young HOBBIT, with dark curly hair and deep blue eyes. This is FRODO BAGGINS his EYES alight with EXCITEMENT. Tossing away the long stem of grass in his mouth, Frodo runs off.|1
#
# 112|Regie|The cart rattles along a leafy lane, driven by a stooped figure in Grey.|1
#
# 113|Regie|INTERCUT WITH SHOTS OF FRODO RUNNING CAREERING DOWN A|1
#
# 114|Regie|HILL JUMPING OVER LOGS DODGING TREE BRANCHES.|1
#
# 116|Regie|The shambling OLD PONY snorts and rears as SUDDENLY FRODO appears on a bank above the cart.|1
#
# 118|Regie|GANDALF glowers at the young Hobbit.|1
#
# 120|Regie|They look at each other a moment then both start laughing as FRODO'S face breaks into a smile and he leaps on to the front seat of the cart.|1
#
# 122|Regie|Next to Gandalf, we see how small Hobbits are Frodo is 3 foot 6 inches tall.|1
#
# 128|Regie|The cart rattles past a FIELD LUPIN being tended by|1
#
# 129|Regie|HOBBITS.|1
#
# 132|Regie|Gandalf looks down at Frodo, a twinkle in his eye.|1
#
# 134|Regie|The cart rattles over a Stone bridge towards a Busy Hobbit Marketplace.|1
#
# 136|Regie|Gandalf as he surveys the peaceful scene before him.|1
#
# 139|Regie|Hobbits look up exclaiming in wonder and excitement as the cart bearing Gandalf and Frodo rolls past the Green Dragon Inn towards The party field. Where scOrcs of Hobbits are busy preparing for the big night.|1
#
# 149|Regie|Frodo shoots a knowing look, as Gandalf averts his eyes.|1
#
# 157|Regie|ODO PROUDFOOT looks up as the Cart passes by, deeply suspicious.|1
#
# 161|Regie|As the cart rattles into the small village of Hobbiton a quaint rustic settlement, nestled amongst rolling green hills and large trees.|1
#
# 164|Regie|The Hobbits live in Hobbit Holes neat burrows dug into the grassy hillside, with round doors and cute front gardens.|1
#
# 166|Regie|Excited children, chasing after the cart.|1
#
# 168|Regie|Gandalf ignOrcs the children's cries. The children stand deflated, watching Gandalf disappear up the lane. At that moment spinning balls of bright color suddenly leap out of the cart, fizzing over the heads of the delighted children.|1
#
# 170|Regie|Gandalf smiling to himself, well pleased with his joke. ODO PROUDFOOT is unable to suppress a chuckle. Frodo stands up in the cart as Gandalf reigns in the horse.|1
#
# 175|Regie|GANDALF'S CART pulls up outside the gate to BAG END a particularly fine example of a Hobbit hole, with a large round front door set into a grassy hillside. There is a sign on the gate which reads "NO ADMITTANCE EXCEPT ON PARTY BUSINESS." Gandalf strides up to the garden path of Bag End. He raises his staff and raps on the front door a voice calls out|1
#
# 178|Regie|Suddenly the door opens and BILBO BAGGINS stands before him. He is a HOBBIT OF INDERTIMINATE AGE, with a mischievous Twinkle in his eye. Wearing a dashing brocade waist coat, he looks every inch the eccentric gentleman.|1
#
# 185|Regie|Gandalf drops to his knee to embrace his old friend.|1
#
# 187|Regie|Gandalf looks at him more keenly.|1
#
# 192|Regie|Bilbo leads Gandalf into Bag End cozy and cluttered with souvenirs of Bilbo's travels. Gandalf has to stoop to avoid hitting his head on the low ceiling. Bilbo hangs up Gandalf's hat on a peg and trots off down the hall.|1
#
# 194|Regie|Bilbo disappears into the kitchen as Gandalf looks around enjoying the familiarity of Bag End he turns, knocking his head on the light and then walking into the wooden beam. He groans.|1
#
# 198|Regie|Gandalf stops in front of a framed map, charred in one corner it is Thorin's map of the Lonely Mountain, Gandalf smiles to himself.|1
#
# 200|Regie|Bilbo jumps, a half eaten pork pie in his hand, as Gandalf mysteriously appears behind him.|1
#
# 205|Regie|Bilbo Baggins, you open this door I know you're in there.|1
#
# 207|Regie|Gandalf watches, amused as Bilbo tries to hide.|1
#
# 218|Regie aus Sprechertext|Bilbo stands gazing out of the kitchen window.|Filmnr.
#
# 222|Regie|Bilbo's fingers close around his waistcoat pocket gripping a small, unseen object.|1
#
# 228|Regie|Gandalf and Bilbo are sitting on the Bag End porch. Below them, final preparations are being made on the Party field. Bilbo strikes a match and lights his pipe.|1
#
# 230|Regie|Bilbo blows a perfect smoke ring and watches it rise into the air. A tiny sailing ship with masts and sails glides through the Center of Bilbo's smoke ring.|1
#
# 234|Regie|BOOM. A FIREWORK explodes into the night sky high above Hobbiton in the shape of a great green tree with unfolding branches. with glowing flowers as they rain down from the branches evaporating just above the up turned faces of the delighted party-goers 144 Hobbits, feasting and drinking Carts of beer and wine are scattered about, and the tables are piled high with steaming scones and savories. Gandalf hurries about, lighting fireworks with a blue spark that dances magically from his staff Bilbo is greeting visitors. Frodo and SAM sit at a table drinking ale Frodo notices Sam's eyes keep flicking to another pretty Hobbit, Rosie Cotton, sitting some distance away.|1
#
# 238|Regie|Sam goes to drain his glass suddenly it is snatched out of his hands as Frodo thrusts him into the middle of a passing throng of dancers.|1
#
# 241|Regie|SAM'S HORRIFIED FACE|1
#
# 242|Regie|as he is Swept away. Frodo laughs and finishes Sam's beer.|1
#
# 244|Regie|Gandalf as he sets alight a particularly spectacular firework that draws gasps of admiration from the party guests.|1
#
# 245|Regie|Bilbo is relating stories of his adventure to a group of young hobbit children.|1
#
# 247|Regie|A LITTLE HOBBIT GIRL'S|1
#
# 248|Regie|upturned face her eyes growing larger and larger.|1
#
# 250|Regie|STUNNED GASPS from his young Audience greet his astonishing feat. MERRY AND PIPPIN, two mischievous Young Hobbits in their late teens. Pippin scrambles on to the back of Gandalf's wagon, snatching up a small firework|1
#
# 252|Regie|Merry is holding out the big rocket he looks aghast at the fizzing fuse that Pippin has just lit.|1
#
# 257|Regie|Merry fearfully tosses the Rocket to Pippin. The fuse sizzles angrily.|1
#
# 260|Regie|Pippin attempts to throw the fizzing rocket back to Merry. WHOOSH. The two hobbits are suddenly blown off their feet in a shower of sparks as the rocket blasts off with frightening power. The ROCKET ZOOMS over the Party It suddenly bursts apart, forming the shape of a great red golden Dragon. Fire gushes from its nostrils as it turns back and Flies low towards the startled crowd. Frodo watches the Fireworks Dragon with alarm but Bilbo is oblivious to the Panicking crowd and impending danger.|1
#
# 263|Regie|FRODO|1
#
# 264|Regie|As he hurriedly pulls Bilbo to the ground, just as the dragon roars a few feet above their heads like a flaming express train. Hobbits dive to the ground, tables overturn, tents collapse, food flies everywhere. The fireworks dragon turns a somersault and explodes over the hills with a deafening bang. This gets the biggest Cheer of the night.|1
#
# 265|Regie|MERRY AND PIPPIN,|1
#
# 266|Regie|clothes and hair smoking.|1
#
# 269|Regie|LARGE HANDS suddenly clamp down on Merry and Pippin's ears. Gandalf looking DOWN STERNLY.|1
#
# 275|Regie|MERRY AND PIPPIN|1
#
# 276|Regie|Are leaning over a barrel, washing dishes in soapy water with Gandalf sitting nearby, smoking his pipe and sipping an ale. Cries of "SPEECH. SPEECH" erupt from the party.|1
#
# 278|Regie|Bilbo stepping on a stool he bows in gratitude at the applause.|1
#
# 281|Regie|A HOBBIT WITH PARTICULARLY BIG FEET|1
#
# 285|Regie|SCATTERED CLAPPING as the guests try to work out if that was a compliment or not. FRODO AND GANDALF smiling to themselves. Bilbo a strange hum seems to fill his head. A bead of sweat rolls down his brow.|1
#
# 286|Regie|Bilbo's hand pulls something out of his waistcoat pocket and holds it behind his back.|1
#
# 292|Regie|Bilbo instantly vanishes. The party explodes into an uproar the crowd leaps to its feet.|1
#
# 293|Regie|FRODO|1
#
# 294|Regie|staring at the empty stool in disbelief.|1
#
# 297|Regie|The party is still in an excited uproar some 50 yards away as we pan across a moonlit lane to the front door of Bag End. Door opens, pulled by an invisible hand.|1
#
# 299|Regie|The door quietly closes Bilbo materializes as he pulls a plain gold ring off his finger. Bilbo laughs as he tosses the ring in the air, then places it in his pocket.|1
#
# 301|Regie|Bilbo emerges from the passage, carrying a walking stick. He finds Gandalf looming over him.|1
#
# 312|Regie|Bilbo he gives Gandalf a look and nods toward the mantelpiece.|1
#
# 317|Regie|GANDALF LOOKS DOWN AT BILBO WITH RISING CONCERN.|1
#
# 327|Regie|Gandalf rises to his full height, his eyes flash, his shadow suddenly seems to fill the room|1
#
# 332|Regie|Bilbo lifts his knapsack and heads for the front door.|1
#
# 340|Regie|Bilbo hesitates reaches into his pocket.|1
#
# 342|Regie|Bilbo pulls out the ring he stares at it in his palm. With all his will power, Bilbo allows the ring to slowly slide off his palm and drop to the floor. The tiny ring lands with a heavy thud on the wooden floor.|1
#
# 345|Regie|Bilbo staggering out of Bag end he braces himself in the night air, Pale and Trembling, as if his loss of the ring has weakened him. Gandalf steps up behind.|1
#
# 350|Regie|Bilbo walks away from Bag End, disappearing into the night, softly singing "The Road goes on and on."|1
#
# 354|Regie|THE RING Glinting on the floor Gandalf circles around it, a Puzzled look on his face. Gandalf slowly reaches for the ring. His fingers barely touch the ring the creepy Hum rises on the soundtrack. Gandalf is sitting in front of the fire, with his pipe staring into the flickering flames.|1
#
# 361|Regie|Frodo rushes into Bag End he stops and picks up the ring at his feet. Gandalf continues staring into the fire, as if locked in thought.|1
#
# 367|Regie|Gandalf turns his eyes locking onto the ring in Frodo's fingers.|1
#
# 369|Regie|Gandalf sorts hurriedly through Bilbo's papers.|1
#
# 371|Regie|Gandalf holds out the envelope Frodo drops the ring into it.|1
#
# 373|Regie|Gandolf seals the envelope with wax. He hands it to Frodo.|1
#
# 382|Regie|Gandalf is already at the door, he turns to Frodo.|1
#
# 384|Regie|Gandalf hurries out the door leaving FRODO standing alone in the Bag End.|1
#
# 385|Regie|THE ENVELOPE|1
#
# 386|Regie|The camera pushes in the hum of the ring comes up on the soundtrack. The camera pushes through the white paper to the ring beneath the hum the whispered murmur of BLACK SPEECH can be heard.|1
#
# 389|Regie|The jagged ruins of" BARAD-DUR. THE DARK TOWER. TEASING THE HUGE DARK TOWER OF BARAD-DUR is being rebuilt. Thousands of ORCS crawl over the surface, hauling stone and iron up the towering heights.|1
#
# 390|Regie|MOUNT DOOM A HUGE, BILLOWING CLOUD OF BLACK FILTH|1
#
# 391|Regie|grows and spreads across the red streaked sky casting a shadowy pall over the nightmarish landscape.|1
#
# 398|Regie|NINE BLACK RIDERS burst out of Minas Morgul and charge toward Camera.|1
#
# 400|Regie|A LONE HORSEMAN gallops to the crest of a hill on the west road. The main highway south to Minas Tirith he looks toward the saw toothed mountains of Mordor  seeping out across the blood red sky, his face grave. He spurs his horse on.|1
#
# 403|Regie|GANDALF|1
#
# 404|Regie|making is way down into the lower depths of the Citidel.|1
#
# 407|Regie|Pages flipping as Gandalf searches ancient scrolls and books placed high on a wooden table. His eyes settle on one old parchment. He murmurs hurriedly to himself, reading.|1
#
# 410|Regie|ISILDUR, TRIUMPHANT, REACHES FOR THE ONE RING, HIS|1
#
# 411|Regie|EYES FIXATED ON IT.|1
#
# 417|Regie|ELVISH LETTERING MARKS ON THE FADED OLD DOCUMENT|1
#
# 418|Regie|IN GANDALF'S HAND.|1
#
# 422|Regie|FARMER MAGGOT is chopping wood in his garden SNORTING HORSE NOSTRILS as the shadow of a black rider looms over a Hobbit House. Terrified, FARMER MAGGOT cowers in his doorway FANG, his dog, Whimpers and backs away.|1
#
# 425|Regie|The BLACK RIDER GALLOPS AWAY AT SPEED|1
#
# 428|Regie|ROSIE COTTON|1
#
# 429|Regie|bids the last of the Patron's "Goodnight" Sam meets her eyes for a moment as he and Frodo leave the inn.|1
#
# 433|Regie|FRODO FAREWELLS SAM outside Bag End, and heads towards the front door. Creepy POV from inside Bag end Frodo coming up the path.|1
#
# 437|Regie|FRODO enters Bag End he immediately Pauses, sensing that something is amiss. All is quiet Frodo peers uneasily into the darkened living room. SUDDENLY. A large figure looms out of the shadows, reaching for Frodo. Frodo lets out a startled cry, pulls himself free and spins around to face his Assailant. Gandalf steps into a shaft of moonlight. Paranoia blazes in his eyes. His clothes are dirty and ragged from much traveling. Hair and beard much longer an unkempt.|1
#
# 441|Regie|Frodo pulls the envelope out of an old chest. Gandalf, suspicious, Alert. Without a word, Gandalf takes the envelope and tosses it into the fireplace.|1
#
# 443|Regie|Flames instantly consume the envelope revealing the ring, as it sinks into the red hot embers. Gandalf reaches into the fire with a pair of tongs he lifts the ring out.|1
#
# 445|Regie|Gandalf drops the ring into Frodo's hand he reacts to its weight.|1
#
# 452|Regie|GANDALF STILL TENSE|1
#
# 455|Regie|Mordor?|1
#
# 457|Regie|In the common tongue it says, "One ring to rule them all, One ring to find them, One ring to bring them all, and in the darkness bind them."|1
#
# 460|Regie|The ring lies on Frodo's simple kitchen table.|1
#
# 462|Regie|FRODO STUNNED|1
#
# 467|Regie|emanates from the Ring. Frodo looks at Gandalf, each knowing the other has heard it.|1
#
# 469|Regie|THE RING|1
#
# 470|Regie|lies between them on the table.|1
#
# 475|Regie|FRODO|1
#
# 476|Regie|hurriedly entering the living room.|1
#
# 479|Regie|Gandalf looks at Frodo, sadly.|1
#
# 486|Regie|A teasing Glimpse of Gollum being tortured by the Orcs. The wretched creature screams in pain.|1
#
# 491|Regie|FRODO'S HORRIFIED FACE.|1
#
# 495|Regie|On a dark country lane, a Hobbit bounder lifts his watch lantern in alarm.|1
#
# 497|Regie|Out of the darkness thunder two BLACK RIDERS A LETHAL SWORD swings down at the small Hobbit bounder.|1
#
# 500|Regie|FRODO thrusts the ring at Gandalf.|1
#
# 509|Regie|THE RING IN FRODO'S HAND.|1
#
# 513|Regie|THE RING IN FRODO'S CLENCHED HAND.|1
#
# 517|Regie|FRODO|1
#
# 518|Regie|throwing clothes into a knapsack Gandalf watches him, making plans.|1
#
# 530|Regie|Frodo is preparing to leave.|1
#
# 534|Regie|Gandalf looks at the young Hobbit, moved by his courage.|1
#
# 536|Regie|SUDDENLY. A SOUND from outside.|1
#
# 538|Regie|GANDALF FREEZES he moves quietly towards the window, eyes wide with tension. He raises his staff above the window, and slams it down on the intruder. THERE IS A YELP OF PAIN.|1
#
# 541|Regie|Gandalf hauls a small figure into the room SAM GAMGEE sprawls across the floor. He looks up in terror as Gandalf looms over him.|1
#
# 549|Regie|FRODO SMILES|1
#
# 553|Regie|HOBBITON shrouded in a white veil of MIST. To reveal Gandalf, Frodo and Sam hurrying across a ploughed field, away from Hobbiton. Gandalf leads his Horse Frodo and Sam are carrying knapsacks.|1
#
# 560|Regie|Gandalf leads Frodo and Sam under the cover of Woods.|1
#
# 562|Regie|Gandalf takes Frodo to one side.|1
#
# 564|Regie|FRODO NODS he pats his pocket.|1
#
# 568|Regie|FRODO AND SAM hiking over the gentle Shire Countryside wading through a shallow stream heating a kettle over a small fire clambering over stone walls.|1
#
# 571|Regie|Sam stops short taking stock of his surroundings. Sam looks back from where they came.|1
#
# 578|Regie|FRODO gives Sam a pat on the shoulder.|1
#
# 580|Regie|Sam takes a deep breath and steps forward. SAM'S brown, furry foot hits the ground.|1
#
# 581|Regie|FRODO IS SMILING.|1
#
# 583|Regie|Frodo and Sam continue their journey.|1
#
# 587|Regie|Gandalf is galloping along the outskirts of the ancient forest of Fangorn. Nestled in a basin at the foot of the distant Misty Mountains, the tall black tower of Orthanc is clearly visible|1
#
# 589|Regie|Gandalf gallops through the gate, into the fortress of ISENGARD a great ring-wall of stone, a mile from rim to rim, encloses beautiful trees and gardens, watered by streams that flow down from the mountains.|1
#
# 591|Regie|The strange tower of Orthanc hewn from a solid pillar of black obsidian rises up in the center of the Isengard Circle. Gandalf arrives at the foot of the Orthanc Stairs.|1
#
# 594|Regie|SARUMAN, THE WHITE WIZARD|1
#
# 595|Regie|he sweeps down the Orthanc stairs.|1
#
# 597|Regie|Gandalf moves quickly towards him, grimy and weary from his long ride.|1
#
# 601|Regie|Gandalf and Saruman walk slowly between the beautiful trees of Isengard, Saruman's clean, white robe contrasts with Gandalf's dusty grey robes.|1
#
# 611|Regie|Saruman and Gandalf are seated in a small, cluttered room to the side of the cavernous central chamber.|1
#
# 620|Regie|Gandalf and Saruman stride through Orthanc toward a stone plinth on which a sphere like shape is draped with a cloth.|1
#
# 622|Regie|Saruman lifts the cloth to reveal the Palantir.|1
#
# 625|Regie|FLASH A FIERY EYE.|1
#
# 626|Regie|Saruman sits upon his throne.|1
#
# 635|Regie|Gandalf backs away and turns to run to the door horrified as the doors suddenly slam shut.|1
#
# 637|Regie|Gandalf slowly turns to Saruman a look of dawning horror.|1
#
# 640|Regie|At that moment Gandalf is suddenly blasted across the room. He slams against the wall pinned there by some unseen force. With sudden effort, Gandalf wrenches himself off the wall and swings his staff on Saruman blasting him off his feet. Gandalf and Saruman battle, powerful blasts throwing them across the room. SARUMAN SCREAMS, EYES BLAZING. Gandalf's staff is suddenly wrenched from his grasp it flies across the chamber into Saruman's hand. Gandalf is flung to the floor.|1
#
# 644|Regie|Gandalf is breathing hard on the floor, his eyes look into the madness of Saruman Commanding two staffs, Saruman sends Gandalf into a sickening spin. Gandalf tumbles towards the top of the chamber as if falling in reverse. the roof of Orthanc rockets toward camera.|1
#
# 647|Regie|Frodo and Sam walking along a country lane which borders Farmer Maggot's Fields. Sam is looking up Frodo has disappeared around a corner in the lane.|1
#
# 660|Regie|Merry, Pippin, and Frodo picking themselves up a variety of vegetables have scattered everywhere.|1
#
# 663|Regie|Merry gives Sam a large cabbage.|1
#
# 665|Regie|A large pitchfork can be seen racing towards them along the Hedgerow angry shouts from Farmer Maggot.|1
#
# 667|Regie|Merry and Pippin hurriedly gather their booty and race away with Frodo and Sam on their heels.|1
#
# 671|Regie|The BAYING OF LARGE DOGS sounds.|1
#
# 678|Regie|Frodo, Sam, and Merry and Pippin tumble head over heels down a bank, onto a dark, wooded road. A winded Pippin, his face inches away from a large pile of Horse droppings.|1
#
# 680|Regie|Frodo picks himself up and looks around quickly.|1
#
# 682|Regie|Pulls a LARGE CARROT, almost broken through in the middle, out from his back pocket.|1
#
# 687|Regie|Pippin has spied something under the trees on the far side of the road.|1
#
# 689|Regie|SMALL, brown mushrooms growing amongst the Loamy undergrowth. Sam, Merry, and Pippin race toward the mushrooms. Frodo is tense and watchful. He realizes they are on a wooded road. Scattered leaves rise into the air Whirling down the road as if blown by an invisible wind.|1
#
# 692|Regie|SUDDENLY THE SOUND OF HORSES HOOVES.|1
#
# 694|Regie|A long drawn WAIL comes down the wind, like the cry of some evil and lonely creature.|1
#
# 696|Regie|Sam grabs Merry and Pippin as the Hobbits quickly scramble down the bank, hiding under a mossy log. THE SOUND OF HOOVES is close A sinister MOUNTED RINGWRATH steps into view hooded and faceless, mounted on a huge snarling black horse with insane eyes . Frodo freezes in terror. The RINGWRAITH pauses right beside their hiding place he sits very still with his head bowed, listening. From inside the hood comes a sniffing noise as if he is trying to catch an elusive scent his head turning from side to side.|1
#
# 697|Regie|FRODO|1
#
# 698|Regie|Beads of sweat gather on his brow. The ringwraith suddenly slides off his horse, leaning over the mossy log, peering suspiciously into the woods.|1
#
# 699|Regie|FRODO|1
#
# 700|Regie|He is drawing the ring out of his pocket, with trembling hands his face fevered and sweating as if in the grip of some terrible INTERNAL STRUGGLE. The SOUND OF SNIFFING intensifies as the ringwraith darts his head from side to side like a bird of party.|1
#
# 701|Regie|FRODO SQUEEZING HIS EYES SHUT.|1
#
# 702|Regie|QUICK PSYCHIC BLASTS. AND EVIL DARK TOWER A GREAT EYE A|1
#
# 703|Regie|BURST OF FLAME.|1
#
# 704|Regie|SAM LOOKING AT FRODO WITH CONCERN|1
#
# 706|Regie|Merry desperately hurls the mushrooms across the road the ringwraith spins around at the sound, and darts to the far side of the road with frightening speed. Frodo instantly slumps as if a PSYCHIC LINK had been broken|1
#
# 711|Regie|Frodo is staring, a look of shock on his face at the ring lying in the palm of his hand.|1
#
# 713|Regie|Frodo, Sam, Merry, and Pippin hurry through the trees slipping and sliding on the muddy ground.|1
#
# 717|Regie|Merry moves past pippin, toward Frodo, watching intently Sam keeps looking around nervously.|1
#
# 720|Regie|The SILHOUETTE OF A BLACK RIDER looms against the skyline. The Four Hobbits sprawled on the ground, holding their breath. The BLACK RIDER turns and departs.|1
#
# 722|Regie|Merry looks at his friend realizing Frodo is in deep trouble.|1
#
# 724|Regie|The Hobbits break cover. SUDDENLY, A RINGWRAITH bursts out of the forest TOWARD THEM.|1
#
# 726|Regie|The Hobbits run THE RINGWRAITH SHRIEKS.|1
#
# 734|Regie|FRODO, SAM, MERRY AND PIPPIN, are running towards the wide, placid Brandywine river and the FERRY.|1
#
# 736|Regie|STOMPING HOOVES SNARLING HORSES.|1
#
# 737|Regie|Four RINGWRAITHS are speeding through the Fog converging on the FERRY CROSSING. The HOBBITS stampede across the Wharf and Tumble onto the Ferry.|1
#
# 739|Regie|Frodo races across the Wooden Wharf, followed by the ringwraiths. He leaps into the Ferry.|1
#
# 740|Regie|HOOVES THUNDER DOWN THE WOODEN WHARF.|1
#
# 741|Regie|Sam and Merry shove off with the poles the ferry slides out into the river, just as the ringwraiths arrive. They pull up on the end of the wharf shrieking with rage. The Hobbits cover their ears. The Ringwraiths wheel their horses towards the north and Gallop away along the river bank, quickly disappearing into the fog.|1
#
# 747|Regie|Lights of Bree a small village of stone and half timbered houses nestled against a low wooded hill.|1
#
# 750|Regie|A thick hedge surrounds the village a great gate bars the western entrance.|1
#
# 752|Regie|FRODO, SAM, MERRY AND PIPPIN approaching the gatehouse wild eyes, ragged, and out of breath.|1
#
# 754|Regie|A SURLY GATEKEEPER glances down at them.|1
#
# 757|Regie|The gatekeeper swings his lantern onto the hobbits, bathing them in an uncomfortable yellow spotlight.|1
#
# 761|Regie|The Hobbits gratefully enter Bree the gatekeeper eyeing them curiously in the lantern light.|1
#
# 765|Regie|The tall BREE FOLK loom over the nervous little hobbits as Frodo, Sam, Merry and Pippin make their way through the Narrow Streets. Tall buildings tower above them lights glow dimly from behind thick curtains.|1
#
# 769|Regie|The sign of the "PRANCING PONY INN" Frodo, Sam, Merry, and Pippin hurry toward it.|1
#
# 772|Regie|Frodo, Sam, Merry and Pippin come rushing in. Frodo attracts the INN KEEPERS'S attention.|1
#
# 782|Regie|the noise, smokey Inn. It is dimly lit, cheifly from a blazing log fire and crowded with a mixture of BIG FOLK, LOCAL HOBBITS, and a couple of dwarfs. Frodo, Sam, Merry and Pippin are sitting at a table against the wall clearly trying to remain Quiet and inconspicuous Sam can't help himself he keeps casting nervous glances around.|1
#
# 786|Regie|Merry ploinks himself down at a table, carrying a very large mug of beer.|1
#
# 790|Regie|Sam watches Pippin rise unsteadily to his feet and head to the bar.|1
#
# 792|Regie|A COUPLE OF SWARTHY MEN leaning against the bar glance at Frodo, then quickly look away.|1
#
# 794|Regie|Sam indicates a BROODING STRANGER who sits alone at a table in the far corner, smoking a curiously carved long stemmed pipe, peering from beneath a travel stained cowl with gleaming eyes. Frodo gestures to Butterbur.|1
#
# 798|Regie|BENEATH TABLE FRODO'S fingers are nervously TOYING WITH THE RING.|1
#
# 801|Regie|FRODO|1
#
# 802|Regie|Sweat runs down his brow. The Strange hum of the Ring spills into the Soundtrack.|1
#
# 803|Regie|"Baggins Baggins " a creepy whisper seems to fill Frodo's head sound that dissolves into Pippin's loud voice|1
#
# 805|Regie|PIPPIN|1
#
# 806|Regie|sitting at the bar, chatting with Locals. Frodo leaps to his feet and pushes his way towards the bar.|1
#
# 808|Regie|Frodo grabs Pippin's sleeve, spilling his beer.|1
#
# 811|Regie|Pippin pushes Frodo away he stumbles backwards, and falls to the floor. At that instant, the Inn goes silent and all the attention turns to Frodo.|1
#
# 813|Regie|The ring in agonizing Slow motion we watch as it seems to hang in the air for a split second then crashes down onto his out stretched finger. FRODO VANISHES. There is a sharp intake of breath followed by total silence.|1
#
# 816|Regie|The RINGWRAITHS turn sharply in their saddles Instantly aware that the ring is being worn. They spur their horses towards the distant lights of Bree.|1
#
# 820|Regie|Sam looks sick Pippin instantly sobers, realizing his folly the brooding stranger frowns and the inn erupts into excited babble.|1
#
# 823|Regie|FRODO as he finds himself in the TWILIGHT WORLD of the ring THE EXCITED CROWD ARE suddenly moving in slow motion distorted voices a weird photographic negative quality. FRODO is moving in real time against the slow motion background. He suddenly clutches his head as he is hit with quick images of a GREAT EYE. AN EVIL CAT-LIKE EYE, wreathed in flames.|1
#
# 824|Regie|VOICE OF SAURON|1
#
# 825|Regie|There is no life here in the void only cold only death FRODO is terrified. He rolls under a table, desperately pulling the ring from his finger. FRODO MATERIALIZES into the real world. AT THAT MOMENT A LARGE HAND reaches under the table and Grabs Frodo by the collar, and DRAGS HIM AWAY.|1
#
# 828|Regie|Frodo is roughly pushed against the wall. The Brooding stranger looms over him.|1
#
# 832|Regie|Frodo is pushed into the Hobbit's room by Strider.|1
#
# 843|Regie|The door bursts open and Sam, Merry and Pippin appear on the doorway. Sam is Squaring off with is fists, Merry brandishes a candlestick, and Pippin a chair.|1
#
# 845|Regie|STRIDER SHEATHS his sword, a slight smile playing on his lips.|1
#
# 849|Regie|The gate keeper comes out of his Lodgings with a lantern a look of fear on his face. He approaches the closed gate with great apprehension. The Gatekeeper peers out of his Peephole.|1
#
# 850|Regie|CRASH.|1
#
# 851|Regie|The gate crashed down on the gatekeeper as four RINGWRAITHS ride into Bree.|1
#
# 855|Regie|The four RINGWRAITHS fly done the empty streets, like horsemen of the apocalypse.|1
#
# 857|Regie|the front door FLIES OPEN. The FOUR RINGWRAITHS rush into the PRANCING PONY with WICKED SWORDS DRAWN. BUTTERBUR hiding behind his bar trembling and sweating in TERROR.|1
#
# 859|Regie|MERRY SNORING SOFTLY ON HIS PILLOW.|1
#
# 860|Regie|PIPPIN stirs slightly, then settles back to sleep. the door creaks open THE FOUR RINGWRAITHS silently slide into the Hobbit's room. The LOOM above each bed, raising their SHINING SWORDS ABOVE THE SLEEPING HOBBITS. Sam's eyes open wide. In unison, the RINGWRAITS STAB THE HOBBITS, in a Slashing, hacking frenzy.|1
#
# 862|Regie|Strider is grimly listening to the sounds from his room.|1
#
# 864|Regie|the RINGWRAITHS step back from the slashed beds in triumph. a hacked blanket is pulled back to reveal nothing but a shredded pillow. The RINGWRAITHS SHRIEK WITH RAGE Sam sits up with a start. Another shredded pillow is revealed. More Shrieks of rage. PIPPIN AND MERRY wake with a start.|1
#
# 867|Regie|Sam, Merry, and Pippin have been sleeping on Strider's bed. Frodo stands next to Strider by the window, peering out nervously as furious Ringwraith screeches echo across the courtyard from the Hobbits room.|1
#
# 874|Regie|Strider looks from the window as the Ringwraiths gallop down the Bree Streets. Strider turns back to the Hobbits, his face lit faintly by the Glowing Embers of the Fire.|1
#
# 879|Regie|STRIDER, MERRY, PIPPIN, AND FRODO march through a gloomy, overgrown forest. Sam follows at the read leading "Bill", a scrawny pony, who is laden with supplies.|1
#
# 882|Regie|Frodo watches uneasily as Strider moves off into the cover of the trees.|1
#
# 891|Regie|SAM looks excited.|1
#
# 893|Regie|Strider leads the Hobbits through the gloom of the forest.|1
#
# 896|Regie|Strider leading Frodo, Sam, Merry, and Pippin across the windswept moors. The hobbits suddenly stop and unstrap their knapsacks.|1
#
# 901|Regie|Strider stares at Pippin blankly, then turns away, shaking his head.|1
#
# 905|Regie|An apple is thrown to Merry, who deftly catches it. Another, aimed at Pippin, catches him on the forehead.|1
#
# 909|Regie|The hobbits trudge through rain, looking tired, hungry, and miserable.|1
#
# 912|Regie|Saruman stands over the Palantir, his hands cupping the massive eye.|1
#
# 914|Regie|BLACK SPEECH FILLS THE ROOM ADMIST THE|1
#
# 915|Regie|HARSH, GUTTURAL WORDS THE VOICE OF SARUMAN EMERGES.|1
#
# 918|Regie|Saruman is seated as his ORC OVERSEER approaches.|1
#
# 923|Regie|GANDALF lying unconscious on a cold obsidian floor. He wakes to the sound of ripping and tearing rising onto his knees lifting his head Gandalf stands as the camera pulls back to reveal him stranded on the summit of Orthanc. He is marooned on the tiny, flat peak, surrounded on all sides by a sheer 500 FOOT DROP. Another whispering wail rends the air. Gandalf crosses quickly to the edge and peers down One of the beautiful Isengard trees is being ripped from the ground by the ORCS. Gandalf looks on in Horror as ORCS hack into the trunk with axes.|1
#
# 930|Regie|MORE AND MORE TREES are hauled down and killed as Gandalf looks on in helpless despair.|1
#
# 933|Regie|The rugged countryside as the hobbits journey on, lead by Strider. Strider stops before a distant hill, topped by an Ancient Ruin.|1
#
# 938|Regie|FRODO, MERRY, AND PIPPIN collapse into a small hollow, halfway up Weathertop they are muddy and exhausted. Stider drops 4 small swords at the Hobbits feet.|1
#
# 942|Regie|Frodo eyes flickering open. He suddenly sits up, sniffing the air. Sam, Merry, and Pippin huddled over a small fire Sausages and bacon sizzle in a hot frying pan.|1
#
# 950|Regie|A SUDDEN SHREIK.|1
#
# 952|Regie|FIVE RINGWRAITHS ON FOOT, running up the steep slope unnaturally fast.|1
#
# 954|Regie|Frodo, Sam, Merry and Pippin clamber desperately towards the summit, clutching their swords.|1
#
# 957|Regie|Frodo, Sam, Merry, and Pippin race into a RING OF BROKEN STONES on the summit or Weathertop the ruined base of an ancient tower. The hobbits stand back-to-back in the centre of the Ring, waiting for the first assault One by one, the 5 Ringwraiths appear brandishing Gleaming swords, they move slowly towards the hobbits. In the center is their leader the WITCH KING.|1
#
# 959|Regie|Sam rushes forward with a cry. He swings his sword at the Witch King, who blocks the blow with his own sword. Sam's blade shatters the WITCH KING lashes out with his fist, sending Sam flying. Merry and Pippin, overcome with terror, throw themselves flat on the ground. THE RINGWRAITHS close in on Frodo a Venomous whisper dances in his head.|1
#
# 960|Regie|Frodo shuts his eyes and staggers back, desperately resisting the WRAITH'S WHISPERINGS slow motion as his hand goes into his pocket and pulls out the ring. The 5 Ringwraiths utter a chilling SCREECH OF EXCITEMENT. Frodo is unable to resist any longer, falls to his knees and slips on the ring. He disappears.|1
#
# 967|Regie|Frodo finds himself in the weird twilight world he looks upon the Ringwraiths, now visible in their TRUE APPEARANCE Five Ghouls dressed in long Grey robes, with white hair, and Pallid, ruthless faces. THE WITCH KING extends a haggard hand towards Frodo, reaching for the ring on his finger. Frodo's trembling hand extends forward as if by the pull of the ring he slides to the ground, unable to pull his hand away. The witch king snarls and springs forward. He stabs at Frodo with a wicked dagger. Frodo winces as the tip of the dagger sinks into his shoulder. Suddenly, Strider charges at the RINGWRAITHS, wielding his sword in one hand, a flaming torch in the other. He moves in slow motion, visible through a sea of mist. Frodo sinks to the ground. Behind him is a faint image of a Ringwraith fleeing, his head engulfed in flames. With draining strength, Frodo manages to pull the ring off his finger.|1
#
# 969|Regie| Appearing back in the real world, Sam rushes over to him.|1
#
# 971|Regie|Another Ringwraith is burning and screaming others screech fearfully at the flames, turn and flee form the Weathertop summit.|1
#
# 973|Regie|Strider kneels before Frodo. He snatches up the Witch King's Dagger from the ground, staring gravely at the long, thin, blade.|1
#
# 981|Regie|Strider is jogging grimly, carrying an ailing Frodo on his back. Sam, Merry, and Pippin are running to keep up. The hobbits are carrying Flaming torches for protection.|1
#
# 988|Regie|Low angle looking up at ORTHANC the tower of Isengard, gleaming in the moonlight. The camera rises to reveal the once beautiful gardens are not a pitted wasteland with smoke and fire billowing out|1
#
# 989|Regie|of numerous tunnels and vent holes that litter the forecourt of ORTHANC. Strange guttural chants echo up from deep underground. The camera is rising a small moth flutters into shot and leads the camera towards the summit or Orthanc. Gandalf lies slumped against the wall at the very top of Orthanc, surrounded by a sheer 500 foot drop. He looks Weak and Frail and is seemingly asleep. The MOTH flutters close to Gandalf. His hand suddenly moves at lighting speed and SNATCHES THE MOTH. Gandalf brings his hand close to his face and opens it. The moth sits on the palm of his hand as Gandalf mutter strange words in a foreign tongue. THE MOTH'S face seemingly listening.|1
#
# 992|Regie|It suddenly flutters away. CAMERA FOLLOWS the moth off the Orthanc summit, but drops past the moth falling down, down, towards the pitted wasteland, straight into a fiery red tunnel.|1
#
# 994|Regie|The dead trees of Isengard are fed into roaring furnaces molten metal pours into casts red hot metal, beaten my sweating orc blacksmiths armor and weapons are forged from the great furnaces. Saruman strides among the ORCS and stands looking on a new born uruk-hai as it escapes its birthing membrane this is LURTZ, who rises up to stand before his master.|1
#
# 997|Regie|Frodo his eyes flicker open clouded, red- rimmed his brow, beaded with sweat.|1
#
# 1000|Regie|A DISTANT CRY of a RINGWRAITH carries through the air.|1
#
# 1002|Regie|Frodo gasps in sudden pain.|1
#
# 1013|Regie|Sam and Strider desperately search the dark forest floor for the Athelas plant. A small, white flowered plant. Strider drops to one knee, carefully pulling it from the ground.|1
#
# 1014|Regie|SUDDENLY. STRIDER FREEZES AS A SWORD BLADE TOUCHES HIS NECK.|1
#
# 1016|Regie|Strider slowly looks up.|1
#
# 1019|Regie|Frodo is breathing hard, desperately ill. Surreal impression a SHIMMERING FIGURE IN WHITE leaps off a horse.|1
#
# 1020|Regie|An ethereal vision of ARWEN, as she appears on the other side.|1
#
# 1027|Regie|ARWEN|1
#
# 1028|Regie|Who now appears in her earth bound form, a young Elven woman with tousled hair, dressed in mud-splattered riding clothes.|1
#
# 1038|Regie|Arwen reaches for Strider's hand looking deep into his eyes.|1
#
# 1044|Regie|Arwen mounts her horse, ALSFORTH.|1
#
# 1047|Regie|Arwen looks down at Strider as she supports Frodo with one hand.|1
#
# 1051|Regie|Asfaloth springs away, bearing Arwen and Frodo into the night.|1
#
# 1054|Regie|through the forest from the back of the White Horse.|1
#
# 1055|Regie|FRODO, BOUNCING IN THE SADDLE,|1
#
# 1056|Regie|he lifts his head weakly. SURREAL THE HORSES HEAD BOBBING trees sliding by moonlight flickers through the trees.|1
#
# 1059|Regie|of Arwen's white horse emerging from the trees and galloping across the open land as the sun rises.|1
#
# 1064|Regie|The white horse charges through a Pine Forest. Suddenly 2 Galloping Ringwraiths emerge from the trees behind. 2 more Ringwraiths slide in from different directions to join the chase. Arwen grits her teeth urges the white horse to greater speed.|1
#
# 1067|Regie|The white horse speeds out of the pine trees the 4 ringwraiths close behind 2 more ringwraiths galloping down the hillside. 3 MORE RINGWRAITHS enter frame from different directions a total of 9 RINGWRAITHS now pursuing Frodo and Arwen. Panting head of the WHITE ELVEN HORSE.|1
#
# 1071|Regie|As the White Horse races towards Camera, to Reveal the wide river Bruinen in the foreground.|1
#
# 1072|Regie|Without hesitation, the white horse leaps into the shallow water and thunders across the Ford. The 9 Ringwraiths pull up short of the Ford, clearly nervous of the water. The white horse reaches the other side Arwen pulls up and turns to defiantly face the Ringwraiths from across the Ford.|1
#
# 1075|Regie|THE WITCH KING SCREECHES ANGRILY, draws his sword, and leads the Ringwraiths across the Ford. The water starts flowing faster a distant rumble can be heard. Arwen waits until they are halfway across she suddenly stands in the saddle arms raised.|1
#
# 1078|Regie|THE GROUND SUDDENLY TREMBLES A MIGHTY ROAR FILLS THE AIR.|1
#
# 1079|Regie|Frodo looks up weakly to see a vast torrent of Water flooding down the river towards the ford as if a dam had burst. The Foaming water seems to form the shape of Dancing white horses with frothing manes. The Ringwraiths scream in terror as they are swallowed up in the deluge. Their Piercing cries are drowned in the roaring of the river as it carries them away. FRODO as he loses consciousness.|1
#
# 1081|Regie|Arwen gathers the small Hobbit in her arms, feeling his life slip away.|1
#
# 1083|Regie|DELIRIOUS IMAGES AND SOUNDS.|1
#
# 1085|Regie|A BRIGHT LIGHT suddenly flares Frodo squeezes his eyes shut, gasping.|1
#
# 1087|Regie|A FAMILIAR VOICE cuts through the swirl of sound.|1
#
# 1090|Regie|Frodo's eyes flicker Open He is lying in bed next to an Open Window Dappled sunlight plays on richly carved timbers the sound of a nearby waterfall drifts through the Vista of Fir Trees.|1
#
# 1094|Regie|GANDALF IS SITTING NEXT TO FRODO'S BED.|1
#
# 1095|Regie|softly puffing on his pipe. He smiles at Frodo.|1
#
# 1097|Regie|Frodo sits up, looking at Gandalf questioningly.|1
#
# 1100|Regie|Gandalf troubled. His eyes drift away.|1
#
# 1104|Regie|SARUMAN stands over Gandalf, gloating.|1
#
# 1106|Regie|With the power of his staff, Saruman raises Gandalf from the ground, then sends him crashing to the floor.|1
#
# 1108|Regie|SUDDENLY. GANDALF lurches to his feet and Throws himself off the Tower. Saruman watches Gandalf fly away from Isengard on the Back of a GIANT EAGLE.|1
#
# 1114|Regie|Gwaihir the Eagle soars majestically over the mountains, carrying Gandalf towards the dawn.|1
#
# 1117|Regie|Frodo raises himself up and looks at Gandalf.|1
#
# 1120|Regie|Sam runs to Frodo's bedside. He is overjoyed to find Frodo awake.|1
#
# 1125|Regie|bedside his face is neither old nor young, though in it is written the memory of many things both glad and sorrowful.|1
#
# 1129|Regie|RIVENDELL a small cluster of elegant Elven Buildings sitting in a Shangri-la like Valley below towering cliffs and snow capped mountains.|1
#
# 1136|Regie|Frodo and Sam walk together. Suddenly, the voices of Merry and Pippin can be heard as they bound up to Frodo and throw their arms around him.|1
#
# 1138|Regie|Sam looks past Frodo smiling a bent figure sits alone on a bench, in the Sun. Frodo turning, following Sam's gaze.|1
#
# 1142|Regie|BILBO BAGGINS. He breaks in to a broad grin as Frodo rushes forward to embrace him. Bilbo has aged significantly since we last saw him.|1
#
# 1145|Regie|LATER Frodo is turning the neatly inscribed title page of a red leather bound journal|1
#
# 1147|Regie|Bilbo smiles Proudly. He is sitting with Frodo on a terrace overlooking a Waterfall. Frodo looks at Page after page of beautiful Handwriting, with intricate Maps and Drawings.|1
#
# 1153|Regie|Frodo turns a page there before him, is a map of the Shire.|1
#
# 1158|Regie|Sam busily tries to stuff more and more things into his already full pack pots and pans, blankets, cooking utensils, provisions, clothes.|1
#
# 1161|Regie|Sam looks up, startled.|1
#
# 1175|Regie|Gandalf and Elrond watch Frodo and Sam from Elrond's balcony,|1
#
# 1184|Regie|Elrond turns and walks away.|1
#
# 1186|Regie|Gandalf turns and looks out the window.|1
#
# 1187|Regie|Sounds of arrivals Gandalf watches as Boromir rides through Rivendell gate, followed by Legolas and Gimli.|1
#
# 1192|Regie|With the broken sword, Isildur slices off Sauron's finger. Elrond reacts.|1
#
# 1196|Regie|ISILDUR PICKS UP THE RING AND STARES AT IT,|1
#
# 1197|Regie|ENTRANCED.|1
#
# 1203|Regie|ELROND AND ISILDUR STAND BEFORE THE FIRES OF|1
#
# 1204|Regie|MT. DOOM.|1
#
# 1206|Regie|ISILDUR CAPTIVATED BY THE RING.|1
#
# 1208|Regie|Isildur turns and walks away|1
#
# 1211|Regie|Elrond turns to Gandalf.|1
#
# 1220|Regie|Strider watches from the shadows as Boromir strolls through the darkened gallery. Boromir's eyes are drawn to an old Fresco on the wall depicting Isildur defeating Sauron. Boromir looks with Wonderment at Narsil, the Broken Blade of Elendil, which lies on a cloth-covered plinth.|1
#
# 1223|Regie|Boromir senses Strider's presence he looks from the blade to Strider, as if sensing a connection.|1
#
# 1226|Regie|Strider picks up the broken hilt, as Arwen appears behind him.|1
#
# 1235|Regie|Night falls upon the beautiful valley of Rivendell still and quiet.|1
#
# 1237|Regie|Strider and Arwen stand upon a stone bridge the Evenstar at Arwen's breast shines in the moonlight.|1
#
# 1240|Regie|Arwen reaches up and gently touches the Grey at Strider's temples.|1
#
# 1242|Regie|Arwen looks into Strider's eyes.|1
#
# 1251|Regie|Arwen closes Strider's fingers around the jewel.|1
#
# 1252|Regie|Arwen leans towards Strider, gently kissing him.|1
#
# 1255|Regie|Elrond addresses the council.|1
#
# 1257|Regie|Frodo sits amongst a council of free-peoples of Middle earth, Elrond stands before them, addressing Gandalf, Strider, Legolas, and 20 other elves, Dwarves, and men.|1
#
# 1259|Regie|Frodo steps forward and moves towards a stone Plinth. He places the ring on the plinth and returns to his seat.|1
#
# 1268|Regie|Strider says nothing and Boromir turns away dismissively. LEGOLAS stands.|1
#
# 1270|Regie|Frodo looks at Strider questioningly Boromir turns sharply.|1
#
# 1281|Regie|Gimli suddenly rushes forward. He swings his axe down on the ring. The axe shatters with a deafening crack. Gimli falls backwards, staring in disbelief at the ring unharmed. Frodo winces as an angry image of the fiery eye hits him. He slumps in this chair, clutching his forehead. Gandalf looks at him with concern.|1
#
# 1284|Regie|Stunned silence the council sits with downcast eyes, as if a great dread has descended on them. Boromir addresses the council in a quiet voice|1
#
# 1289|Regie|Gimli leaps to his feet.|1
#
# 1293|Regie|motion the angry faces, the shaking fists, the accusatory fingers, his eyes move across to the ring the hum grows louder in his head.|1
#
# 1295|Regie|THE RING fills the screen streams of blood flow across the surface flames flicker within the Gold Band.|1
#
# 1297|Regie|FRODO breathing rapidly, Caught in the grip of his hideous vision. With a huge effort or will, Frodo tears his gaze upon the ring. Frodo suddenly stands he speaks in a strong, clear voice.|1
#
# 1299|Regie|Sudden silence Frodo looks around the room at the astounded faces.|1
#
# 1307|Regie|Boromir looks at them all then walks towards Frodo.|1
#
# 1309|Regie|Boromir looks towards Elrond and Gandalf.|1
#
# 1311|Regie|Frodo stares in wonder as the Greatest Fighters in all Middle earth stand at his side.|1
#
# 1313|Regie|A Sudden Noise Sam pops up from behind a Bush.|1
#
# 1316|Regie|Merry and Pippin jump up from behind another bush.|1
#
# 1322|Regie|ELROND SURVEYS THE GROUP|1
#
# 1327|Regie|An old sword sliding out of a shabby leather Scabbard its polished, well tendered Blade glitters cold and bright.|1
#
# 1329|Regie|Bilbo offers Sting to Frodo.|1
#
# 1332|Regie|Bilbo unwraps a small shirt of close woven Mail.|1
#
# 1334|Regie|Frodo peels off his shirt revealing The Ring on the Chain around his neck.|1
#
# 1342|Regie|Bilbo sobs and Frodo moves to comfort him.|1
#
# ...
#
# 2079|Regie|FRODO shuts his eyes, his breath coming in GASPS.|3
#
# 2084|Regie|With that, SAM lifts FRODO on to his shoulders and starts to CLIMB MOUNT DOOM. His plain hobbit-face grows stern, almost grim, as the will hardens in him.|3
#
# 2085|Regie|TWO TINY HOBBITS on the ENDLESS shale SLOPES of the MOUNTAIN.|3
#
# 2088|Regie|ARAGORN and COMPANY watch as they are surrounded by a tide of ORCS.|3
#
# 2089|Regie|ARAGORN raises ANDURIL in the BROAD SWEEP as he walks forward he turns to FACE the OTHERS.|3
#
# 2090|Regie|QUIET RESOLVE written on ARAGORN's face as he looks into the EYES of the remaining members of the FELLOWSHIP.|3
#
# 2092|Regie|ARAGORN turning, SWORD-raised, he CHARGES FORWARD.|3
#
# 2093|Regie|There is a moment of SILENCE no-one else moves SUDDENLY a SHOUT goes up.|3
#
# 2094|Regie|PIPPIN and MERRY charging forward The rest of the MEN following.|3
#
# 2095|Regie|ARAGORN crashing head on into a line of ORCS.|3
#
# 2096|Regie|The blade of ANDURIL flashing as ARAGORN HACKS at ORCS.|3
#
# 2101|Regie|Like a small grey insect, SAM creeps up the slope with FRODO on his back foot by foot.|3
#
# 2102|Regie|The mantling CLOUD swirls, revealing the cruel pinnacles and iron crown of BARAD-DUR, the Dark Tower, in the distance.|3
#
# 2103|Regie|SAM staggering under FRODO'S weight STRONG ash- laden WINDS are buffeting him as he slowly CLIMBS MOUNT DOOM.|3
#
# 2104|Regie|The PLAIN of GORGOROTH lies 1000 FEET BELOW, wrapped in fume and shadow.|3
#
# 2105|Regie|A TREMOR ripples through the GROUND a RED FLAME explodes into the SKY.|3
#
# 2106|Regie|SAM looks up - fearful the MOUNTAIN could explode at any moment.|3
#
# 2107|Regie|Through the THICK, FUME-LADEN AIR a set of STAIRS can be made out.|3
#
# 2109|Regie|SAM can't believe it - relief and joy flood through him.|3
#
# 2111|Regie|SMACK OUT OF NOWHERE the figure of SMEAGOL crashes into them sending SAM and FRODO sprawling.|3
#
# 2112|Regie|SMEAGOL pounces on FRODO his fingers wrapping around his throat, snapping FRODO'S neck from side to side.|3
#
# 2113|Regie|FRODO as he struggles to unlock the BONY, WHITE FINGERS around his neck but SMEAGOL'S grip is too strong.|3
#
# 2114|Regie|SMEAGOL'S fingers tightening around FRODO'S neck - squeezing the life out of him.|3
#
# 2118|Regie|FRODO comes to.|3
#
# 2121|Regie|The BATTLE between MEN and ORCS rages on From MORDOR, high OVERHEAD, the NAZGUL fly out into the FRAY.|3
#
# 2124|Regie|All the old HATRED between SAM and SMEAGOL boils over as they FIGHT SAM falls back SMEAGOL BITING at his SHOULDER. SAM pushes SMEAGOL away with his feet rolls to his KNEES, as SMEAGOL charges at him.|3
#
# 2125|Regie|SAM slashes out with STING. He cuts SMEAGOL across the stomach. SMEAGOL staggers back, SCREAMING with PAIN.|3
#
# 2126|Regie|SAM looks around desperately for FRODO.|3
#
# 2128|Regie|FRODO has GONE.|3
#
# 2129|Regie|FRODO RUNNING UP THE MOUNTAIN.|3
#
# 2132|Regie|FELLOWSHIP fight BRAVELY a hideous screech rends the AIR.|3
#
# 2133|Regie|GANDALF looks up to a NAZGUL diving straight toward him.|3
#
# 2134|Regie|GANDALF eyes flicker as a small MOTH flutters across his line of sight.|3
#
# 2138|Regie|Another cry rends the air as.|3
#
# 2139|Regie|SMACK. The GIANT EAGLE, GWAHIR, SMASHES into the FELLBEAST, it's claws ripping into the HIDEOUS MONSTER'S NECK.|3
#
# 2140|Regie|PIPPIN in the midst of BATTLE looks up.|3
#
# 2142|Regie|Above the BATTLE attack formation, more EAGLES appear.|3
#
# 2143|Regie|PIPPIN (cont'd) The Eagles are coming. The Eagles are coming.|3
#
# 2144|Regie|The EAGLES engage the NAZGUL.|3
#
# 2147|Regie|SAM is GASPING, his lungs EXPLODING as he RACES up the SLOPES of MOUNT DOOM searching for FRODO.|3
#
# 2148|Regie|SAM arriving at the STONE DOORWAY of SAMMATH NAUR leading into the MOUNTAIN.|3
#
# 2149|Regie|SAM staggers into it.|3
#
# 2151|Regie|SAM flinches against the FIERCE HEAT blasting down the TUNNEL.|3
#
# 2153|Regie|SAM lurches forward towards an ORANGE GLOW deep in the HEART of the MOUNTAIN.|3
#
# 2157|Regie|The HEAT is almost UNBEARABLE SAM sees FRODO in the DISTANCE.|3
#
# 2159|Regie|FRODO is standing on the EDGE of the CRACK OF DOOM a deep LAVA FILLED CHASM, in the very heart of ancient SAURON'S FORGES, the greatest in Middle-earth.|3
#
# 2160|Regie|The RAGING ORANGE GLARE from the CHASM turns FRODO into a BLACK SILHOUETTE standing TENSE and STILL.|3
#
# 2161|Regie|FRODO holds the RING in his HAND he RAISES IT, holding it over the BUBBLING LAVA far below.-|3
#
# 2163|Regie|FRODO a STRANGE EXPRESSION on his face.|3
#
# 2165|Regie|The HUM of the RING grows louder and louder. FRODO PULLS the RING close to his body as he turns to SAM.|3
#
# 2166|Regie|FRODO looks at SAM, the RING has finally taken him.|3
#
# 2168|Regie|SAM SCREAMS as.|3
#
# 2169|Regie|FRODO PUTS THE RING ON. He VANISHES.|3
#
# 2175|Regie|With a storm of wings, the NAZGUL wheel around and hurtle towards MOUNT DOOM.|3
#
# 2176|Regie|In the midst of the BATTLE - GANDALF realising FRODO has been seen.|3
#
# 2179|Regie|SAM is SCREAMING for FRODO.|3
#
# 2180|Regie|FOOTPRINTS moving across the ASH COVERED CAVERN FLOOR.|3
#
# 2181|Regie|SUDDENLY. GOLLUM smashes a ROCK down on SAM'S HEAD, knocking him to the GROUND.|3
#
# 2182|Regie|GOLLUM LEAPS on to the INVISIBLE FRODO.|3
#
# 2183|Regie|FRODO'S FOOTPRINTS staggering about under GOLLUM'S WEIGHT.|3
#
# 2184|Regie|GOLLUM clawing FRANTICALLY, riding on the BACK of the INVISIBLE FRODO.|3
#
# 2187|Regie|ARAGORN turns and is confronted by an ARMOURED TROLL, wielding an ENORMOUS MALLET.|3
#
# 2190|Regie|GOLLUM suddenly LIFTS HIS HANDS to his face and BITES HARD.|3
#
# 2191|Regie|FRODO MATERIALIZES as he DROPS TO HIS KNEES, clutching his BLEEDING HAND he SCREAMS.|3
#
# 2197|Regie|LEGOLAS as ARAGORN falls to the GROUND.|3
#
# 2200|Regie|GOLLUM triumphantly HOLDS the RING ALOFT ECSTATIC.|3
#
# 2201|Regie|GOLLUM dancing GLEEFULLY PERILOUSLY close to the EDGE OF THE CHASM.|3
#
# 2204|Regie|ARAGORN turns to see HUGE TROLL FEET moving CLOSER LEGOLAS races toward him.|3
#
# 2206|Regie|GOLLUM still TRIUMPHANT on the edge of the PRECIPICE The FIERY LAVA casting an EVIL LIGHT He jumps about in DELIGHT.|3
#
# 2208|Regie|FRODO rises slowly his EYES lock on GOLLUM time seems to stand still as each regards the other.|3
#
# 2209|Regie|the RING glinting in GOLLUM'S HAND BEAUTIFUL POWERFUL EVIL.|3
#
# 2210|Regie|SUDDENLY. FRODO lunges at GOLLUM.|3
#
# 2211|Regie|FRODO thuds into GOLLUM, lifting him off his feet.|3
#
# 2218|Regie|THUD. The HUGE FOOT of the CAVE TROLL lands on ARAGORN'S chest. He STABS at. it ineffectually.|3
#
# 2219|Regie|GANDALF in despair.|3
#
# 2222|Regie|SAM watches in HORROR as FRODO and GOLLUM disappear into the CHASM. He staggers over.|3
#
# 2223|Regie|GOLLUM falls into the CRACK OF DOOM INSTANTLY engulfed in the CHURNING LAVA.|3
#
# 2224|Regie|SAM leans into the CRACK OF DOOM.|3
#
# 2225|Regie|FRODO clinging onto the ROCK FACE with his ONE GOOD HAND.|3
#
# 2226|Regie|The CAVERNS are SHAKING VIOLENTLY.|3
#
# 2227|Regie|SAM desperately reaches for him FRODO is too far down.|3
#
# 2229|Regie|FRODO looks at SAM, his face impassive.|3
#
# 2231|Regie|FRODO struggles to reach SAM he.can't reach WITH HIS BLEEDING hand, and falls'back, still clinging valiantly to the ROCK with his good hand.|3
#
# 2235|Regie|FRODO looks at SAM imploringly.|3
#
# 2237|Regie|FRODO reaches up once more and this time SAM GRASPS his hand TIGHTLY .|3
#
# 2238|Regie|The RING sits on the river of LAVA for a brief moment, then SINKS away.|3
#
# 2239|Regie|the EYE OF SAURON.|3
#
# 2240|Regie|Across the GREAT PLAINS - MOUNT DOOM is clearly IMPLODING.|3
#
# 2243|Regie|On the BATTLEFIELD, all eyes turn to MOUNT DOOM.|3
#
# 2244|Regie|The CAVE TROLL, with ARAGORN at his mercy, is distracted by the SOUNDS emanating from MORDOR he turns in TERROR and RUNS OFF.|3
#
# 2246|Regie|The FELLOWSHIP turn to watch as the MASSIVE DARK TOWER of SAURON shakes itself to pieces.|3
#
# 2247|Regie|TOWERS FALL and WALLS CRUMBLE vast spires of SMOKE and spouting STEAM billow up.|3
#
# 2248|Regie|The FOUNDATIONS explode apart.|3
#
# 2250|Regie|The BLACK GATES collapse in a huge cloud of ASH.|3
#
# 2254|Regie|THE COMPANY watch as MOUNT DOOM explodes the reason for their MISERY is clear it's plain FRODO and SAM can never survive the cataclysm.|3
#
# 2257|Regie|The VOLCANO is ERUPTING, FIRE belches from it's riven summit, sending LAVA streaming down it's sides.|3
#
# 2258|Regie|FRODO and SAM stagger out of the SAMMATH NAUR DOOR all around ASH and MOLTEN ROCKS fall. The SKIES burst into THUNDER, seared with LIGHTNING.|3
#
# 2259|Regie|The screaming NAZGUL fall from the sky in FLAMES.|3
#
# 2260|Regie|The ground is shaking so violently that FRODO and SAM can barely stand.|3
#
# 2261|Regie|FRODO stumbles SAM helps him up FRODO smiles.|3
#
# 2263|Regie|SAM looks down at FRODO FRODO'S FACE is at PEACE his BURDEN destroyed.|3
#
# 2265|Regie|FRODO and SAM crawl onto a ROCK as LAVA streams towards them in seconds THEIR ROCK is an island in a sea of MOLTEN FIRE. ,' .|3
#
# 2266|Regie|FRODO shuts his eyes.|3
#
# 2270|Regie|FRODO glances at SAM he is WEEPING.|3
#
# 2271|Regie|FRODO wrapping an ARM around SAM'S SHOULDER.|3
#
# 2273|Regie|TWO TINY HOBBITS waiting to die amid a cataclysmic landscape LAVA erupts around them FIREBALLS rain down from the sky.|3
#
# 2276|Regie|GWAIHIR, the GREAT EAGLE flaps towards CAMERA He bears GANDALF on his back, and is followed by TWO MORE EAGLES.|3
#
# 2277|Regie|WIDE SHOT The EAGLES bravely fly amid the RAINING ASH and MOLTEN ROCKS and SNATCH FRODO and SAM from the ROCK.|3
#
# 2278|Regie|FRODO'S FACE as the FIERY VOLCANO recedes away beneath him the wind ruffles his hair he PASSES OUT.|3
#
# 2281|Regie|FRODO'S eyes flutter open looking around slowly his eyes alight on GANDALF.|3
#
# 2286|Regie|as MERRY and PIPPIN run in jumping on the bed and hugging FRODO.|3
#
# 2287|Regie|GIMLI and LEGOLAS enter the room their joy is PLAIN.|3
#
# 2288|Regie|ARAGORN joins them - the FELLOWSHIP is complete.|3
#
# 2289|Regie|finally FRODO'S eyes fall upon a FIGURE standing apart from the others it is SAM.|3
#
# 2290|Regie|FRODO'S and SAM'S eyes meet.|3
#
# 2293|Regie|SWEEPING over the MINAS TIRITH WALLS, racing towards the TOP of the CITY through a BLIZZARD of WHITE FLOWER PETALS. MINAS TIRITH is restored it gleams WHITE in the BRIGHT SUN.|3
#
# 2294|Regie|to REVEAL the COURT OF THE KINGS, CROWDED with 4000 PEOPLE cramming the WIDE PATH leading to the TOWER HALL.|3
#
# 2295|Regie|The CROWN of CONDOR glints in the BRILLIANT SUNSHINE.|3
#
# 2296|Regie|GANDALF places the CROWN upon ARAGORN'S head.|3
#
# 2298|Regie|ARAGORN smiles up at GANDALF.|3
#
# 2300|Regie|ARAGORN slowly RISES, turning to face the CROWD, who CHEER and CLAP for their KING.|3
#
# 2305|Regie|The CHEERS of his PEOPLE are DEAFENING.|3
#
# 2306|Regie|ARAGORN sings for his people Then WALKS in SLOW PROCESSION down the WHITE PAVED PATH as the CROWD BOW their heads in respect to their NEW KING.|3
#
# 2307|Regie|ARAGORN passes EOWYN and FARAMIR who bow before him EOMER steps FORWARD to bow in respect.|3
#
# 2308|Regie|TRUMPETS SOUND as a PROCESSION of ELVES, dressed in shimmering SILVERS and WHITES, led by LEGOLAS approach the KING LEGOLAS gestures behind him.|3
#
# 2309|Regie|ARAGORN'S eyes scan amongst the ELVES|3
#
# 2310|Regie|A BANNER carried aloft bearing the WHITE TREE of CONDOR in FULL FLOWER the RANKS of ELVES part revealing|3
#
# 2311|Regie|ARWEN, eyes shining MORTAL now, but deeply in love carrying the STANDARD of CONDOR ARAGORN kisses her|3
#
# 2312|Regie|ELROND looks on his face breaks into a smile.|3
#
# 2313|Regie|ARAGORN and ARWEN embrace.|3
#
# 2314|Regie|ARAGORN and ARWEN walking through the CROWD towards four SMALL FIGURES who stand nervously at the end of the AVENUE.|3
#
# 2315|Regie|ARAGORN and ARWEN look on FRODO, SAM, MERRY and PIPPIN, as they stand before them.|3
#
# 2316|Regie|The FOUR HOBBITS, dressed in their OLD CLOTHES, clean and mended, bow their heads.|3
#
# 2317|Regie|ARAGORN raises his HAND.|3
#
# 2322|Regie|TEARS spring into FRODO'S EYES. He clutches SAM'S shoulder as 4000 PEOPLE pay homage to the courage of two little Hobbits from the Shire.|3
#
# 2323|Regie|CAMERA RISES INTO THE AIR away from the CROWDED CITADEL, until MINAS TIRITH becomes a SPECK in the LANDSCAPE.|3
#
# 2327|Regie|DISSOLVING into the PARCHMENT MAP of MIDDLE-EARTH Slowly drifting across the MAP towards the WEST.|3
#
# 2332|Regie|Revealing HOBBITON bathed in a WARM SUNSET As FRODO, SAM, MERRY and PIPPIN ride into SHOT on PONIES past ODO PROUDFOOT who shakes his head at the STRANGENESS of their appearance.|3
#
# 2334|Regie|FRODO brings a round of drinks to the TABLE.|3
#
# 2339|Regie|The FOUR FRIENDS look at each other. A WORLD of experience now separates from their fellow HOBBITS.|3
#
# 2340|Regie|Seated at a long table, the FOUR FRIENDS raise their glasses SAM eye is suddenly caught.|3
#
# 2341|Regie|ROSIE COTTON who is serving behind the BAR.|3
#
# 2342|Regie|SAM steels himself and leaves to go and TALK to ROSIE.|3
#
# 2343|Regie|FRODO, MERRY and PIPPIN exchange smiles as.|3
#
# 2347|Regie|On a BEAUTIFUL sunny day, SAM and ROSIE are MARRIED With their dearest FRIENDS gathered around them.|3
#
# 2348|Regie|ROSIE throws a beautiful bouquet of FLOWERS it's caught by PIPPIN who smiles in embarrassment.|3
#
# 2351|Regie|FRODO walks through BAG END to his STUDY.|3
#
# 2353|Regie|FRODO from behind. He is HUNCHED over a DESK.|3
#
# 2357|Regie|FRODO WINCES with a sharp GASP of PAIN He puts the PEN down and CLUTCHES at his SHOULDER.|3
#
# 2358|Regie|SAM has entered the ROOM and stands BEHIND FRODO.|3
#
# 2360|Regie|FRODO He is DRAWN and PALE.|3
#
# 2362|Regie|SAM at a loss for words. His EYES fall to the BOOK '|3
#
# 2364|Regie|to FRODO'S HANDWRITING|3
#
# 2371|Regie|LYRICAL MUSIC OVER.|3
#
# 2372|Regie|A COLD WINTER'S MORNING Out of the FOG rattles a SMALL COVERED WAGON GANDALF is at the REINS.|3
#
# 2373|Regie|FRODO, SAM, MERRY and PIPPIN are waiting on PONIES for the WAGON all are wearing their GREY ELVEN ROBES.|3
#
# 2375|Regie|GANDALF arrives in his CART.|3
#
# 2378|Regie|The WAGON trundles along at a SEDATE PACE.|3
#
# 2379|Regie|SAM, MERRY and PIPPIN ride behind, leading FRODO'S EMPTY PONY.|3
#
# 2383|Regie|FRODO is SITTING in the WAGON his ARM around his UNCLE BILBO.|3
#
# 2384|Regie|BILBO is extremely OLD and FRAIL. He is DOZING his head slumped.|3
#
# 2391|Regie|BILBO nods back to sleep FRODO rests his head against him.|3
#
# 2394|Regie|FRODO, walking arm-in-arm with BILBO through a beautiful ELVEN BOAT-HOUSE GANDALF follows with MERRY, PIPPIN and SAM.|3
#
# 2395|Regie|As BILBO looks up, he is STUNG by the BEAUTY before hm i|3
#
# 2397|Regie|Passing under a beautiful ELVEN ARCHWAY.|3
#
# 2398|Regie|to reveal a WHITE SHIP, ready to depart from a WHITE STONE DOCK.|3
#
# 2399|Regie|ELROND, CELEBORN and GALADRIEL are waiting for them.|3
#
# 2403|Regie|BILBO bows in acknowledgement to ELROND, CELEBORN and GALADRIEL, who return his GREETING.|3
#
# 2409|Regie|BILBO walks down toward the BOAT and BOARDS with ELROND.|3
#
# 2410|Regie|FRODO looks up GALADRIEL is watching him. She SMILES, TURNS and BOARDS the BOAT.|3
#
# 2411|Regie|GANDALF kneels before SAM, MERRY and PIPPIN - who are all looking TEARFUL.|3
#
# 2413|Regie|There is GREAT SADNESS MERRY SNIFFLES LOUDLY.|3
#
# 2419|Regie|GANDALF looks at FRODO then turns and slowly walks towards the GANGPLANK to board the SHIP.|3
#
# 2421|Regie|FRODO turns to SAM.|3
#
# 2424|Regie|SAM looks down FRODO is holding BILBO'S RED JOURNAL out towards him.|3
#
# 2426|Regie|SAM is SOBBING MERRY and PIPPIN are DISTRAUGHT.|3
#
# 2427|Regie|FRODO hugs MERRY and PIPPIN, and last of all SAM and climbs on board the SHIP.|3
#
# 2428|Regie|FRODO a look of WONDERMENT crosses his face as he STEPS FORWARD and ACCEPTS GANDALF'S HAND finally released from his pain, care falls from his face he is the young FRODO we first met so long ago.|3
#
# 2429|Regie|SAM, MERRY and PIPPIN comfort each other as the WHITE SHIP glides away from the DOCK.|3
#
# 2435|Regie|SAM walks up the path towards his house.|3
#
# 2436|Regie|A LITTLE GIRL toddles up to greet him.|3
#
# 2438|Regie|He hugs his daughter.|3
#
# 2440|Regie|ROSIE COTTON steps up and kisses SAM on the cheek she gives him a TINY BABY BOY to cradle.|3
#
# 2442|Regie|SAM with his FAMILY he draws a deep breath|3
#
# 2444|Regie|SAM looks at his LOVELY FAMILY with GREAT HAPPINESS, tinged with a little SADNESS.|3
#
# 2445|Regie|SAM and ROSIE take the CHILDREN'S HANDS and enter BAGSHOT the BRIGHT YELLOW DOORWAY closes behind them.|3

# %% [markdown]
# ## 2.) Regieanweisungen aus Skript 2

# %%
lotr_2 = requests.get('https://imsdb.com/scripts/Lord-of-the-Rings-The-Two-Towers.html')

# %%
def get_all_lines():
    # webscrape text
    soup = BeautifulSoup(lotr_2.text, 'lxml')
    all_character_tags = soup.find('pre')

    # convert scraped bs4 element tags to string
    text = str(all_character_tags)

    # delete all tags
    text = re.sub(r'</?[a-zA-Z]+>', '', text)

    # split into text blocs 
    # Problem: mehrere Trenner - \r\n\r\n und \r\n \r\n)
    blocs = re.split(r'(\r\n\s?\r\n)', text)


    # WRITE TO CSV

    # Dateiname festlegen
    filename = f'lotr_skript2_dialog_regie_first_output.csv'

    # Datei löschen, falls sie existiert:
    if os.path.exists(f'data/{filename}'):
        os.remove(f'data/{filename}')


    with open(f'data/{filename}', 'a') as f:
        # Spaltenüberschriften
        f.write(f'Nr.|Sprecher/Regie|Text|Filmnr.\n')
        print(f'Nr.|Sprecher/Regie|Text|Filmnr.\n')

        # Blöcke durchgehen
        for num, bloc in enumerate(blocs):
            # Leerzeichen entfernen und Fragezeichen ersetzen (erzeugt beim Ausführen sonst Unicode-Error)
            bloc = bloc.replace("�", "%")   

            # match Regieanweisungen d.h. alle Blöcke, die direkt mit [ beginnen
            if(re.match(r'^\s*\[', bloc)):
                # remove whitespace
                regieText = bloc.strip()
                regieText = re.sub(r'\r\n', '', regieText) # Zeilenumbrüche innerhalb des Texts
                regieText = re.sub(r'\s+', ' ', regieText) # mehrfache Leerzeichen werden zu einem

                # write to CSV
                # Bsp: 1|Regie|Frodo jumps.|                 
                f.write(f'{num}|Regie|{regieText}|2\n')
                print(f'{num}|Regie|{regieText}|2\n')

            # match Sprechertext, d.h. alle Blöcke, die NICHT direkt mit [ beginnen
            elif(not re.match(r'^\s*\[', bloc)):
                # überflüssiger whitespace vor dem Namen entfernen
                # positives Lookahead, matched jegliche Art whitespace vor dem ersten Buchstaben
                sprecherText = re.sub(r'^\s*(?=([a-zA-Z]))', "", bloc)

                # matched alles vor dem ersten Zeilenumbruch, d.h. den Sprechernamen
                if (re.match(r'^.*(?=(\r\n))', sprecherText)):
                    # Name ohne Whitespace aus dem Text herausziehen
                    # group(0) wird benötigt, um auf den Text im Match-Objekt zuzugreifen, das von re.match zurückgegeben wird
                    name = re.match(r'^.*(?=(\r\n))', sprecherText).group(0).strip()

                    # alles vor dem ersten Zeilenumbruch (inkl. Name wird gelöscht)
                    sprecherText = re.sub(r'^.*\r\n', '', sprecherText)
                    sprecherText = sprecherText.strip()
                    sprecherText = re.sub(r'\r\n', '', sprecherText) # Zeilenumbrüche innerhalb des Texts
                    sprecherText = re.sub(r'\s+', ' ', sprecherText) # mehrfache Leerzeichen werden zu einem

                    # write to CSV
                    # only write if name is not empty (otherwise there will be empty rows in between)
                    if(name != ""):
                        f.write(f'{num}|{name}|{sprecherText}|2\n')
                        print(f'{num}|{name}|{sprecherText}|2\n')
                else:
                    f.write(f'{num}|Sprechertext|{sprecherText}|2\n')
                    print(f'{num}|Sprechertext|{sprecherText}|2\n')
                
get_all_lines()
# Out:
# Nr.|Sprecher/Regie|Text|Filmnr.
#
# 0|Sprechertext||2
#
# 2|Sprechertext|THE LORD OF THE RINGS: THE TWO TOWERS|2
#
# 4|Screenplay by|Peter Jackson, Fran Walsh and Philippa Boyens.|2
#
# 6|Based on "The Lord of The Rings" trilogy by|J.R.R Tolkien.|2
#
# 8|Sprechertext|Transcription credits|2
#
# 10|Accela, Aina, Bad burn, Bridget Chubb,|Brionn Equus (Lochrann), Drusilia, Elf Lady, %owyn Unquendor, Feanari, Finafyr, Flourish, Galadriel, Heri, Julamb, JustinsIce(Mdjasrie), Kazren, Krystal, Lady%owynKenobi, Lady Evenstar, Legolas%Bow, Lithorose, Melody, Mormegil, Nilmandra, Padfoot, Penwiper, Pilgrim Grey, Primula Baggins, Randy Savage, Samwise the Brave, Sirius Black, Tethra, The Lidless Eye, Turnar, Xyla, Yaksha|2
#
# 12|Elvish dialogue from The Elvish Linguistic|Fellowship.|2
#
# 14|Sprechertext||2
#
# 16|Regie|[TITLE: THE LORD OF THE RINGS]|2
#
# 18|Sprechertext||2
#
# 20|Regie|[Camera pans over the Misty Mountains as voices drift in from the background.]|2
#
# 22|GANDALF|You cannot pass!|2
#
# 24|FRODO|Gandalf!|2
#
# 26|GANDALF|I am a servant of the Secret Fire, wielder of the Flame of Anor!|2
#
# 28|Regie|[Camera pans closer to the mountain side.]|2
#
# 30|GANDALF|Argh! Go back to the shadow. The Dark Fire will not avail you, Flame of Ud%n! [Camera zooms in through the mountain and focuses on Gandalf and the Balrog on the bridge of Khazad-d%m. The Balrog strikes down on Gandalf with its flaming sword. Gandalf parries the blow with Glamdring, shattering the Balrog%s sword.] YOU% SHALL NOT... PASS!!!|2
#
# 32|Regie|[Gandalf strikes his staff onto the bridge. As the Balrog steps forward, the bridge collapses from under it and the demon plunges backward into the chasm. Gandalf, exhausted, leans on his staff and watches the Balrog fall then turns to follow the others. At the last minute, the flaming whip lashes up from the depths of the abyss and winds around Gandalf%s ankle, dragging him over the edge. He clings onto the bridge but is straining to keep his grip.]|2
#
# 34|GANDALF|Argh!|2
#
# 36|Regie|[Frodo rushes forward but Boromir restrains him.]|2
#
# 38|BOROMIR|No! No!|2
#
# 40|FRODO|Gandalf!|2
#
# 42|GANDALF|Fly, you fools!|2
#
# 44|Regie|[Gandalf loses his grip and falls into the chasm]|2
#
# 46|FRODO|Noooooooooooooooo!!!!|2
#
# 48|Regie|[Gandalf loses his grip and falls into the chasm]|2
#
# 50|FRODO|[Calls after Gandalf as he falls into the abyss] Gaaandaaaaalf!!|2
#
# 52|Regie|[Gandalf falls after the Balrog and grabs hold of his sword Glamdring on his way down. As they continue to plunge into the depths, Gandalf hacks away at the Balrog even as it thrashes and bounces off the walls. They continue to plunge at great speed, sometimes with Gandalf clinging to the horn of the demon. The battling pair then falls into an enormous cavern and plunges into the water. Just then Frodo awakens as if from a nightmare.]|2
#
# 54|FRODO|Gandalf!|2
#
# 56|SAM|What is it, Mr. Frodo?|2
#
# 58|FRODO|Nothing. Just a dream. [Lies back down.]|2
#
# 60|Regie|[Frodo and Sam climbs over the rocky terrain Emyn Muil. They look into the distance at the Mountain of Fire.]|2
#
# 62|SAM|Mordor. The one place in Middle-earth we don%t want to see any closer, and the one place we%re trying to get to. It%s just where we can%t get. Let%s face it, Mr. Frodo, we%re lost. I don%t think Gandalf meant for us to come this way.|2
#
# 64|FRODO|He didn%t mean for a lot of things to happen, Sam... but they did.|2
#
# 66|Regie|[Suddenly Frodo feels and sees the Eye zooming in on him. He gasps and pants as he backs away.]|2
#
# 68|SAM|Mr. Frodo? It%s the Ring, isn%t it?|2
#
# 70|FRODO|It%s getting heavier. [Clutches the Ring by his chest and sits down, still panting. He then fumbles for his water bottle and takes a sip.]|2
#
# 72|FRODO|What food have we got left?|2
#
# 74|SAM|Well, let me see. [He takes out a package of lembas bread from his pack] Oh yes, lovely % Lembas bread. And look! [He digs deeper into his pack] More lembas bread.|2
#
# 76|Regie|[Sam shows another package. He then breaks off a piece and tosses it to Frodo, and munches on a piece himself.]|2
#
# 78|SAM|I don't usually hold with foreign food, but this Elvish stuff, it%s not bad.|2
#
# 80|FRODO|[smiles] Nothing ever dampens your spirits, does it Sam?|2
#
# 82|Regie|[Sam smiles back, and then looks ominously towards Mordor.]|2
#
# 84|SAM|Those rain clouds might.|2
#
# 86|Regie|[They continue trekking through difficult terrain, often huddling underneath their cloaks.]|2
#
# 88|SAM|[Looks around] This looks strangely familiar.|2
#
# 90|FRODO|[Exasperated] It%s because we%ve been here before! We%re going in circles.|2
#
# 92|SAM|Ah! What's that 'orrid stink? I'll warrant there's a nasty bog nearby. Can you smell it?|2
#
# 94|FRODO|Yes. I can smell it. [Drops to a whisper] We%re not alone.|2
#
# 96|Regie|[NIGHTTIME Frodo and Sam are sleeping. A dark shape appears on top of the cliff. The creature Gollum has appeared and is making his way down to the hobbits.]|2
#
# 98|GOLLUM|The thieves! The thieves! The filthy little thieves! Where is it? Where isss it? They stole it from us. My preciousss. [Gollum creeps closer and closer.] Curse them! We hates them! It%s ours, it is... and we wantssss it!|2
#
# 100|Regie|[Gollum reaches out his hand towards the hobbits. Suddenly the hobbits spring up, grab hold of Gollum%s arms and pull him down. Amidst the struggle, Gollum wriggles loose and leaps onto Frodo. As Frodo falls back, the chain and Ring around his neck is revealed and Gollum jumps straight for the Ring. Sam tries to grab at him but is knocked away. Gollum now jumps on top of Frodo and tries to reach for the Ring even as Frodo grabs his hands and tries to push him away. Gollum%s cheeks puff with exertion as he struggles with Frodo, his enormous eyes fixed on the Ring. Sam grabs hold of Gollum again and tears him away from Frodo. Gollum then turns around and bites Sam on the shoulder, wriggles around and clasps his arms around Sam%s neck and legs around his waist in a death grip. Frodo unsheathes Sting and holds it to Gollum's throat.]|2
#
# 102|FRODO|[menacingly] This is Sting. You%ve seen it before, haven%t you... Gollum! Release him or I%ll cut your throat!|2
#
# 104|Regie|[Slowly, Gollum loosens his grip on Sam and as the latter disentangles himself, Gollum wails. In the next scene, Gollum is being dragged with Sam's Elvish rope around his neck, wailing and writhing in pain.]|2
#
# 106|GOLLUM|It burns! It burns us! It freezes! Nasty Elves twisted it. Take it off us!|2
#
# 108|SAM|Quiet you!|2
#
# 110|Regie|[Sam tugs fiercely at the rope. Gollum cries some more and collapses onto his back. Sam turns to Frodo in dismay.]|2
#
# 112|SAM|It%s hopeless! Every Orc in Mordor%s going to hear this racket! Let%s just tie him up and leave him.|2
#
# 114|GOLLUM|No! That would kill us! Kill us!|2
#
# 116|SAM|It%s no more than you deserve!|2
#
# 118|FRODO|Maybe he does deserve to die, but now that I see him, I do pity him.|2
#
# 120|GOLLUM|[Begging] We be nice to them if they be nice to us. Take it off us. We swears to do what you wants. We swears.|2
#
# 122|FRODO|There%s no promise you can make that I can trust.|2
#
# 124|GOLLUM|We swears to serve the master of the preciousss. We swears on... on the precious. *Gollum. Gollum.*|2
#
# 126|FRODO|The Ring is treacherous. It will hold you to your word.|2
#
# 128|GOLLUM|Yes... on the preciousss. On the preciousss.|2
#
# 130|SAM|I don%t believe you! [Gollum backs away, frightened, and climbs onto a boulder] Get down! I said, down!|2
#
# 132|Regie|[Sam jerks strongly at the rope as Gollum tries to get away from him. He crashes onto the ground, choking.]|2
#
# 134|FRODO|Sam!|2
#
# 136|SAM|He%s trying to trick us! We let him go he%ll throttle us in our sleep!|2
#
# 138|Regie|[Gollum lies panting and holding his throat. He backs away, frightened, as Frodo approaches him.]|2
#
# 140|FRODO|You know the way to Mordor?|2
#
# 142|GOLLUM|[nods warily] Yes...|2
#
# 144|FRODO|You%ve been there before?|2
#
# 146|GOLLUM|[nods again] Yes...|2
#
# 148|Regie|[Frodo reaches out and takes the rope noose off Gollum%s neck. Gollum seems surprised and relieved.]|2
#
# 150|FRODO|You will lead us to the Black Gate.|2
#
# 152|Regie|[Gollum scrambles off in the direction of Morannon and the hobbits follow in his wake.]|2
#
# 154|Sprechertext||2
#
# 156|Regie|[A band of Uruk-hai marches across the plain, with two hobbits bound to the backs of two Uruk-hai. Pippin tries to call to Merry, who is unconscious with a gash on his right brow.]|2
#
# 158|PIPPIN|Merry. Merry! [He receives no response.]|2
#
# 160|Regie|[Suddenly, an Uruk-hai puts up his hand and signals a stop.]|2
#
# 162|UGL%K|What is it? What do you smell?|2
#
# 164|MAN-FLESH URUK|[sniffs the air] Man-flesh.|2
#
# 166|PIPPIN|[quietly to himself] Aragorn!|2
#
# 168|UGL%K|They've picked up our trail! Let's move!|2
#
# 170|Regie|[The Uruk-hai quicken their pace. Pippin struggles to reach his Elven brooch with his teeth. He then tears it off his cloak and drops it onto the ground. A foot stomps onto the brooch but it remains unbroken and visible on the grass.]|2
#
# 172|Regie|[Aragorn is lying with his eyes closed and ear pressed to the ground, listening for the sound of footsteps.]|2
#
# 174|ARAGORN|Their pace has quickened. [He looks up.] They must have caught our scent. Hurry! [He runs off.]|2
#
# 176|LEGOLAS|Come on, Gimli! [Looks back at Gimli and then runs after Aragorn]|2
#
# 178|GIMLI|[pauses in his steps and huffs] Three days% and nights% pursuit. No food. No rest. And no sign of our quarry but what bare rock can tell. [Runs after his companions.]|2
#
# 180|Regie|[The Three Hunters run across rocks and plains, with Aragorn in the lead, followed by Legolas and Gimli. From time to time, Legolas looks back to make sure that Gimli is keeping up. Aragorn suddenly bends down to pick up an Elven brooch from the ground.]|2
#
# 182|ARAGORN|Not idly do the leaves of L%rien fall.|2
#
# 184|LEGOLAS|[stops and turns to Aragorn.] They may yet be alive.|2
#
# 186|ARAGORN|Less than a day ahead of us. Come! [Runs off again]|2
#
# 188|Regie|[Gimli stumbles from behind some rocks and rolls to the ground]|2
#
# 190|LEGOLAS|Come, Gimli! We are gaining on them!|2
#
# 192|GIMLI|[Panting] I am wasted on cross-country! We dwarves are natural sprinters! Very dangerous over short distances!|2
#
# 194|Regie|[The trackers come over a hill and pause as they gaze across the plains below.]|2
#
# 196|Sprechertext|                         |2
#
# 198|ARAGORN|Rohan. Home of the horse-lords. There is something strange at work here. Some evil gives speed to these creatures, sets its will against us.|2
#
# 200|Regie|[Legolas runs ahead and looks out to the horizon.]|2
#
# 202|ARAGORN|Legolas, what do your Elf eyes see?|2
#
# 204|LEGOLAS|The Uruks turn northeast. They%re taking the hobbits to Isengard!|2
#
# 206|ARAGORN|Saruman.|2
#
# 208|Sprechertext||2
#
# 210|Regie|[The tower of Orthanc stands amidst the smoking caverns of Isengard. Saruman stands in his chamber, communicating with the Dark Lord through the Palant%r.]|2
#
# 212|SARUMAN (V.O.)|The world is changing. [View changes to the tower of Barad-d%r, with its huge Orc armies on a bridge.] Who now has the strength to stand against the armies of Isengard and Mordor? To stand against the might of Sauron and Saruman and the union of the two towers?|2
#
# 214|Regie|[Camera pans upwards along the height of the tower of Barad-d%r until the flaming Eye is in view.]|2
#
# 216|SARUMAN (V.O.)|Together, my lord Sauron, we shall rule this Middle-earth.|2
#
# 218|Regie|[The trees around Isengard are being ripped down, chopped up and used to feed huge furnaces. The caverns of Isengard glow with the fires of industry, sounds of hammering fill the air and molten iron is poured into casts to forge weapons.]|2
#
# 220|SARUMAN (V.O.)|The old world will burn in the fires of industry. The forests will fall. A new order will rise. We will drive the machine of war with the sword and the spear and the iron fists of the Orc. We have only to remove those who oppose us.|2
#
# 222|Regie|[Saruman stands in the midst of a gathering of Dunlanders.]|2
#
# 224|SARUMAN|The horsemen took your land. They drove your people into the hills to scratch a living off rocks.|2
#
# 226|DUNLAND MAN|Murderers!|2
#
# 228|SARUMAN|Take back the lands they stole from you! Burn every village!|2
#
# 230|CROWD|[Roars with approval] Argh!!|2
#
# 232|Regie|[They stomp off to destroy the villages of Rohan as Saruman stands coldly still among the stampede. A Rohan village is in pandemonium as people try to escape the on-coming pillage.]|2
#
# 234|SARUMAN (V.O.)|It will begin in Rohan. Too long have these peasants stood against you. But no more.|2
#
# 236|Regie|[A woman with her hand on a horse calls out to her children.]|2
#
# 238|MORWEN|%othain! %othain! You take your sister. You%ll go faster with just two.|2
#
# 240|FREDA|[As Morwen puts her onto the horse in front of her brother] Papa says %othain must not ride Garulf, he is too big for him!|2
#
# 242|MORWEN|Listen to me. You must ride to Edoras and raise the alarm. Do you understand me?|2
#
# 244|%OTHAIN|Yes, Ma!|2
#
# 246|FREDA|[starts to cry] I don%t wanna leave! I don't wanna go, Mama!|2
#
# 248|MORWEN|Freda, I will find you there.|2
#
# 250|Regie|[A woman screams]|2
#
# 252|MORWEN|Quickly!|2
#
# 254|Regie|[The children ride off.]|2
#
# 256|MORWEN|[Looks after them] Go child!|2
#
# 258|Regie|[Dunlanders and Uruk-hai enter the village, burning everything in sights as the Rohirrim scream and run in all directions. %othain and Freda weep as they look back from a distance.]|2
#
# 260|SARUMAN (V.O.)|Rohan, my lord, is ready to fall.|2
#
# 262|Regie|[A group of horsemen ride to Edoras. %omer is in the lead, carrying a gravely wounded Th%odred.]|2
#
# 264|Regie|[%owyn runs hastily up the stairs to the Golden Hall and enters a bedchamber. She runs to the bed.]|2
#
# 266|%OWYN|Th%odred!|2
#
# 268|Regie|[Th%odred seems to hear her call but is unable to respond. He has a bloody gash on the side of his head. %omer nods to %owyn in the direction of Th%odred%s torso. %owyn draws back the covers and upon seeing Th%odred%s fatal wound, her lips tighten and eyes close. She looks up to catch %omer%s eye.]|2
#
# 270|Regie|[%omer and %owyn are speaking to Th%oden-king who sits motionless on his throne, wizened, and aged beyond his years.]|2
#
# 272|%OWYN|Your son is badly wounded, my lord.|2
#
# 276|GR%MA|That is a lie! [Appears from the shadows.] Saruman the White has ever been our friend and ally.|2
#
# 278|TH%ODEN|[mumbles feebly] Gr%ma% Gr%ma% [Gr%ma leans down close to the King.]My son...? Gr%ma...?|2
#
# 280|%OMER|Orcs are roaming freely across our lands. Unchecked. Unchallenged. Killing at will. Orcs bearing the white hand of Saruman. [He drops a helmet onto the ground, which topples over to reveal the white hand of Saruman.]|2
#
# 282|GR%MA|Why do you lay these troubles on an already troubled mind. Can you not see? Your uncle is wearied by your malcontent, your war-mongering.|2
#
# 284|%OMER|War-mongering?|2
#
# 286|Regie|[%omer grabs Gr%ma and pins him against a pillar.]|2
#
# 288|%OMER|How long is it since Saruman bought you? What was the promised price, Gr%ma? When all the men are dead you will take your share of the treasure?|2
#
# 290|Regie|[Gr%ma%s eyes flicks to right, watching %owyn as she walks by. %owyn stops to stare back for a moment before departing form the hall. %omer jerks Gr%ma again and clutches his hand around Gr%ma%s jaw.]|2
#
# 292|%OMER|Too long have you watched my sister, too long have you haunted her steps.|2
#
# 294|Regie|[Gr%ma's eyes look to the left and relax as %omer is suddenly pulled off Gr%ma by his thugs.]|2
#
# 296|GR%MA|You see much %omer, Son of %omund. Too much. [The thugs punch %omer n the stomach] You are banished forthwith from the kingdom of Rohan. Under pain of death!|2
#
# 300|Sprechertext||2
#
# 302|Regie|[Uruk-hai and Orcs continue to march across the plains with their hobbit captives, with Aragorn, Legolas, and Gimli hot on their pursuits.]|2
#
# 304|GIMLI|Keep breathing! That%s the key! Breathe! Ho!|2
#
# 306|LEGOLAS|They%ve run as if the very whips of their masters were behind them.|2
#
# 308|Regie|[They continue running over vast distances. The Uruk-hai and Orcs halt at nightfall, many panting with exertion.]|2
#
# 310|MORDOR ORC|We%re not going no further till we%ve had a breather!|2
#
# 312|UGL%K|Get a fire going!|2
#
# 314|Regie|[As the Orcs and Uruk-hai take their rest, Pippin crawls over towards Merry.]|2
#
# 316|PIPPIN|Merry! Merry!|2
#
# 318|MERRY|[opens his eyes] I think... we might have made a mistake leaving the Shire, Pippin.|2
#
# 320|Regie|[A group of Orcs chops down the trees nearby for firewood. Low groans and rumbles start to emerge from the forest.]|2
#
# 322|PIPPIN|What%s making that noise?|2
#
# 324|MERRY|[looks towards the forest] It%s the trees.|2
#
# 326|PIPPIN|What?|2
#
# 328|MERRY|Do you remember the Old Forest? On the borders of Buckland? Folk used to say that there was something in the water that made the trees grow tall... and come alive.|2
#
# 330|PIPPIN|Alive?|2
#
# 332|MERRY|Trees that could whisper. Talk to each other. Even move.|2
#
# 334|MA%HUR|I'm starving. We ain't 'ad nothin' but maggoty bread for three stinkin' days!|2
#
# 336|SNAGA|Yeah. Why can%t we have some meat? [His eyes rest on the hobbits.] What about them? They%re fresh.|2
#
# 338|UGL%K|They are not for eating!|2
#
# 340|GRISHN%KH|What about their legs? They don't need those. Ooh% They look tasty!|2
#
# 342|UGL%K|[Shoves at the Orcs] Get back, scum!|2
#
# 344|Regie|[The other Orcs are getting restless.]|2
#
# 346|MORDOR ORC|Carve them up!|2
#
# 348|SNAGA|[Moves towards the hobbits with his blade drawn] Just a mouth full.|2
#
# 350|UGL%K|No!|2
#
# 352|Regie|[Pippin and Merry recoil in fright. Ugl%k jumps on the Orc and cuts off his head, which bounces off the hobbit's shoulders.]|2
#
# 354|UGL%K|Looks like meat%s back on the menu, boys!!|2
#
# 356|Regie|[The Uruk-hai and Orcs cheer and started tearing into the fresh meat, intestines flying, taking their eyes off the hobbits for a while.]|2
#
# 358|MERRY|Pippin, let%s go.|2
#
# 360|Regie|[Their hands still bound, the hobbits try to crawl away. Suddenly a foot comes down on Merry and Pippin is turned onto his back.]|2
#
# 362|GRISHN%KH|[Brandishing a blade in front of Pippin%s face] Go on, call for help. Squeal! No one%s gonna save you now!|2
#
# 364|Regie|[Suddenly, a spear pierces the Orc's back. Mayhem ensues as Riders of Rohan burst out from their hiding places and ambush the Orcs.]|2
#
# 366|MERRY|Pippin! [Gestures for them to make their escape.]|2
#
# 368|Regie|[The hobbits try to escape from the pandemonium to the forest, dodging bodies and stomping feet. Suddenly Pippin turns onto his face and looks up to a pair of thrashing hooves bearing down on him.]|2
#
# 370|PIPPIN|ARGH!!!|2
#
# 372|Sprechertext||2
#
# 374|Regie|[The Three Hunters are still chasing after the Uruk-hai. It is dawn.]|2
#
# 376|LEGOLAS|[Pauses and looks up] A red sun rises. Blood has been spilled this night.|2
#
# 378|Regie|[Camera pans over the rock and plains, alternating between the band of Uruk-hai and the Three Hunters giving chase. The trackers hear the sound of horses. Aragorn and company hide behind some boulders. A large group of horse-men appears, galloping quickly with their banners flying. Aragorn comes out of hiding as they pass, followed by Legolas and Gimli.]|2
#
# 380|ARAGORN|Riders of Rohan, what news from the Mark?|2
#
# 382|Regie|[At a signal from %omer at the lead, the riders make a quick turn and head towards them, surrounding them in ever-tightening circles. As they stop, they point their long spears menacingly at them.]|2
#
# 384|%OMER|What business does an Elf, a man and a Dwarf have in the Riddermark? Speak quickly!|2
#
# 386|GIMLI|Give me your name, Horsemaster, and I shall give you mine.|2
#
# 388|Regie|[%omer hands his staff to another rider, and gets off his horse. Aragorn puts a hand on Gimli%s shoulder.]|2
#
# 390|%OMER|I would cut off your head, Dwarf, if it stood but a little higher from the ground.|2
#
# 392|Regie|[Legolas, in a lightning fast move, points an arrow at %omer.]|2
#
# 394|LEGOLAS|You would die before your stroke fell!|2
#
# 396|Regie|[The riders all point their spears closer at the travellers. After a tense moment, Aragorn pushes down Legolas% arm.]|2
#
# 398|ARAGORN|I am Aragorn, son of Arathorn. This is Gimli, son of Gl%in and Legolas of the Woodland realm. We are friends of Rohan and of Th%oden, your king.|2
#
# 400|%OMER|Th%oden no longer recognizes friend from foe. [Takes off helmet] Not even his own kin.|2
#
# 402|Regie|[The spears are withdrawn.]|2
#
# 404|%OMER|Saruman has poisoned the mind of the king and claimed lordship over these lands. My company are those loyal to Rohan. And for that, we are banished. The White Wizard is cunning. He walks here and there, they say, as an old man, hooded and cloaked. And everywhere his spies slip past our nets.|2
#
# 406|ARAGORN|We are not spies. We track a party of Uruk-hai westward across the plain. They%ve taken two of our friends captive.|2
#
# 410|GIMLI|But there were two hobbits. Did you see two hobbits with them?|2
#
# 412|ARAGORN|They would be small % only children to your eyes.|2
#
# 414|%OMER|We left none alive. We piled the carcasses and burned them. [Points to a smoking pile in the distance.]|2
#
# 416|GIMLI|Dead?|2
#
# 418|%OMER|[nods] I am sorry.|2
#
# 420|Regie|[Legolas puts a hand on Gimli%s shoulder in grief. %omer turns and whistles.]|2
#
# 424|Regie|[%omer puts on his helmet and gets back on his horse]|2
#
# 426|%OMER|Look for your friends. But do not trust to hope, it has forsaken these lands. [To the riders] We ride north!|2
#
# 428|Regie|[Aragorn, Legolas and Gimli look on as the Riders go off. They then ride towards the burning carcasses. Gimli starts to shift through the smoldering pile, and pulls out a charred belt and dagger sheath.]|2
#
# 430|GIMLI|It%s one of their wee belts.|2
#
# 432|LEGOLAS|[with his head bowed and eyes closed] Hiro %th% ab 'wanath... (May they find peace in death)|2
#
# 434|ARAGORN|[Kicks a helmet and yells] AAARRGGHH!!! [He falls to his knees.]|2
#
# 436|GIMLI|We failed them.|2
#
# 438|Regie|[Aragorn looks to the side as some tracks catch his attention.]|2
#
# 440|ARAGORN|A hobbit lay here, and the other. [Flashback: Pippin yells as he looks up at a pair of thrashing hooves bearing down on him. He rolls over, avoiding the hooves.] They crawled.|2
#
# 442|Regie|[ARAGORN STARTS TO FOLLOW THE TRACKS, WITH LEGOLAS AND GIMLI BEHIND HIM. FLASHBACK Merry and Pippin crawl frantically away from the battle.]|2
#
# 444|ARAGORN|Their hands were bound. [Flashback: Merry rubs his bonds furiously against the sharp edge of a weapon.] Their bonds were cut. [Aragorn holds up a broken length of thick rope.]|2
#
# 446|ARAGORN|They ran over here. They were followed.|2
#
# 448|Regie|[FLASHBACK Their hands freed, the hobbits run away from the battle scene, dodging under a horse and trying to stay out of harms way. As they flee, Grishn%kh grabs Pippin by his belt and clings on.]|2
#
# 450|MERRY|The belt!|2
#
# 452|Regie|[Pippin undoes his belt and Grishn%kh is left holding it.]|2
#
# 454|MERRY|Run!|2
#
# 456|ARAGORN|The tracks lead away from the battle... [They break into a run and then stop] into Fangorn Forest.|2
#
# 458|Regie|[The Three looks up into a dense and dark forest]|2
#
# 460|GIMLI|Fangorn. What madness drove them in there?|2
#
# 462|Sprechertext||2
#
# 464|Regie|[Scene moves from the trackers into the nighttime chase of Merry and Pippin. The hobbits run into the Fangorn, seeking to lose the pursuing Orc. They collapse onto the ground, out of breath.]|2
#
# 466|PIPPIN|Did we lose him? [Looks around] I think we lost him.|2
#
# 468|Regie|[Suddenly, Grishn%kh appears from behind the trees, brandishing a blade.]|2
#
# 470|GRISHN%KH|I%m gonna rip out your filthy little innards! Come here!|2
#
# 472|Regie|[Merry and Pippin run and hide behind a tree.]|2
#
# 474|MERRY|Trees! Climb a tree!|2
#
# 476|Regie|[Pippin and Merry quickly scramble up a tree each.]|2
#
# 478|MERRY|[Looks around and then sighs in relief.] He's gone.|2
#
# 480|Regie|[Suddenly, Merry is pulled by his legs and falls to the ground. Grishn%kh leans over him with his menacing blade. Merry tries to kick him off but to no avail.]|2
#
# 482|PIPPIN|Merry!|2
#
# 484|Regie|[Pippin looks down in horror but as he turns his head, he spots a pair of gleaming yellow eyes blinking in the tree he%s clinging to. The tree starts to move and groan.]|2
#
# 486|TREEBEARD|Hooooo...|2
#
# 488|PIPPIN|Argh!!|2
#
# 490|Regie|[Pippin loses his grip in fright and grabs at the air futilely as he falls. The tree catches him before he hits the ground.]|2
#
# 492|GRISHN%KH|Let%s put a maggot-hole in your belly. [Suddenly he senses something behind him and as he looks up, the tree stomps and squashes him onto the forest floor.]|2
#
# 494|PIPPIN|Run, Merry!|2
#
# 496|Regie|[Merry tries to run away but is scooped by the tree.]|2
#
# 498|TREEBEARD|[Looks at the creatures in his hands] Little Orcs! Bur%rum...|2
#
# 500|PIPPIN|It%s talking, Merry. The tree is talking!|2
#
# 502|TREEBEARD|Tree?! I am no tree. I am an Ent. [Stomps slowly through the forest.]|2
#
# 504|MERRY|A treeherder! A shepherd of the forest.|2
#
# 506|PIPPIN|Don%t talk to it, Merry. Don%t encourage it.|2
#
# 508|TREEBEARD|Treebeard, some call me.|2
#
# 510|PIPPIN|And whose side are you on?|2
#
# 512|TREEBEARD|Side? I am on nobody%s side because nobody%s on my side, little Orc. Nobody cares for the woods anymore.|2
#
# 514|MERRY|We%re not Orcs. We%re Hobbits!|2
#
# 516|TREEBEARD|Hobbits? Never heard of a hobbit before. Sounds like Orc mischief to me! [Tightens his hold on the hobbits and squeezes them. Merry and Pippin whimpers in pain] They come with fire, they come with axes. Gnawing, biting, breaking, hacking, burning! Destroyers and usurpers, curse them!|2
#
# 518|MERRY|No, you don%t understand. We%re Hobbits... Halflings! Shirefolk!|2
#
# 520|TREEBEARD|Maybe you are and maybe you aren%t. The White Wizard will know.|2
#
# 522|PIPPIN|The White Wizard?|2
#
# 524|MERRY|Saruman.|2
#
# 526|Regie|[Treebeard drops them on the ground and the hobbits look up at the White Wizard.]|2
#
# 528|Sprechertext||2
#
# 530|Regie|[Following Gollum, Frodo and Sam reach the end of Emyn Muil and see that Mordor is now closer.]|2
#
# 532|GOLLUM|See, see, we have led you out! Hurry hobbitses hurry. Very lucky we find you.|2
#
# 534|Regie|[Gollum jumps on a rock. Frodo walks past, Gollum shrinks as Sam draws near.]|2
#
# 536|GOLLUM|Nice hobbit. [Leaps after Frodo, putting a wide berth between him and Sam.]|2
#
# 538|Regie|[Sam%s foot slipped into muck.]|2
#
# 540|SAM|Whoa, it%s a bog! He%s led us into a swamp!|2
#
# 542|GOLLUM|A swamp, yes, yes. Come, master. We will take you on safe paths through the mist. Come, hobbits, come. We go quickly.|2
#
# 544|Regie|[Gollum looks back and gestures for the hobbits to follow.]|2
#
# 546|GOLLUM|I found it, I did. The way through the marshes. Orcs don't use it. Orcs don't know it. They go round for miles and miles. Come quickly. Swift and quick as shadows we must be.|2
#
# 548|Regie|[The marsh lands stretch for miles and miles as far as the eye can see. The hobbits and Gollum appear as little specks. As the three pick their way gingerly though the marshes, they see faces floating in the water, still, rotting and pale, and flickering flames on the swamps.]|2
#
# 550|SAM|There are dead things! Dead faces in the water!|2
#
# 552|GOLLUM|All dead. All rotten. Elves and men and orcses. A great battle long ago. [Turns to face the hobbits.] The Dead Marshes. Yes, yes that is their name. This way. Don%t follow the lights.|2
#
# 554|Regie|[Sam%s foot slips again into the water.]|2
#
# 556|SAM|Ohh!|2
#
# 558|GOLLUM|Careful now, or hobbits go down to join the dead ones and light little candles of their own.|2
#
# 560|Regie|[Frodo is drawn to one of the faces in Elven armour. He stares at it intently, until suddenly its eyes open and Frodo falls face-down into the water.]|2
#
# 562|SAM|Frodo!|2
#
# 564|Regie|[Frodo is in the water and sees many faces of the dead, no longer still but screaming and grasping, their rotten robes and hair flowing about their gruesome faces. Their hands are reaching for him. Suddenly he is grabbed from behind. Frodo sputters and gasps for air as Gollum pulls him out of the water.]|2
#
# 566|FRODO|[Looks at Gollum in perplexed gratitude and disbelief.] Gollum...|2
#
# 568|GOLLUM|Don%t follow the lights! [Crawls away]|2
#
# 570|SAM|[Runs to Frodo%s side.] Mr. Frodo! Are you alright?|2
#
# 572|Regie|[Frodo lies panting, staring after Gollum]|2
#
# 574|Sprechertext|                         |2
#
# 576|Regie|[NIGHTFALL Sam is asleep but Frodo is still awake. He is holding the Ring in the palm of his hand and stroking it, mesmerized. Suddenly he hears Gollum.]|2
#
# 578|GOLLUM|Sooo bright. Sooo beautiful. [Frodo quickly puts the Ring back inside his shirt. He looks up to see Gollum crouching away from him, stroking the centre of his palm] our preciousss...|2
#
# 580|FRODO|What did you say?|2
#
# 582|GOLLUM|Master should be resting. Master needs to keep up his strength.|2
#
# 584|FRODO|[Moves over and crouches in front of Gollum] Who are you?|2
#
# 586|GOLLUM|Mustn%t ask us. Not its business. *Gollum, Gollum*|2
#
# 588|FRODO|Gandalf told me you were one of the River Folk.|2
#
# 590|GOLLUM|Cold be heart and hand and bone. Cold be travellers far from home.|2
#
# 592|FRODO|He said your life was a sad story.|2
#
# 594|GOLLUM|They do not see what lies ahead, when sun has failed and moon is dead.|2
#
# 596|FRODO|You were not so very different from a hobbit once, were you... Sm%agol?|2
#
# 598|GOLLUM|[Looks up slowly.] What did you call me?|2
#
# 600|FRODO|That was your name once, wasn%t it? A long time ago.|2
#
# 602|GOLLUM|My name... My name... S... S...Sm%agol%|2
#
# 604|Regie|[Suddenly, the piercing cries of the Nazg%l are heard overhead]|2
#
# 606|GOLLUM|Argh!!|2
#
# 608|SAM|Black Riders!|2
#
# 610|GOLLUM|Hide! Hide!|2
#
# 612|FRODO|Argh!|2
#
# 614|Regie|[Suddenly Frodo feels the pain of the Nazg%l's sword piercing him and the call of the Ring. Images of the Ringwraiths come to him in flashes.]|2
#
# 616|FRODO|Argh!!|2
#
# 618|SAM|C%mon Frodo! C'mon!|2
#
# 620|Regie|[Frodo continues to clutch at the Ring on his chest, immobilized. Sam drags Frodo across to hide beneath some bramble bushes. The Nazg%l appears, tightening his hold on the reins. Camera then shows him riding a Fell Beast, swooping down across the marsh lands. Chilling screams of the Nazg%l fill the air.]|2
#
# 622|GOLLUM|Quick! They will see us! They will see us!|2
#
# 624|SAM|I thought they were dead!|2
#
# 626|GOLLUM|Dead? No, you cannot kill them. No.|2
#
# 628|Regie|[A loud screech from the Nazg%l flying high above the marshes.]|2
#
# 630|GOLLUM|[cowering] Wraiths! Wraiths on wings! They are calling for it. They are calling for the preciousss.|2
#
# 632|Regie|[Frodo feels the call of the Ring and gropes for his necklace. Sam sees this and grabs hold of Frodo%s hand.]|2
#
# 634|SAM|Mr. Frodo! It%s alright. I%m here.|2
#
# 636|Regie|[The Nazg%l continues to circle overhead and then flies off towards Mordor.]|2
#
# 638|GOLLUM|Hurry, hobbits. The Black Gate is very close.|2
#
# 640|Sprechertext||2
#
# 642|Regie|[Scene returns to Fangorn forest. Gimli fingers a dark stain on a leaf and brings it to his mouth.]|2
#
# 644|GIMLI|[Spits] Ptui! Orc blood.|2
#
# 646|ARAGORN|These are strange tracks.|2
#
# 648|GIMLI|The air is so close in here.|2
#
# 650|LEGOLAS|This forest is old. Very old. Full of memory... and anger.|2
#
# 652|Regie|[Groans reverberate through the forest and Gimli raises his axe.]|2
#
# 654|LEGOLAS|The trees are speaking to each other.|2
#
# 656|ARAGORN|[Whispers] Gimli!|2
#
# 658|GIMLI|Huh?|2
#
# 660|ARAGORN|[Gestures] Lower your axe.|2
#
# 662|GIMLI|[Lowering his axe slowly] Oh.|2
#
# 664|LEGOLAS|Aragorn, nad n% ennas! (Something is out there.)|2
#
# 666|ARAGORN|Man cenich? (What do you see?)|2
#
# 668|Regie|[Close-up of Legolas% eyes]|2
#
# 670|LEGOLAS|The White Wizard approaches.|2
#
# 672|ARAGORN|Do not let him speak. He will put a spell on us.|2
#
# 674|Regie|[Aragorn wraps his hand around the hilt of his sword, Gimli tightens his hold on his axes, and Legolas notches an arrow to his bow.]|2
#
# 676|ARAGORN|We must be quick.|2
#
# 678|Regie|[With a yell, the three swing round to attack. Gimli%s axe and Legolas% arrow are deflected. Aragorn drops his sword as it becomes red hot in his grasp. They shield their eyes with their hands from the bright light emanating from the White Wizard.]|2
#
# 680|WHITE WIZARD|You are tracking the footsteps of two young hobbits.|2
#
# 682|ARAGORN|Where are they?|2
#
# 684|WHITE WIZARD|They passed this way the day before yesterday. They met someone they did not expect. Does that comfort you?|2
#
# 686|ARAGORN|Who are you? Show yourself!|2
#
# 688|Regie|[The bright light dims, revealing Gandalf, all dressed in white. The three are astounded. Legolas and Gimli bow.]|2
#
# 690|ARAGORN|It cannot be. You fell.|2
#
# 692|GANDALF|Through fire and water. [Flashback: Gandalf is battling the Balrog atop D%rin%s Tower.] From the lowest dungeon to the highest peak, I fought with the Balrog of Morgoth.|2
#
# 694|Regie|[Gandalf holds up Glamdring and a flash of lightning strikes it before he plunges the sword into the Balrog. With a final cry, the Balrog falls from the peak and lands, smoking, onto the icy mountainside.]|2
#
# 696|GANDALF|Until at last, I threw down my enemy and smote his ruin upon the mountainside.|2
#
# 698|Regie|[On top of the mountain, Gandalf crawls a bit and then collapses.]|2
#
# 700|GANDALF|Darkness took me. And I strayed out of thought and time. [Camera zooms in Gandalf%s eye and enters an amorphous realm of stars and galaxies, ending in a blinding white light] Stars wheeled overhead and everyday was as long as a life-age of the earth. But it was not the end. I felt life in me again.|2
#
# 702|Regie|[Camera zooms out from Gandalf%s eye, lying naked and very still. His hair has turned white and wounds are completely healed. He suddenly shudders with a deep gasp and pants as life returns to him]|2
#
# 704|GANDALF|I've been sent back until my task is done.|2
#
# 706|ARAGORN|Gandalf!|2
#
# 708|GANDALF|Gandalf? Yes... That's what they used to call me. Gandalf the Grey. That was my name. [He smiles]|2
#
# 710|GIMLI|Gandalf!|2
#
# 712|GANDALF|[With a twinkle in his eye] I am Gandalf the White. [Aragorn grins] And I come back to you now at the turn of the tide.|2
#
# 714|Regie|[They walk through the forest, with Gandalf leading the way, now wearing a grey cloak over his white robes.]|2
#
# 716|GANDALF|One stage of your journey is over, another begins. War has come to Rohan. We must ride to Edoras with all speed.|2
#
# 718|Regie|[Outside the forest, Gandalf whistles piercingly. Soon an answering neigh is heard and a white horse appears from the plain, answering the call.]|2
#
# 720|LEGOLAS|That is one of the Mearas, unless my eyes are cheated by some spell.|2
#
# 722|Regie|[The horse comes round to stop in front of Gandalf.]|2
#
# 724|GANDALF|Shadowfax. [Gimli bows in the background.] He's the lord of all horses and he's been my friend through many dangers.|2
#
# 726|Regie|[The Three Hunters and Gandalf ride across the plains to Edoras.]|2
#
# 728|Sprechertext||2
#
# 730|Regie|[Back at Fangorn, Treebeard is walking through the forest with Merry and Pippin sitting on his shoulders.]|2
#
# 732|TREEBEARD|My home lies deep in the forest near the roots of the mountain. I told Gandalf I would keep you safe and safe is where I%ll keep you. The trees have grown wild and dangerous. Anger festers in their hearts. They will harm you if they can. There are too few of us now. Too few of us Ents left to manage them.|2
#
# 734|Sprechertext|                         |2
#
# 736|Regie|[Frodo and Sam are climbing a high rock overlooking Morannon.]|2
#
# 738|GOLLUM|The Black Gate of Mordor.|2
#
# 740|Regie|[The enormous Black Gate comes into view with Orcs patrolling and standing guard on the towers and atop the walls. From the right, an army of Easterling soldiers is marching to the Black Gate.]|2
#
# 742|SAM|Oh save us. My ol' Gaffer'd have a thing or two to say if he could see us now.|2
#
# 744|GOLLUM|Master says to show him the way into Mordor, so good Sm%agol does. Master says so.|2
#
# 746|FRODO|I did.|2
#
# 748|Regie|[Orcs are patrolling the Black Gate.]|2
#
# 750|SAM|That%s it then. We cannot get past that.|2
#
# 752|Regie|[A command is heard and an Orc sounds a horn, signalling for the Gate to be opened. Two enormous cave trolls stretch and growl and then pull the mighty Gate open.]|2
#
# 754|SAM|Look! The gate, it's opening! I can see a way down.|2
#
# 756|Regie|[He moves closer to the edge. Suddenly, the rock underneath him gives way and he falls.]|2
#
# 758|FRODO|Sam, no!|2
#
# 760|SAM|Argh!!|2
#
# 762|Regie|[Frodo goes after Sam.]|2
#
# 764|GOLLUM|Master!|2
#
# 766|Regie|[Two Easterling soldiers see streams of dust coming down the cliff made by Sam and Frodo. They move away from the troop to investigate. Frodo reaches Sam who is stuck in the scree. As the Easterlings move closer and closer, Frodo throws his Elvish cloak over himself and Sam. The soldiers are now directly in front of Sam, but their eyes see nothing but rock. Frodo and Sam peer from underneath the cloak. The soldiers soon leave and after a moment, Frodo throws back the cloak and pulls Sam out.]|2
#
# 768|FRODO|I do not ask you to come with me, Sam.|2
#
# 770|SAM|I know, Mr Frodo. I doubt even these Elvish cloaks will hide us in there.|2
#
# 772|Regie|[They prepare to make a run for the Gate.]|2
#
# 774|FRODO|Now!|2
#
# 776|Regie|[Gollum pulls them back.]|2
#
# 778|GOLLUM|No! No, no master! They catch you! They catch you! Don%t take it to him! He wants the preciousss. Always he%s looking for it! And the preciousss is wanting to go back to him. But we mustn%t let him have it.|2
#
# 780|Regie|[Frodo tries to make a run for it.]|2
#
# 782|GOLLUM|No! [Pulls Frodo back again.] There%s another way. More secret. A dark way.|2
#
# 784|SAM|Why haven%t you spoken of this before?!|2
#
# 786|GOLLUM|Because Master did not ask!|2
#
# 788|SAM|He%s up to something.|2
#
# 790|FRODO|Are you saying there%s another way into Mordor?|2
#
# 792|GOLLUM|Yes. There is a path, and some stairs, and then% a tunnel. [Frodo and Sam watch as the Black Gate closes. Gollum is stroking Frodo%s arm and burying his face in his cloak.]|2
#
# 794|FRODO|He%s led us this far, Sam.|2
#
# 796|SAM|Mr. Frodo, no.|2
#
# 798|FRODO|He%s been true to his word.|2
#
# 800|SAM|[Whispers] No!|2
#
# 802|FRODO|Lead the way, Sm%agol.|2
#
# 804|GOLLUM|Good Sm%agol always helps.|2
#
# 806|Regie|[Frodo follows Gollum as Sam stares after him in disbelief.]|2
#
# 808|Regie|[On the plains of Rohan. Gandalf, Aragorn, Legolas and Gimli stop as Edoras comes into view.]|2
#
# 810|GANDALF|Edoras and the Golden Hall of Meduseld. There dwells Th%oden, King of Rohan, whose mind is overthrown. Saruman%s hold over King Th%oden is now very strong.|2
#
# 812|Regie|[In the Hall, %owyn is kneeling before Th%oden, holding his hand in hers.]|2
#
# 816|Regie|[Th%oden just sits and stares ahead, his eyes clouded and unseeing.]|2
#
# 818|%OWYN|Will you not go to him? [She weeps.] Will you do nothing?|2
#
# 820|Regie|[Scene returns to Gandalf and company.]|2
#
# 822|GANDALF|Be careful what you say. Do not look for welcome here.|2
#
# 824|Regie|[They ride on towards Edoras.]|2
#
# 826|Sprechertext||2
#
# 828|Regie|[At Edoras, %owyn is weeping at the dead Th%odred's bed. She kisses his hand. Gr%ma appears at the door.]|2
#
# 830|GR%MA|Oh, he% he must have died sometime in the night. What a tragedy for the king to lose his only son and heir.|2
#
# 832|Regie|[He sits on the bed and puts a hand on %owyn%s shoulder.]|2
#
# 834|GR%MA|I understand his passing is hard to accept, especially now that your brother has deserted you.|2
#
# 836|%OWYN|[jumps back and throws off Gr%ma%s hand] Leave me alone, snake!|2
#
# 838|GR%MA|[Rises from the bed and moves ever closer to %owyn] Oh, but you are alone! Who knows what you have spoken to the darkness. In bitter watches of the night, when all your life seems to shrink, the walls of your bower closing in about you, like a hutch to trammel some wild thing in.|2
#
# 840|Regie|[He puts a hand on her cheek and moves down to her throat.]|2
#
# 842|GR%MA|So fair, so cold, like a morning of pale spring still clinging to winter's chill.|2
#
# 844|Regie|[%owyn and Gr%ma stare at each other intently.]|2
#
# 846|%OWYN|Your words are poison!|2
#
# 848|Regie|[%owyn runs out of the hall. Weeping, she looks away into the distance. A flag comes off its pole and is carried by the breeze. %owyn sees riders coming towards Edoras. As Aragorn passes the entrance to Edoras, the flag floats down to land near him. Edoras is silent and somber. Everyone is dressed in black and staring at the newcomers in wary silence. Aragorn looks up at the hall and sees a lady in white standing on the steps. He looks around at more somber people.]|2
#
# 850|GIMLI|You%ll find more cheer in a graveyard.|2
#
# 852|Regie|[Aragorn looks up to the hall again but the lady has disappeared. The company climbs up the stairs to the hall and is met by guards.]|2
#
# 854|GANDALF|[sees H%ma] Ah.|2
#
# 856|H%MA|I cannot allow you before Th%oden-King so armed, Gandalf Greyhame. By order of Gr%ma Wormtongue.|2
#
# 858|Regie|[Gandalf nods in understanding and signals for the others to surrender their weapons. Aragon hands over his sword and knives. Legolas gives a little twirl to his knives before handing them over to the guards. Gimli hands over his axes reluctantly.]|2
#
# 860|H%MA|[gestures to Gandalf] Your staff.|2
#
# 862|GANDALF|Hmm? [Glances at his staff.] Oh. You would not part an old man from his walking stick? [Looks at H%ma innocently.]|2
#
# 864|Regie|[H%ma hesitates for a second and then gestures that they follow him into the hall. Gandalf gives Aragorn a tiny wink and enters the hall, leaning on Legolas% arm.]|2
#
# 866|GR%MA|[Leaning down and whispering to Th%oden.] My lord, Gandalf the Grey is coming. He%s a herald of woe.|2
#
# 868|GANDALF|The courtesy of your hall is somewhat lessened of late, Th%oden King.|2
#
# 870|Regie|[As Gandalf approaches Th%oden, Aragorn, Legolas and Gimli pull back and survey the hall and its hostile occupants. A group of men starts to follow their steps with hostility.]|2
#
# 872|GR%MA|[Whispering to Th%oden.] He%s not welcome.|2
#
# 874|TH%ODEN|Why should I% welcome you, Gandalf% Stormcrow? [Looks to Gr%ma for affirmation.]|2
#
# 876|GR%MA|A just question, my liege. [He walks towards Gandalf.] Late is the hour in which this conjurer chooses to appear. Lathspell spell I name him. Ill news is an ill guest.|2
#
# 878|GANDALF|Be silent! Keep your forked tongue behind you teeth. I have not passed through fire and death to bandy crooked words with a witless worm! [Raises his staff against Gr%ma.]|2
#
# 880|GR%MA|His staff! [Backing away from Gandalf while addressing the guards] I told you to take the wizard%s staff!|2
#
# 882|Regie|[The hostile guards attack. Aragorn, Legolas and Gimli engage them in a fist-fight as Gandalf continues to approach Th%oden. Gamling tries to go forward but H%ma holds him back.]|2
#
# 884|GANDALF|Th%oden, son of Thengel, too long have you sat in the shadows.|2
#
# 886|Regie|[Gr%ma tries to crawl away unnoticed, but Gimli catches him and pins him to the floor.]|2
#
# 888|GIMLI|[Growls] I would stay still, if I were you.|2
#
# 890|GANDALF|Hearken to me! I release you from the spell. [Gestures with his hand]|2
#
# 892|TH%ODEN|[Menacingly] Hahahhhahahahah! [Gandalf opens his eyes in surprise.] You have no power here, Gandalf the Grey!|2
#
# 894|Regie|[Gandalf throws back his grey cloak, exuding blinding white light. Th%oden is thrown back against his seat.]|2
#
# 896|TH%ODEN|Argh!|2
#
# 898|GANDALF|[Points his staff towards Th%oden.] I will draw you, Saruman, as poison is drawn from a wound.|2
#
# 900|Regie|[%owyn rushes in. Seeing her uncle threatened, she tries to go to him but is held back by Aragorn.]|2
#
# 902|ARAGORN|Wait.|2
#
# 904|TH%ODEN|[In Saruman%s voice.] If I go. . . Th%oden dies.|2
#
# 906|Regie|[Gandalf moves his staff sharply and Th%oden flies back against the chair again.]|2
#
# 908|GANDALF|You did not kill me, you will not kill him!|2
#
# 910|TH%ODEN|[in Saruman's voice] Rohan is mine!|2
#
# 912|GANDALF|Be gone!!|2
#
# 914|Regie|[Gandalf smites Th%oden as he lunges at him. Th%oden is thrown back into the chair and the shot changes to Saruman flying backwards from the Palant%r which he used to manipulate Th%oden. He lands landing hard on the floor of Orthanc, bleeding from a gash in his forehead. In the hall, Th%oden lets out a moan and slumps forward in the chair. %owyn runs to her uncle%s side as he falls. Th%oden%s head rises again and his face begins to change gradually into that of a much younger-looking man. Clarity and recognition returns to his eyes.]|2
#
# 916|TH%ODEN|[Looks closely at %owyn] I know your face. %owyn% %owyn.|2
#
# 918|Regie|[%owyn weeps with joy]|2
#
# 920|TH%ODEN|Gandalf?|2
#
# 922|GANDALF|Breathe the free air again, my friend.|2
#
# 924|Regie|[The hall is shown to be filled with light again, as everyone marvels at the rejuvenation of the king.]|2
#
# 926|TH%ODEN|[Standing up and looking around him.] Dark have been my dreams of late. [He looks down at his trembling hands.]|2
#
# 928|GANDALF|Your fingers would remember their old strength better... if they grasped your sword.|2
#
# 930|Regie|[H%ma runs up with his sword. Th%oden reaches for it with trembling hands. He wraps his fingers around it slowly and then draws it, gazing upon the shiny steel. In a corner, Gr%ma trembles and tries to escape but is pulled back by Gimli. Suddenly, Th%oden%s gaze turns to Gr%ma. Gr%ma is thrown out of the hall and down the stairs.]|2
#
# 932|GR%MA|Argh! [Beseechingly to Th%oden] I've only ever served you, my lord!|2
#
# 934|TH%ODEN|[Advancing towards Gr%ma, holding the sword firmly in his hand] Your leechcraft would have had me crawling on all fours like a beast!|2
#
# 936|GR%MA|[Grovelling] Send me not from your side.|2
#
# 938|Regie|[Th%oden raises his sword to kill Gr%ma. Aragorn holds him back.]|2
#
# 940|ARAGORN|No, my lord! No, my lord. Let him go. Enough blood has been spilled on his account.|2
#
# 942|Regie|[Gr%ma scrambles to his feet and pushes through the crowd]|2
#
# 944|GR%MA|Get out of my way!|2
#
# 946|H%MA|Hail, Th%oden king!|2
#
# 948|Regie|[The crowd kneels in homage before Th%oden. Aragorn kneels also. Gr%ma rides out of Edoras. As Th%oden turns to go back into the hall, he looks up.]|2
#
# 950|TH%ODEN|Where is Th%odred? Where is my son?|2
#
# 952|Sprechertext|                         |2
#
# 954|Regie|[A white flower comes into view, held up by a hand. It is released and spirals down to land among similar flowers, in front of a tomb.]|2
#
# 956|TH%ODEN|Simbelmyn%. Ever has it grown on the tombs of my forebearers. [Looks at Gandalf] Now it shall cover the grave of my son. Alas, that these evil days should be mine. The young perish and the old linger. That I should live to see the last days of my house.|2
#
# 958|GANDALF|Th%odred%s death was not of your making.|2
#
# 960|TH%ODEN|No parent should have to bury their child.|2
#
# 962|Regie|[Th%oden starts to weep]|2
#
# 964|GANDALF|He was strong in life. His spirit will find its way to the halls of your fathers. Westu h%l. Fer%u, Th%odred, Fer%u. (Be-thou well. Go-thou, Th%odred, go-thou.)|2
#
# 966|Regie|[Gandalf turns to go back to the hall and leaves Th%oden to grieve in private. He spots two children on horseback. The boy collapses and falls off the horse. Later, inside the Golden Hall, the two children are eating at a table, and %owyn is with them.]|2
#
# 968|%OWYN|They had no warning. They were unarmed. Now the wildmen are moving through the Westfold, burning as they go. Rick, cot and tree.|2
#
# 970|FREDA|Where%s mama?|2
#
# 972|%OWYN|Shh...|2
#
# 974|GANDALF|This is but a taste of the terror that Saruman will unleash. All the more potent for he is driven now by fear of Sauron. Ride out and meet him head on. Draw him away from your women and children. [Leans forward and puts a hand on Th%oden%s chair. Th%oden looks at his hand warily.] You must fight.|2
#
# 976|ARAGORN|You have two thousand good men riding north as we speak. %omer is loyal to you. His men will return and fight for their king.|2
#
# 978|TH%ODEN|They will be three hundred leagues from here by now. %omer cannot help us. I know what it is that you want of me. But I will not bring further death to my people. I will not risk open war.|2
#
# 980|Regie|[Gimli takes a bite of his bread as he watches the exchange between Aragorn and Th%oden.]|2
#
# 982|ARAGORN|Open war is upon you. Whether you would risk it or not.|2
#
# 984|TH%ODEN|When last I looked, Th%oden, not Aragorn, was king of Rohan.|2
#
# 986|Regie|[Gimli takes a drink and burps.]|2
#
# 988|GANDALF|Then what is the king%s decision?|2
#
# 990|Regie|[Scene shifts to outside Meduseld]|2
#
# ...
#
# 2150|SOLDIER|Hold fast the gate!]|2
#
# 2152|TH%ODEN|[Through a crack in the gate] Gimli! Aragorn! Get out of there!|2
#
# 2154|Regie|[Legolas calls to them from the top of the battlements]|2
#
# 2156|LEGOLAS|Aragorn! [He throws them a rope]|2
#
# 2158|Regie|[Aragorn grabs Gimli in one hand and the rope with the other as they are pulled up the wall. Just then the Uruk-hai load and fires enormous hooks over the battlements. Hundred of Uruk-hai climb onto super-ladders as they are pulled up towards the walls, the super-ladders locking onto the edge of the battlements with their steel grips. Legolas takes aim as another super-ladder is being pulled up and shoots away one of the ropes. The ladder falls back onto the Uruk-hai army.]|2
#
# 2160|TH%ODEN|Pull everybody back! Pull them back!|2
#
# 2162|GAMLING|Fall back! Fall back!|2
#
# 2164|TH%ODEN|They%ve broken through! The castle is breached. Retreat!|2
#
# 2166|GAMLING|Fall back!|2
#
# 2168|TH%ODEN|Retreat!|2
#
# 2170|ARAGORN|Hurry! Inside! Get them inside!|2
#
# 2172|GAMLING|Into the Keep!|2
#
# 2174|Regie|[They all run towards the keep, Legolas firing two arrows into the Uruk-hai army as he goes.]|2
#
# 2176|Sprechertext||2
#
# 2178|Regie|[Treebeard is walking through the forest, carrying Merry and Pippin. The hobbits look dejected.]|2
#
# 2180|TREEBEARD|I will leave you at the western borders of the forest. You can make your way north to your homeland from there.|2
#
# 2182|Regie|[Pippin suddenly looks up with a gleam in his eyes.]|2
#
# 2184|PIPPIN|Wait! Stop! Stop! [Treebeard comes to a stop.] Turn around. Turn around. Take us south!|2
#
# 2186|TREEBEARD|South? But that will lead you past Isengard.|2
#
# 2188|PIPPIN|Yes. Exactly. If we go south we can slip past Saruman unnoticed. The closer we are to danger, the farther we are from harm. It%s the last thing he%ll expect.|2
#
# 2190|TREEBEARD|Mmmm. That doesn%t make sense to me. But then, you are very small. Perhaps you%re right. South it is then. Hold on, little Shirelings. I always like going south. Somehow it feels like going down hill.|2
#
# 2192|MERRY|Are you mad? We%ll be caught!|2
#
# 2194|PIPPIN|No we won%t. Not this time.|2
#
# 2196|Sprechertext||2
#
# 2198|Regie|[Faramir and company draws close to Osgiliath.]|2
#
# 2200|RANGER 1|Look! Osgiliath burns!|2
#
# 2202|RANGER 2|Mordor has come.|2
#
# 2204|FRODO|[With tears in his eyes] The Ring will not save Gondor. It has only the power to destroy. Please, let me go.|2
#
# 2206|Regie|[Faramir hesitates for a moment.]|2
#
# 2208|FARAMIR|Hurry. [He presses them on]|2
#
# 2210|FRODO|Faramir, you must let me go!|2
#
# 2212|Regie|[Frodo and Sam are pushed on towards Osgiliath]|2
#
# 2214|Sprechertext||2
#
# 2216|Regie|[Treebeard, Merry and Pippin come to the southern edge of the forest.]|2
#
# 2218|TREEBEARD|And a little family of field mice that climb up sometimes and they tickle me awfully. They%re always trying to get somewhere where they % Oh!! [He sees the desolated landscape of tree stumps that used to be forested grounds] Many of these trees were my friends. Creatures I had known from nut and acorn.|2
#
# 2220|PIPPIN|I%m sorry, Treebeard.|2
#
# 2222|TREEBEARD|[With tears in his eyes] They had voices of their own. [His gaze turns to the treeless Isengard and its smoking caverns] Saruman! A wizard should know better!|2
#
# 2224|Regie|[He lets out a ferocious roar that echoes through the forest]|2
#
# 2226|TREEBEARD|There is no curse in Elvish, Entish or the tongues of men for this treachery. My business is with Isengard tonight. With rock and stone!|2
#
# 2228|Regie|[Merry and Pippin turn around as they hear rumbles from the forest. They see many Ents emerging and marching towards them]|2
#
# 2230|MERRY|Yes!|2
#
# 2232|TREEBEARD|Hoorarooom... Come my friends. The Ents are going to war. It is likely that we go to our doom. Last march of the Ents!|2
#
# 2234|Sprechertext||2
#
# 2236|Regie|[Osgiliath is still under siege as Faramir and company arrives, dodging arrows and falling rocks.]|2
#
# 2238|MADRIL|Faramir, Orcs have taken the eastern shore. Their numbers are too great. By nightfall we%ll be overrun.|2
#
# 2240|Regie|[Frodo suddenly seems stricken]|2
#
# 2242|SAM|Mr Frodo!|2
#
# 2244|FRODO|It%s calling to him, Sam. His eye is almost on me.|2
#
# 2246|SAM|Hold on, Mr. Frodo% You'll be alright...|2
#
# 2248|Regie|[Frodo sees that Sam is speaking to him but he hears nothing. His senses are overcome.]|2
#
# 2250|FARAMIR|Take them to my father. Tell him Faramir sends a mighty gift. A weapon that will change our fortunes in this war.|2
#
# 2252|Regie|[Sam breaks away as they are being led away.]|2
#
# 2254|SAM|Do you want to know what happened to Boromir? You want to know why your brother died? He tried to take the Ring from Frodo! After swearing an oath to protect him, he tried to kill him! The Ring drove your brother mad!|2
#
# 2256|RANGER|Watch out!|2
#
# 2258|Regie|[A boulder crashes into a tower overhead and shatters it. Suddenly, Frodo%s eyes roll up and he stares at Faramir strangely.]|2
#
# 2260|SAM|Mr Frodo?|2
#
# 2262|FRODO|[In a faraway voice] They%re here. They%ve come.|2
#
# 2264|FARAMIR|[Looking up] NAZG%L!! [He grabs the hobbits and thrusts them into a corner.] Stay here. Keep out of sight. [To his men] Take cover!|2
#
# 2266|Sprechertext||2
#
# 2268|Regie|[Banners of the White Hand are flying from the battlements of Helm%s Deep. The Hornburg is overrun with Uruk-hai. Th%oden and company are in the hall of the keep.]|2
#
# 2270|TH%ODEN|The fortress is taken. It is over.|2
#
# 2272|ARAGORN|[Carrying a table with Legolas to shore up the door of the hall] You said this fortress would never fall while your men defend it! They still defend it! They have died defending it!|2
#
# 2274|Regie|[In the Glittering Caves, the women and children cry in fear as they hear the battering ram banging on the door.]|2
#
# 2276|WOMAN|They are breaking in!|2
#
# 2278|ARAGORN|Is there no other way for the women and children to get out of the caves? [There is no answer.] Is there no other way?|2
#
# 2280|GAMLING|There is one passage. It leads into the mountains. But they will not get far. The Uruk-hai are too many.|2
#
# 2282|ARAGORN|Send word for the women and children to make for the mountain pass. And barricade the entrance.|2
#
# 2284|TH%ODEN|So much death. What can men do against such reckless hate?|2
#
# 2286|ARAGORN|[Pause] Ride out with me. Ride out and meet them.|2
#
# 2288|TH%ODEN|[A light of determination shines in his eyes] For death and glory.|2
#
# 2290|ARAGORN|For Rohan. For your people.|2
#
# 2292|GIMLI|The sun is rising.|2
#
# 2294|Regie|[Aragorn looks up at a window to see faint light streaming through. He recalls Gandalf's words.]|2
#
# 2296|GANDALF (V.O.)|Look to my coming at first light on the fifth day. At dawn, look to the east.|2
#
# 2298|TH%ODEN|Yes. Yes! The horn of Helm Hammerhand shall sound in the deep one last time!|2
#
# 2300|GIMLI|Yes! [Gimli runs up the steps to the horn of Helm Hammerhand]|2
#
# 2302|TH%ODEN|Let this be the hour when we draw swords together. Fell deeds awake. Now for wrath! Now for ruin! And a red dawn!|2
#
# 2304|Regie|[He mounts his horse and puts on his helmet. The sound of the horn rumbles through Helm's Deep as Gimli blows with gusto.]|2
#
# 2306|TH%ODEN|FORTH EORLINGAS!!|2
#
# 2308|Regie|[Th%oden leads the charge out of the keep into the Hornburg, slashing away at the Uruk-hai as they go. Without pause, they storm out of the gate and down the Causeway, right into the column of waiting Uruk-hai. In the midst of battle, Aragorn looks east and sees a white rider against the rising sun]|2
#
# 2310|ARAGORN|Gandalf.|2
#
# 2312|GANDALF|Th%oden king stands alone.|2
#
# 2314|%OMER|[Coming up from behind] Not alone. [He raises a hand] Rohirrim!!|2
#
# 2316|Regie|[Riders move up behind %omer.]|2
#
# 2318|TH%ODEN|[Looking to the east] %omer!|2
#
# 2320|%OMER|To the king!|2
#
# 2322|Regie|[The Rohirrim and the White Rider charge down the slope. Half the Uruk-hai army turns to face the challenge, bearing their spears down towards the riders. As the riders draw closer, the sun rises behind them, momentarily blinding the Uruk-hai who raise the hands (and spears) to shield their eyes. The riders crash right into the Uruk-hai and engage them in battle.]|2
#
# 2324|Sprechertext||2
#
# 2326|Regie|[The Ents are stomping over Isengard, swinging their huge limbs, throwing and stamping on Orcs and rolling huge boulders over the ground. An Ent is pulled down with chains by some Orcs, who immediately jump on and hacks away at his wooden limbs. Saruman rushes out onto the balcony of Orthanc and stares at the pandemonium in incredulity. Merry and Pippin also throws stones at Orcs, their aims true.]|2
#
# 2328|PIPPIN|Yes!|2
#
# 2330|TREEBEARD|A hit. A fine hit!|2
#
# 2332|Regie|[Two Ents rock a wooden structure and push it over into the caverns below, smashing against the rock. Some Orcs fire flamed-tipped arrows at an Ent, setting him on fire. Saruman continues to look about from his balcony, helpless. Some Ents are now breaking away at a dam.]|2
#
# 2334|TREEBEARD|Break the dam! Release the river!|2
#
# 2336|Regie|[The dam is broken and Saruman looks up to see the river rushing down the slope towards Isengard, washing away Orcs and wooden structures in its path. ]|2
#
# 2338|MERRY|Pippin, hold on! [The hobbits tighten their hold on top of Treebeard]|2
#
# 2340|TREEBEARD|Hold on, little hobbits!|2
#
# 2342|Regie|[Treebeard braces himself against the flood. As the water rushes over Isengard, an Ent rushes in and thrusts his burning body into the water. The water rushes into the caverns, washing away the bridges, mechanisms and structures within.]|2
#
# 2344|Sprechertext|                         |2
#
# 2346|Regie|[Frodo walks slowly away from the safe corner. Gondorian Rangers are still running about, defending their stations.]|2
#
# 2348|SAM|What are you doing? Where are you going?!|2
#
# 2350|Regie|[SLOW MOTION Frodo walks up some stairs and stands on a bridge. A Nazg%l on a Fell beast emerges in front of him. Frodo stares at the Nazg%l, fixated. Feeling the call of the Ring, he holds it up. Faramir watches the unfolding tableau from below. As Frodo moves to put the Ring on his finger and the Nazg%l flies closer and closer, Sam runs up and knocks Frodo over. Faramir releases an arrow and shoots the Fell Beast. Frodo and Sam roll down the stairs. As they come to a stop at the bottom, Frodo holds Sam in a death grip, yells and points Sting at his throat, his eyes livid with madness and anger that someone would try to take the Ring away.]|2
#
# 2352|FRODO|Aaarrgghh!!!|2
#
# 2354|SAM|[With tears running down his face] It%s me. It%s your Sam. Don%t you know your Sam?|2
#
# 2356|Regie|[The madness fades and recognition returns to Frodo%s eyes. He realises what he nearly did and is overcome. Stumbling backwards, he collapses against a wall and Sting falls to the ground with a clang. Sam gets up slowly.]|2
#
# 2358|FRODO|[Slowly and with despair] I can%t do this, Sam.|2
#
# 2360|SAM|[Getting up slowly] I know. It%s all wrong. By rights we shouldn%t even be here. But we are. [He stands and leans against a wall, looking out into the distance.] It%s like in the great stories, Mr. Frodo. The ones that really mattered. Full of darkness and danger they were. And sometimes you didn%t want to know the end. Because how could the end be happy? [Images of the riders winning the battle against the Uruk-hai at Helm%s Deep] How could the world go back to the way it was when so much bad had happened?|2
#
# 2362|TH%ODEN|Victory! We have victory! [He raises his sword with a victorious cry]|2
#
# 2364|SAM|But in the end, it%s only a passing thing, this shadow. [The women and children welcome the men as they return. %owyn runs up to Aragorn and embraces him, crying tears of relief.] Even darkness must pass. A new day will come. [Isengard is flooded. Merry and Pippin looks on from their perch on Treebeard. On the balcony, Saruman stumbles back into his chamber] And when the sun shines it will shine out the clearer. Those were the stories that stayed with you. That meant something, even if you were too small to understand why. But I think, Mr. Frodo, I do understand. I know now. Folk in those stories had lots of chances of turning back only they didn%t. They kept going because they were holding on to something.|2
#
# 2366|FRODO|What are we holding on to, Sam?|2
#
# 2368|SAM|There%s some good in this world, Mr. Frodo. And it%s worth fighting for.|2
#
# 2370|Regie|[Standing in a corner, even Gollum seems moved. Faramir walks over and comes to kneel in front of Frodo]|2
#
# 2372|FARAMIR|I think at last we understand one another, Frodo Baggins.|2
#
# 2374|MADRIL|You know the laws of our country, the laws of your father. If you let them go, your life will be forfeit.|2
#
# 2376|FARAMIR|Then it is forfeit. Release them.|2
#
# 2378|Regie|[Sam shakes the ranger%s hand from his shoulder. Frodo looks up at Faramir with gladness. Over in the realm of Rohan, Gandalf, Th%oden and company ride to the top of a slope, looking towards the Mountain of Fire in the distance.]|2
#
# 2380|GANDALF|Sauron%s wrath will be terrible, his retribution swift. The battle for Helm%s Deep is over. The battle for Middle-earth is about to begin. All our hopes now lie with two little hobbits. Somewhere in the wilderness.|2
#
# 2382|Regie|[Frodo and Sam are walking through the woods, away from Osgiliath.]|2
#
# 2384|SAM|I wonder if we%ll ever be put into songs or tales.|2
#
# 2386|FRODO|What?|2
#
# 2388|SAM|I wonder if people will ever say, %let%s hear about Frodo and the Ring.% And they%ll say %yes, that%s one of my favorite stories. Frodo was really courageous, wasn%t he, dad.% %Yes, my boy, the most famousest of hobbits. And that%s saying alot.%|2
#
# 2390|FRODO|Huh, you left out one of the chief characters % Samwise the Brave. I want to hear more about Sam.|2
#
# 2392|Regie|[Frodo turns to look at Sam.]|2
#
# 2394|FRODO|Frodo wouldn%t have got far without Sam.|2
#
# 2396|SAM|Now Mr. Frodo, you shouldn%t make fun. I was being serious.|2
#
# 2398|FRODO|[smiling] So was I. [He turns to walk on]|2
#
# 2400|SAM|[Dreamily] Samwise the Brave. [He gives his backpack a heave and follows Frodo]|2
#
# 2402|Regie|[Gollum is crouching a short distance away]|2
#
# 2404|FRODO|Sm%agol!|2
#
# 2406|SAM|We%re not gonna wait for you. Come on!|2
#
# 2408|SM%AGOL|Master... Master looks after us. Master wouldn%t hurt us.|2
#
# 2410|GOLLUM|Master broke his promise.|2
#
# 2412|SM%AGOL|Don%t ask Sm%agol. Poor, poor Sm%agol.|2
#
# 2414|GOLLUM|Master betrayed us! Wicked, tricksy, false. We ought to wring his filthy little neck. [Twists the branch of a tree] Kill him! Kill him! Kill them both. And then we take the precious and we be the master.|2
#
# 2416|SM%AGOL|[Scuttles and hides behind a tree] The fat hobbit, he knows. Eyes always watching.|2
#
# 2418|GOLLUM|Then we stabs them out. Put out his eyeses. And make HIM crawl.|2
#
# 2420|SM%AGOL|[Bites on his finger and nods eagerly] Yes! Yes! Yes!|2
#
# 2422|GOLLUM|Kill them both.|2
#
# 2424|SM%AGOL|Yes! No no! [Backs away against a tree] It%s too risky, it%s too risky.|2
#
# 2426|Regie|[He looks in the direction of the hobbits]|2
#
# 2428|SAM|Where%s he gone? Hey Gollum, where are you?|2
#
# 2430|FRODO|Sm%agol?|2
#
# 2432|GOLLUM|[Softly and sinisterly] We could let HER do it.|2
#
# 2434|SM%AGOL|Yes. She could do it.|2
#
# 2436|GOLLUM|Yes, precious she could. And then we takes it once they%re dead.|2
#
# 2438|SM%AGOL|Once they%re dead%|2
#
# 2440|GOLLUM|Shh% [He pops out from hiding in front of the hobbits.]|2
#
# 2442|SM%AGOL|Come on, hobbits. Long ways to go yet. Sm%agol will show you the way.|2
#
# 2444|Regie|[He turns to walk on, with Frodo and Sam following behind.]|2
#
# 2446|GOLLUM|Follow me.|2
#
# 2448|Regie|[ Camera pans up over the forest and Ephel D%ath to reveal the desolation of Mordor. To the left of the frame is the glowing Eye of Sauron atop Barad-d%r, and to the right of the frame is the fiery Mount Doom. Three Fell Beasts circle the dark skies. Lightning flashes as the scene fades to black.]|2
#
# 2450|Sprechertext||2

# %% [markdown]
# ### Datenbereinigung Skript 2

# %% [markdown]
# ### 1. CSV laden

# %%
lotr_2 = pd.read_csv('data/lotr_skript2_dialog_regie_first_output.csv', sep='|')
lotr_2
# Out:
#        Nr.                               Sprecher/Regie  \
# 0        0                                 Sprechertext
# 1        2                                 Sprechertext
# 2        4                                Screenplay by
# 3        6  Based on "The Lord of The Rings" trilogy by
# 4        8                                 Sprechertext
# ...    ...                                          ...
# 1213  2442                                      SM%AGOL
# 1214  2444                                        Regie
# 1215  2446                                       GOLLUM
# 1216  2448                                        Regie
# 1217  2450                                 Sprechertext
#
#                                                    Text  Filmnr.
# 0                                                   NaN        2
# 1                 THE LORD OF THE RINGS: THE TWO TOWERS        2
# 2        Peter Jackson, Fran Walsh and Philippa Boyens.        2
# 3                                        J.R.R Tolkien.        2
# 4                                 Transcription credits        2
# ...                                                 ...      ...
# 1213  Come on, hobbits. Long ways to go yet. Sm%agol...        2
# 1214  [He turns to walk on, with Frodo and Sam follo...        2
# 1215                                         Follow me.        2
# 1216  [ Camera pans up over the forest and Ephel D%a...        2
# 1217                                                NaN        2
#
# [1218 rows x 4 columns]

# %% [markdown]
# ### 2. Erste Rows mit unwichtigen Informationen + mit Attribut "Sprechertext" löschen

# %%
lotr_2 = lotr_2[lotr_2["Nr."] > 20]
lotr_2 = lotr_2[lotr_2["Sprecher/Regie"] != "Sprechertext"]
lotr_2
# Out:
#        Nr. Sprecher/Regie                                               Text  \
# 11      22        GANDALF                                   You cannot pass!
# 12      24          FRODO                                           Gandalf!
# 13      26        GANDALF  I am a servant of the Secret Fire, wielder of ...
# 14      28          Regie         [Camera pans closer to the mountain side.]
# 15      30        GANDALF  Argh! Go back to the shadow. The Dark Fire wil...
# ...    ...            ...                                                ...
# 1212  2440         GOLLUM  Shh% [He pops out from hiding in front of the ...
# 1213  2442        SM%AGOL  Come on, hobbits. Long ways to go yet. Sm%agol...
# 1214  2444          Regie  [He turns to walk on, with Frodo and Sam follo...
# 1215  2446         GOLLUM                                         Follow me.
# 1216  2448          Regie  [ Camera pans up over the forest and Ephel D%a...
#
#       Filmnr.
# 11          2
# 12          2
# 13          2
# 14          2
# 15          2
# ...       ...
# 1212        2
# 1213        2
# 1214        2
# 1215        2
# 1216        2
#
# [1161 rows x 4 columns]

# %% [markdown]
# ### 3. Fehlerhaftes Encoding bereinigen (%-Zeichen ersetzen)

# %%
for index, row in lotr_2.iterrows():
    
    # Clear character names in character column
    lotr_2.at[index, "Sprecher/Regie"] = re.sub("SM%AGOL", "SMEAGOL", lotr_2.at[index, "Sprecher/Regie"])
    lotr_2.at[index, "Sprecher/Regie"] = re.sub("GR%MA", "GRIMA", lotr_2.at[index, "Sprecher/Regie"])
    lotr_2.at[index, "Sprecher/Regie"] = re.sub("H%MA", "HAMA", lotr_2.at[index, "Sprecher/Regie"])
    lotr_2.at[index, "Sprecher/Regie"] = re.sub("NAZG%L", "NAZGUL", lotr_2.at[index, "Sprecher/Regie"])
    lotr_2.at[index, "Sprecher/Regie"] = re.sub("%OWYN", "EOWYN", lotr_2.at[index, "Sprecher/Regie"])
    lotr_2.at[index, "Sprecher/Regie"] = re.sub("%OMER", "EOMER", lotr_2.at[index, "Sprecher/Regie"])
    lotr_2.at[index, "Sprecher/Regie"] = re.sub("TH%ODEN", "THEODEN", lotr_2.at[index, "Sprecher/Regie"])
    lotr_2.at[index, "Sprecher/Regie"] = re.sub("TH%ODRED", "THEODRED", lotr_2.at[index, "Sprecher/Regie"])
    lotr_2.at[index, "Sprecher/Regie"] = re.sub("%OTHAIN", "EOTHAIN", lotr_2.at[index, "Sprecher/Regie"])
    lotr_2.at[index, "Sprecher/Regie"] = re.sub("UGL%K", "UGLUK", lotr_2.at[index, "Sprecher/Regie"])
    lotr_2.at[index, "Sprecher/Regie"] = re.sub("MA%HUR", "MAUHUR", lotr_2.at[index, "Sprecher/Regie"])
    lotr_2.at[index, "Sprecher/Regie"] = re.sub("GRISHN%KH", "GRISHNAKH", lotr_2.at[index, "Sprecher/Regie"])
    lotr_2.at[index, "Sprecher/Regie"] = re.sub("\(V.O.\)", "", lotr_2.at[index, "Sprecher/Regie"])
    lotr_2.at[index, "Sprecher/Regie"] = re.sub("With a grimace, he kills the Uruk-hai", "Regie", lotr_2.at[index, "Sprecher/Regie"])
    
    # Clear place names and person names
    
    lotr_2.at[index, "Text"] = re.sub("Barad-d%r", "Barad-dur", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Palant%r", "Palantir", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Khazad-d%m", "Khazad-dum", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Helm%s\s*Deep", "Helm's Deep", lotr_2.at[index, "Text"])  # covers line breaks
    lotr_2.at[index, "Text"] = re.sub("L%rien", "Lorien", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("M%ria", "Moria", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Lothl%rien", "Lothlorien", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("D%rin%s Tower", "Durin's Tower", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Ud%n", "Udun", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Sm%agol", "Smeagol", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Sm%a%gol", "Smeagol", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Gr%ma", "Grima", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("H%ma", "Hama", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Ham%", "Hama", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Nazg%l", "Nazgul", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("%owyn", "Eowyn", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("%omer", "Eomer", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("%omund", "Eomund", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Th%oden", "Theoden", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Th%odred", "Theodred", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("%othain", "Eothain", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Ugl%k", "Ugluk", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Ma%hur", "Mauhur", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Grishn%kh", "Grishnak", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Gl%in", "Gloin", lotr_2.at[index, "Text"])


    # replace apostrophe's
    
    ## I'm, you're etc.

    lotr_2.at[index, "Text"] = re.sub("I%m", "I'm", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("You%re", "You're", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("you%re", "you're", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("He%s", "He's", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("he%s", "he's", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("She%s", "She's", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("she%s", "she's", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("It%s", "It's", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("it%s", "it's", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("We%re", "We're", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("we%re", "we're", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("They%re", "They're", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("they%re", "they're", lotr_2.at[index, "Text"])

    ## have/has, haven't/hasn't

    lotr_2.at[index, "Text"] = re.sub("i%ve", "i've", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("I%ve", "I've", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("you%ve", "you've", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("You%ve", "You've", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("we%ve", "we've", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("We%ve", "We've", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("they%ve", "they've", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("They%ve", "They've", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("haven%t", "haven't", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Haven%t", "Haven't", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("hasn%t", "hasn't", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Hasn%t", "Hasn't", lotr_2.at[index, "Text"])

    ## is, can, do

    lotr_2.at[index, "Text"] = re.sub("mustn%t", "mustn't", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Mustn%t", "Mustn't", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("let%s", "let's", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Let%s", "Let's", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("can%", "can't", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Can%t", "Can't", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("that%s", "that's", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("That%s", "That's", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("there%s", "there's", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("There%s", "There's", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("what%s", "what's", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("What%s", "What's", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("isn%t", "isn't", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Isn%t", "Isn't", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("aren%t", "aren't", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Aren%t", "Aren't", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("don%t", "don't", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Don%t", "Don't", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("doesn%t", "doesn't", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("doesn%t", "doesn't", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("didn%t", "didn't", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Didn%t", "Didn't", lotr_2.at[index, "Text"])

    ## was/will, wasn't/won't

    lotr_2.at[index, "Text"] = re.sub("I%ll", "I'll", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("you%ll", "you'll", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("You%ll", "You'll", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("he%ll", "he'll", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("He%ll", "He'll", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("she%ll", "she'll", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("She%ll", "She'll", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("it%ll", "it'll", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("It%ll", "It'll", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("we%ll", "we'll", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("We%ll", "We'll", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("they%ll", "they'll", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("They%ll", "They'll", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("wasn%t", "wasn't", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Wasn%t", "Wasn't", lotr_2.at[index, "Text"])

    lotr_2.at[index, "Text"] = re.sub("won%t", "won't", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Won%t", "Won't", lotr_2.at[index, "Text"])

    ## Conjunctive (wouldn't, couldn't, should)

    lotr_2.at[index, "Text"] = re.sub("couldn%t", "couldn't", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("shouldn%t", "shouldn't", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("I%d", "I'd", lotr_2.at[index, "Text"])


    # Single cases

    lotr_2.at[index, "Text"] = re.sub("YOU% SHALL NOT... PASS!!!", "YOU SHALL NOT... PASS!!!", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("lovely % Lembas bread", "lovely Lembas bread", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("S... S...Smeagol%", "S... S...Smeagol.", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Grima% Grima%", "Grima. Grima.", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Ooh% They look tasty!", "Ooh! They look tasty!", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("small % only children", "small, only children", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Bur%rum", "Burarum", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("then% a tunnel", "then...a tunnel", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Oh, he% he must have died", "Oh, he ... he must have died", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Why should I% welcome you, Gandalf%", "Why should I welcome you, Gandalf", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Eowyn% Eowyn", "Eowyn Eowyn", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Simbelmyn%", "Simbelmyn%", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Because% because", "Because ... because", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Mur%derer%!", "Murderer!", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("%em", "them", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("of course ridiculous%", "of course ridiculous.", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("my heart%", "my heart.", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Sleep%", "Sleep.", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Arwen%", "Arwen ...", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Brego% ", "Brego. ", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("And%ril", "Anduril", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Myyy% PRECIOUSSS", "Myyy PRECIOUSSS", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("but% I'm sorry", "but ... I'm sorry", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Where was Gon%%", "Where was Gon--", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("lord %", "lord.", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("To whatever end%", "To whatever end.", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("agreed % you", "agreed ... you", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("War, yes%", "War, yes.", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("ooold%", "ooold", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("anything%", "anything", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("looong%", "looong", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("NAZG'L", "NAZGUL", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("they % Oh!!", "they ... Oh!!", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Hold on, Mr. Frodo%", "Hold on, Mr. Frodo.", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("% Samwise the Brave", ": Samwise the Brave", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("they're dead%", "they're dead.", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Shh%", "Shh.", lotr_2.at[index, "Text"])
    
    
    # Other question marks are either apostrophes or in Elvis/Entish/Old English and will be deleted later anyway
    
    lotr_2.at[index, "Text"] = re.sub("%", "'", lotr_2.at[index, "Text"])
    
    # Remove Kameraanweisungen etc.
    
    lotr_2.at[index, "Text"] = re.sub("FLASHBACK", "", lotr_2.at[index, "Text"])
    lotr_2.at[index, "Text"] = re.sub("Camera pans closer to the mountain side.", "", lotr_2.at[index, "Text"])

# %% [markdown]
# ### Regieanweisungen herausfiltern und in eigene Datei auslagern

# %%
# filter stage directions
stage_directions = lotr_2[(lotr_2["Text"].str.contains("\[")) | (lotr_2["Sprecher/Regie"] == "Regie")]

# remove text outside brackets

for index, row in stage_directions.iterrows():
    # remove curved brackets in advance (data contain nested brackets like [...(..)..], makes things very hard)
    stage_directions.at[index, "Text"] = re.sub("[()]", "", stage_directions.at[index, "Text"])
    # remove content outside square brackets, regex expression idea from 41686d6564's answer at https://stackoverflow.com/questions/64740437/remove-text-outside-of-bracket
    stage_directions.at[index, "Text"] = re.sub("[^[\]]+(?=[[(]|$)", "", stage_directions.at[index, "Text"])
    # remove square brackets
    stage_directions.at[index, "Text"] = re.sub("[\[\]]", "", stage_directions.at[index, "Text"])
    # strip to remove whitespace in beginning and end
    stage_directions.at[index, "Text"] = stage_directions.at[index, "Text"].strip()

# Dateiname festlegen
filename = f'lotr_skript_2_regie.csv'

# Datei löschen, falls sie existiert:
if os.path.exists(f'data/{filename}'):
    os.remove(f'data/{filename}')

# TO CSV

with open(f'data/{filename}', 'a') as f:
    # Spaltenüberschriften
    f.write(f'Nr.|Sprecher/Regie|Text|Filmnr.\n')
    print(f'Nr.|Sprecher/Regie|Text|Filmnr.\n')
    for index, row in stage_directions.iterrows():
        if(row["Text"] != ''):
            f.write(f'{row["Nr."]}|Regie|{row["Text"]}|{row["Filmnr."]}\n')
            print(f'{row["Nr."]}|Regie|{row["Text"]}|{row["Filmnr."]}\n')

            
# Index reset brauchen wir eigentlich nicht mehr...        
        
# reset index and Nr.-column
#count = 1
#for index, row in stage_directions.iterrows():
 #   stage_directions.at[index, "Nr."] = count
  #  count += 1
#stage_directions.reset_index(drop=True, inplace=True)
# Out:
# Nr.|Sprecher/Regie|Text|Filmnr.
#
# 30|Regie|Camera zooms in through the mountain and focuses on Gandalf and the Balrog on the bridge of Khazad-dum. The Balrog strikes down on Gandalf with its flaming sword. Gandalf parries the blow with Glamdring, shattering the Balrog's sword.|2
#
# 32|Regie|Gandalf strikes his staff onto the bridge. As the Balrog steps forward, the bridge collapses from under it and the demon plunges backward into the chasm. Gandalf, exhausted, leans on his staff and watches the Balrog fall then turns to follow the others. At the last minute, the flaming whip lashes up from the depths of the abyss and winds around Gandalf's ankle, dragging him over the edge. He clings onto the bridge but is straining to keep his grip.|2
#
# 36|Regie|Frodo rushes forward but Boromir restrains him.|2
#
# 44|Regie|Gandalf loses his grip and falls into the chasm|2
#
# 48|Regie|Gandalf loses his grip and falls into the chasm|2
#
# 50|Regie|Calls after Gandalf as he falls into the abyss|2
#
# 52|Regie|Gandalf falls after the Balrog and grabs hold of his sword Glamdring on his way down. As they continue to plunge into the depths, Gandalf hacks away at the Balrog even as it thrashes and bounces off the walls. They continue to plunge at great speed, sometimes with Gandalf clinging to the horn of the demon. The battling pair then falls into an enormous cavern and plunges into the water. Just then Frodo awakens as if from a nightmare.|2
#
# 58|Regie|Lies back down.|2
#
# 60|Regie|Frodo and Sam climbs over the rocky terrain Emyn Muil. They look into the distance at the Mountain of Fire.|2
#
# 66|Regie|Suddenly Frodo feels and sees the Eye zooming in on him. He gasps and pants as he backs away.|2
#
# 70|Regie|Clutches the Ring by his chest and sits down, still panting. He then fumbles for his water bottle and takes a sip.|2
#
# 74|Regie|He takes out a package of lembas bread from his packHe digs deeper into his pack|2
#
# 76|Regie|Sam shows another package. He then breaks off a piece and tosses it to Frodo, and munches on a piece himself.|2
#
# 80|Regie|smiles|2
#
# 82|Regie|Sam smiles back, and then looks ominously towards Mordor.|2
#
# 86|Regie|They continue trekking through difficult terrain, often huddling underneath their cloaks.|2
#
# 88|Regie|Looks around|2
#
# 90|Regie|Exasperated|2
#
# 94|Regie|Drops to a whisper|2
#
# 96|Regie|NIGHTTIME Frodo and Sam are sleeping. A dark shape appears on top of the cliff. The creature Gollum has appeared and is making his way down to the hobbits.|2
#
# 98|Regie|Gollum creeps closer and closer.|2
#
# 100|Regie|Gollum reaches out his hand towards the hobbits. Suddenly the hobbits spring up, grab hold of Gollum's arms and pull him down. Amidst the struggle, Gollum wriggles loose and leaps onto Frodo. As Frodo falls back, the chain and Ring around his neck is revealed and Gollum jumps straight for the Ring. Sam tries to grab at him but is knocked away. Gollum now jumps on top of Frodo and tries to reach for the Ring even as Frodo grabs his hands and tries to push him away. Gollum's cheeks puff with exertion as he struggles with Frodo, his enormous eyes fixed on the Ring. Sam grabs hold of Gollum again and tears him away from Frodo. Gollum then turns around and bites Sam on the shoulder, wriggles around and clasps his arms around Sam's neck and legs around his waist in a death grip. Frodo unsheathes Sting and holds it to Gollum's throat.|2
#
# 102|Regie|menacingly|2
#
# 104|Regie|Slowly, Gollum loosens his grip on Sam and as the latter disentangles himself, Gollum wails. In the next scene, Gollum is being dragged with Sam's Elvish rope around his neck, wailing and writhing in pain.|2
#
# 110|Regie|Sam tugs fiercely at the rope. Gollum cries some more and collapses onto his back. Sam turns to Frodo in dismay.|2
#
# 120|Regie|Begging|2
#
# 130|Regie|Gollum backs away, frightened, and climbs onto a boulder|2
#
# 132|Regie|Sam jerks strongly at the rope as Gollum tries to get away from him. He crashes onto the ground, choking.|2
#
# 138|Regie|Gollum lies panting and holding his throat. He backs away, frightened, as Frodo approaches him.|2
#
# 142|Regie|nods warily|2
#
# 146|Regie|nods again|2
#
# 148|Regie|Frodo reaches out and takes the rope noose off Gollum's neck. Gollum seems surprised and relieved.|2
#
# 152|Regie|Gollum scrambles off in the direction of Morannon and the hobbits follow in his wake.|2
#
# 156|Regie|A band of Uruk-hai marches across the plain, with two hobbits bound to the backs of two Uruk-hai. Pippin tries to call to Merry, who is unconscious with a gash on his right brow.|2
#
# 158|Regie|He receives no response.|2
#
# 160|Regie|Suddenly, an Uruk-hai puts up his hand and signals a stop.|2
#
# 164|Regie|sniffs the air|2
#
# 166|Regie|quietly to himself|2
#
# 170|Regie|The Uruk-hai quicken their pace. Pippin struggles to reach his Elven brooch with his teeth. He then tears it off his cloak and drops it onto the ground. A foot stomps onto the brooch but it remains unbroken and visible on the grass.|2
#
# 172|Regie|Aragorn is lying with his eyes closed and ear pressed to the ground, listening for the sound of footsteps.|2
#
# 174|Regie|He looks up.He runs off.|2
#
# 176|Regie|Looks back at Gimli and then runs after Aragorn|2
#
# 178|Regie|pauses in his steps and huffsRuns after his companions.|2
#
# 180|Regie|The Three Hunters run across rocks and plains, with Aragorn in the lead, followed by Legolas and Gimli. From time to time, Legolas looks back to make sure that Gimli is keeping up. Aragorn suddenly bends down to pick up an Elven brooch from the ground.|2
#
# 184|Regie|stops and turns to Aragorn.|2
#
# 186|Regie|Runs off again|2
#
# 188|Regie|Gimli stumbles from behind some rocks and rolls to the ground|2
#
# 192|Regie|Panting|2
#
# 194|Regie|The trackers come over a hill and pause as they gaze across the plains below.|2
#
# 200|Regie|Legolas runs ahead and looks out to the horizon.|2
#
# 210|Regie|The tower of Orthanc stands amidst the smoking caverns of Isengard. Saruman stands in his chamber, communicating with the Dark Lord through the Palantir.|2
#
# 212|Regie|View changes to the tower of Barad-dur, with its huge Orc armies on a bridge.|2
#
# 214|Regie|Camera pans upwards along the height of the tower of Barad-dur until the flaming Eye is in view.|2
#
# 218|Regie|The trees around Isengard are being ripped down, chopped up and used to feed huge furnaces. The caverns of Isengard glow with the fires of industry, sounds of hammering fill the air and molten iron is poured into casts to forge weapons.|2
#
# 222|Regie|Saruman stands in the midst of a gathering of Dunlanders.|2
#
# 230|Regie|Roars with approval|2
#
# 232|Regie|They stomp off to destroy the villages of Rohan as Saruman stands coldly still among the stampede. A Rohan village is in pandemonium as people try to escape the on-coming pillage.|2
#
# 236|Regie|A woman with her hand on a horse calls out to her children.|2
#
# 240|Regie|As Morwen puts her onto the horse in front of her brother|2
#
# 246|Regie|starts to cry|2
#
# 250|Regie|A woman screams|2
#
# 254|Regie|The children ride off.|2
#
# 256|Regie|Looks after them|2
#
# 258|Regie|Dunlanders and Uruk-hai enter the village, burning everything in sights as the Rohirrim scream and run in all directions. Eothain and Freda weep as they look back from a distance.|2
#
# 262|Regie|A group of horsemen ride to Edoras. Eomer is in the lead, carrying a gravely wounded Theodred.|2
#
# 264|Regie|Eowyn runs hastily up the stairs to the Golden Hall and enters a bedchamber. She runs to the bed.|2
#
# 268|Regie|Theodred seems to hear her call but is unable to respond. He has a bloody gash on the side of his head. Eomer nods to Eowyn in the direction of Theodred's torso. Eowyn draws back the covers and upon seeing Theodred's fatal wound, her lips tighten and eyes close. She looks up to catch Eomer's eye.|2
#
# 270|Regie|Eomer and Eowyn are speaking to Theoden-king who sits motionless on his throne, wizened, and aged beyond his years.|2
#
# 276|Regie|Appears from the shadows.|2
#
# 278|Regie|mumbles feeblyGrima leans down close to the King.|2
#
# 280|Regie|He drops a helmet onto the ground, which topples over to reveal the white hand of Saruman.|2
#
# 286|Regie|Eomer grabs Grima and pins him against a pillar.|2
#
# 290|Regie|Grima's eyes flicks to right, watching Eowyn as she walks by. Eowyn stops to stare back for a moment before departing form the hall. Eomer jerks Grima again and clutches his hand around Grima's jaw.|2
#
# 294|Regie|Grima's eyes look to the left and relax as Eomer is suddenly pulled off Grima by his thugs.|2
#
# 296|Regie|The thugs punch Eomer n the stomach|2
#
# 302|Regie|Uruk-hai and Orcs continue to march across the plains with their hobbit captives, with Aragorn, Legolas, and Gimli hot on their pursuits.|2
#
# 308|Regie|They continue running over vast distances. The Uruk-hai and Orcs halt at nightfall, many panting with exertion.|2
#
# 314|Regie|As the Orcs and Uruk-hai take their rest, Pippin crawls over towards Merry.|2
#
# 318|Regie|opens his eyes|2
#
# 320|Regie|A group of Orcs chops down the trees nearby for firewood. Low groans and rumbles start to emerge from the forest.|2
#
# 324|Regie|looks towards the forest|2
#
# 336|Regie|His eyes rest on the hobbits.|2
#
# 342|Regie|Shoves at the Orcs|2
#
# 344|Regie|The other Orcs are getting restless.|2
#
# 348|Regie|Moves towards the hobbits with his blade drawn|2
#
# 352|Regie|Pippin and Merry recoil in fright. Ugluk jumps on the Orc and cuts off his head, which bounces off the hobbit's shoulders.|2
#
# 356|Regie|The Uruk-hai and Orcs cheer and started tearing into the fresh meat, intestines flying, taking their eyes off the hobbits for a while.|2
#
# 360|Regie|Their hands still bound, the hobbits try to crawl away. Suddenly a foot comes down on Merry and Pippin is turned onto his back.|2
#
# 362|Regie|Brandishing a blade in front of Pippin's face|2
#
# 364|Regie|Suddenly, a spear pierces the Orc's back. Mayhem ensues as Riders of Rohan burst out from their hiding places and ambush the Orcs.|2
#
# 366|Regie|Gestures for them to make their escape.|2
#
# 368|Regie|The hobbits try to escape from the pandemonium to the forest, dodging bodies and stomping feet. Suddenly Pippin turns onto his face and looks up to a pair of thrashing hooves bearing down on him.|2
#
# 374|Regie|The Three Hunters are still chasing after the Uruk-hai. It is dawn.|2
#
# 376|Regie|Pauses and looks up|2
#
# 378|Regie|Camera pans over the rock and plains, alternating between the band of Uruk-hai and the Three Hunters giving chase. The trackers hear the sound of horses. Aragorn and company hide behind some boulders. A large group of horse-men appears, galloping quickly with their banners flying. Aragorn comes out of hiding as they pass, followed by Legolas and Gimli.|2
#
# 382|Regie|At a signal from Eomer at the lead, the riders make a quick turn and head towards them, surrounding them in ever-tightening circles. As they stop, they point their long spears menacingly at them.|2
#
# 388|Regie|Eomer hands his staff to another rider, and gets off his horse. Aragorn puts a hand on Gimli's shoulder.|2
#
# 392|Regie|Legolas, in a lightning fast move, points an arrow at Eomer.|2
#
# 396|Regie|The riders all point their spears closer at the travellers. After a tense moment, Aragorn pushes down Legolas' arm.|2
#
# 400|Regie|Takes off helmet|2
#
# 402|Regie|The spears are withdrawn.|2
#
# 414|Regie|Points to a smoking pile in the distance.|2
#
# 418|Regie|nods|2
#
# 420|Regie|Legolas puts a hand on Gimli's shoulder in grief. Eomer turns and whistles.|2
#
# 424|Regie|Eomer puts on his helmet and gets back on his horse|2
#
# 426|Regie|To the riders|2
#
# 428|Regie|Aragorn, Legolas and Gimli look on as the Riders go off. They then ride towards the burning carcasses. Gimli starts to shift through the smoldering pile, and pulls out a charred belt and dagger sheath.|2
#
# 432|Regie|with his head bowed and eyes closed|2
#
# 434|Regie|Kicks a helmet and yellsHe falls to his knees.|2
#
# 438|Regie|Aragorn looks to the side as some tracks catch his attention.|2
#
# 440|Regie|Flashback: Pippin yells as he looks up at a pair of thrashing hooves bearing down on him. He rolls over, avoiding the hooves.|2
#
# 442|Regie|ARAGORN STARTS TO FOLLOW THE TRACKS, WITH LEGOLAS AND GIMLI BEHIND HIM.  Merry and Pippin crawl frantically away from the battle.|2
#
# 444|Regie|Flashback: Merry rubs his bonds furiously against the sharp edge of a weapon.Aragorn holds up a broken length of thick rope.|2
#
# 448|Regie|Their hands freed, the hobbits run away from the battle scene, dodging under a horse and trying to stay out of harms way. As they flee, Grishnak grabs Pippin by his belt and clings on.|2
#
# 452|Regie|Pippin undoes his belt and Grishnak is left holding it.|2
#
# 456|Regie|They break into a run and then stop|2
#
# 458|Regie|The Three looks up into a dense and dark forest|2
#
# 464|Regie|Scene moves from the trackers into the nighttime chase of Merry and Pippin. The hobbits run into the Fangorn, seeking to lose the pursuing Orc. They collapse onto the ground, out of breath.|2
#
# 466|Regie|Looks around|2
#
# 468|Regie|Suddenly, Grishnak appears from behind the trees, brandishing a blade.|2
#
# 472|Regie|Merry and Pippin run and hide behind a tree.|2
#
# 476|Regie|Pippin and Merry quickly scramble up a tree each.|2
#
# 478|Regie|Looks around and then sighs in relief.|2
#
# 480|Regie|Suddenly, Merry is pulled by his legs and falls to the ground. Grishnak leans over him with his menacing blade. Merry tries to kick him off but to no avail.|2
#
# 484|Regie|Pippin looks down in horror but as he turns his head, he spots a pair of gleaming yellow eyes blinking in the tree he's clinging to. The tree starts to move and groan.|2
#
# 490|Regie|Pippin loses his grip in fright and grabs at the air futilely as he falls. The tree catches him before he hits the ground.|2
#
# 492|Regie|Suddenly he senses something behind him and as he looks up, the tree stomps and squashes him onto the forest floor.|2
#
# 496|Regie|Merry tries to run away but is scooped by the tree.|2
#
# 498|Regie|Looks at the creatures in his hands|2
#
# 502|Regie|Stomps slowly through the forest.|2
#
# 516|Regie|Tightens his hold on the hobbits and squeezes them. Merry and Pippin whimpers in pain|2
#
# 526|Regie|Treebeard drops them on the ground and the hobbits look up at the White Wizard.|2
#
# 530|Regie|Following Gollum, Frodo and Sam reach the end of Emyn Muil and see that Mordor is now closer.|2
#
# 534|Regie|Gollum jumps on a rock. Frodo walks past, Gollum shrinks as Sam draws near.|2
#
# 536|Regie|Leaps after Frodo, putting a wide berth between him and Sam.|2
#
# 538|Regie|Sam's foot slipped into muck.|2
#
# 544|Regie|Gollum looks back and gestures for the hobbits to follow.|2
#
# 548|Regie|The marsh lands stretch for miles and miles as far as the eye can see. The hobbits and Gollum appear as little specks. As the three pick their way gingerly though the marshes, they see faces floating in the water, still, rotting and pale, and flickering flames on the swamps.|2
#
# 552|Regie|Turns to face the hobbits.|2
#
# 554|Regie|Sam's foot slips again into the water.|2
#
# 560|Regie|Frodo is drawn to one of the faces in Elven armour. He stares at it intently, until suddenly its eyes open and Frodo falls face-down into the water.|2
#
# 564|Regie|Frodo is in the water and sees many faces of the dead, no longer still but screaming and grasping, their rotten robes and hair flowing about their gruesome faces. Their hands are reaching for him. Suddenly he is grabbed from behind. Frodo sputters and gasps for air as Gollum pulls him out of the water.|2
#
# 566|Regie|Looks at Gollum in perplexed gratitude and disbelief.|2
#
# 568|Regie|Crawls away|2
#
# 570|Regie|Runs to Frodo's side.|2
#
# 572|Regie|Frodo lies panting, staring after Gollum|2
#
# 576|Regie|NIGHTFALL Sam is asleep but Frodo is still awake. He is holding the Ring in the palm of his hand and stroking it, mesmerized. Suddenly he hears Gollum.|2
#
# 578|Regie|Frodo quickly puts the Ring back inside his shirt. He looks up to see Gollum crouching away from him, stroking the centre of his palm|2
#
# 584|Regie|Moves over and crouches in front of Gollum|2
#
# 598|Regie|Looks up slowly.|2
#
# 604|Regie|Suddenly, the piercing cries of the Nazgul are heard overhead|2
#
# 614|Regie|Suddenly Frodo feels the pain of the Nazgul's sword piercing him and the call of the Ring. Images of the Ringwraiths come to him in flashes.|2
#
# 620|Regie|Frodo continues to clutch at the Ring on his chest, immobilized. Sam drags Frodo across to hide beneath some bramble bushes. The Nazgul appears, tightening his hold on the reins. Camera then shows him riding a Fell Beast, swooping down across the marsh lands. Chilling screams of the Nazgul fill the air.|2
#
# 628|Regie|A loud screech from the Nazgul flying high above the marshes.|2
#
# 630|Regie|cowering|2
#
# 632|Regie|Frodo feels the call of the Ring and gropes for his necklace. Sam sees this and grabs hold of Frodo's hand.|2
#
# 636|Regie|The Nazgul continues to circle overhead and then flies off towards Mordor.|2
#
# 642|Regie|Scene returns to Fangorn forest. Gimli fingers a dark stain on a leaf and brings it to his mouth.|2
#
# 644|Regie|Spits|2
#
# 652|Regie|Groans reverberate through the forest and Gimli raises his axe.|2
#
# 656|Regie|Whispers|2
#
# 660|Regie|Gestures|2
#
# 662|Regie|Lowering his axe slowly|2
#
# 668|Regie|Close-up of Legolas' eyes|2
#
# 674|Regie|Aragorn wraps his hand around the hilt of his sword, Gimli tightens his hold on his axes, and Legolas notches an arrow to his bow.|2
#
# 678|Regie|With a yell, the three swing round to attack. Gimli's axe and Legolas' arrow are deflected. Aragorn drops his sword as it becomes red hot in his grasp. They shield their eyes with their hands from the bright light emanating from the White Wizard.|2
#
# 688|Regie|The bright light dims, revealing Gandalf, all dressed in white. The three are astounded. Legolas and Gimli bow.|2
#
# 692|Regie|Flashback: Gandalf is battling the Balrog atop Durin's Tower.|2
#
# 694|Regie|Gandalf holds up Glamdring and a flash of lightning strikes it before he plunges the sword into the Balrog. With a final cry, the Balrog falls from the peak and lands, smoking, onto the icy mountainside.|2
#
# 698|Regie|On top of the mountain, Gandalf crawls a bit and then collapses.|2
#
# 700|Regie|Camera zooms in Gandalf's eye and enters an amorphous realm of stars and galaxies, ending in a blinding white light|2
#
# 702|Regie|Camera zooms out from Gandalf's eye, lying naked and very still. His hair has turned white and wounds are completely healed. He suddenly shudders with a deep gasp and pants as life returns to him|2
#
# 708|Regie|He smiles|2
#
# 712|Regie|With a twinkle in his eyeAragorn grins|2
#
# 714|Regie|They walk through the forest, with Gandalf leading the way, now wearing a grey cloak over his white robes.|2
#
# 718|Regie|Outside the forest, Gandalf whistles piercingly. Soon an answering neigh is heard and a white horse appears from the plain, answering the call.|2
#
# 722|Regie|The horse comes round to stop in front of Gandalf.|2
#
# 724|Regie|Gimli bows in the background.|2
#
# 726|Regie|The Three Hunters and Gandalf ride across the plains to Edoras.|2
#
# 730|Regie|Back at Fangorn, Treebeard is walking through the forest with Merry and Pippin sitting on his shoulders.|2
#
# 736|Regie|Frodo and Sam are climbing a high rock overlooking Morannon.|2
#
# 740|Regie|The enormous Black Gate comes into view with Orcs patrolling and standing guard on the towers and atop the walls. From the right, an army of Easterling soldiers is marching to the Black Gate.|2
#
# 748|Regie|Orcs are patrolling the Black Gate.|2
#
# 752|Regie|A command is heard and an Orc sounds a horn, signalling for the Gate to be opened. Two enormous cave trolls stretch and growl and then pull the mighty Gate open.|2
#
# 756|Regie|He moves closer to the edge. Suddenly, the rock underneath him gives way and he falls.|2
#
# 762|Regie|Frodo goes after Sam.|2
#
# 766|Regie|Two Easterling soldiers see streams of dust coming down the cliff made by Sam and Frodo. They move away from the troop to investigate. Frodo reaches Sam who is stuck in the scree. As the Easterlings move closer and closer, Frodo throws his Elvish cloak over himself and Sam. The soldiers are now directly in front of Sam, but their eyes see nothing but rock. Frodo and Sam peer from underneath the cloak. The soldiers soon leave and after a moment, Frodo throws back the cloak and pulls Sam out.|2
#
# 772|Regie|They prepare to make a run for the Gate.|2
#
# 776|Regie|Gollum pulls them back.|2
#
# 780|Regie|Frodo tries to make a run for it.|2
#
# 782|Regie|Pulls Frodo back again.|2
#
# 792|Regie|Frodo and Sam watch as the Black Gate closes. Gollum is stroking Frodo's arm and burying his face in his cloak.|2
#
# 800|Regie|Whispers|2
#
# 806|Regie|Frodo follows Gollum as Sam stares after him in disbelief.|2
#
# 808|Regie|On the plains of Rohan. Gandalf, Aragorn, Legolas and Gimli stop as Edoras comes into view.|2
#
# 812|Regie|In the Hall, Eowyn is kneeling before Theoden, holding his hand in hers.|2
#
# 816|Regie|Theoden just sits and stares ahead, his eyes clouded and unseeing.|2
#
# 818|Regie|She weeps.|2
#
# 820|Regie|Scene returns to Gandalf and company.|2
#
# 824|Regie|They ride on towards Edoras.|2
#
# 828|Regie|At Edoras, Eowyn is weeping at the dead Theodred's bed. She kisses his hand. Grima appears at the door.|2
#
# 832|Regie|He sits on the bed and puts a hand on Eowyn's shoulder.|2
#
# 836|Regie|jumps back and throws off Grima's hand|2
#
# 838|Regie|Rises from the bed and moves ever closer to Eowyn|2
#
# 840|Regie|He puts a hand on her cheek and moves down to her throat.|2
#
# 844|Regie|Eowyn and Grima stare at each other intently.|2
#
# 848|Regie|Eowyn runs out of the hall. Weeping, she looks away into the distance. A flag comes off its pole and is carried by the breeze. Eowyn sees riders coming towards Edoras. As Aragorn passes the entrance to Edoras, the flag floats down to land near him. Edoras is silent and somber. Everyone is dressed in black and staring at the newcomers in wary silence. Aragorn looks up at the hall and sees a lady in white standing on the steps. He looks around at more somber people.|2
#
# 852|Regie|Aragorn looks up to the hall again but the lady has disappeared. The company climbs up the stairs to the hall and is met by guards.|2
#
# 854|Regie|sees Hama|2
#
# 858|Regie|Gandalf nods in understanding and signals for the others to surrender their weapons. Aragon hands over his sword and knives. Legolas gives a little twirl to his knives before handing them over to the guards. Gimli hands over his axes reluctantly.|2
#
# 860|Regie|gestures to Gandalf|2
#
# 862|Regie|Glances at his staff.Looks at Hama innocently.|2
#
# 864|Regie|Hama hesitates for a second and then gestures that they follow him into the hall. Gandalf gives Aragorn a tiny wink and enters the hall, leaning on Legolas' arm.|2
#
# 866|Regie|Leaning down and whispering to Theoden.|2
#
# 870|Regie|As Gandalf approaches Theoden, Aragorn, Legolas and Gimli pull back and survey the hall and its hostile occupants. A group of men starts to follow their steps with hostility.|2
#
# 872|Regie|Whispering to Theoden.|2
#
# 874|Regie|Looks to Grima for affirmation.|2
#
# 876|Regie|He walks towards Gandalf.|2
#
# 878|Regie|Raises his staff against Grima.|2
#
# 880|Regie|Backing away from Gandalf while addressing the guards|2
#
# 882|Regie|The hostile guards attack. Aragorn, Legolas and Gimli engage them in a fist-fight as Gandalf continues to approach Theoden. Gamling tries to go forward but Hama holds him back.|2
#
# 886|Regie|Grima tries to crawl away unnoticed, but Gimli catches him and pins him to the floor.|2
#
# 888|Regie|Growls|2
#
# 890|Regie|Gestures with his hand|2
#
# 892|Regie|MenacinglyGandalf opens his eyes in surprise.|2
#
# 894|Regie|Gandalf throws back his grey cloak, exuding blinding white light. Theoden is thrown back against his seat.|2
#
# 898|Regie|Points his staff towards Theoden.|2
#
# 900|Regie|Eowyn rushes in. Seeing her uncle threatened, she tries to go to him but is held back by Aragorn.|2
#
# 904|Regie|In Saruman's voice.|2
#
# 906|Regie|Gandalf moves his staff sharply and Theoden flies back against the chair again.|2
#
# 910|Regie|in Saruman's voice|2
#
# 914|Regie|Gandalf smites Theoden as he lunges at him. Theoden is thrown back into the chair and the shot changes to Saruman flying backwards from the Palantir which he used to manipulate Theoden. He lands landing hard on the floor of Orthanc, bleeding from a gash in his forehead. In the hall, Theoden lets out a moan and slumps forward in the chair. Eowyn runs to her uncle's side as he falls. Theoden's head rises again and his face begins to change gradually into that of a much younger-looking man. Clarity and recognition returns to his eyes.|2
#
# 916|Regie|Looks closely at Eowyn|2
#
# 918|Regie|Eowyn weeps with joy|2
#
# 924|Regie|The hall is shown to be filled with light again, as everyone marvels at the rejuvenation of the king.|2
#
# 926|Regie|Standing up and looking around him.He looks down at his trembling hands.|2
#
# 930|Regie|Hama runs up with his sword. Theoden reaches for it with trembling hands. He wraps his fingers around it slowly and then draws it, gazing upon the shiny steel. In a corner, Grima trembles and tries to escape but is pulled back by Gimli. Suddenly, Theoden's gaze turns to Grima. Grima is thrown out of the hall and down the stairs.|2
#
# 932|Regie|Beseechingly to Theoden|2
#
# 934|Regie|Advancing towards Grima, holding the sword firmly in his hand|2
#
# 936|Regie|Grovelling|2
#
# 938|Regie|Theoden raises his sword to kill Grima. Aragorn holds him back.|2
#
# 942|Regie|Grima scrambles to his feet and pushes through the crowd|2
#
# 948|Regie|The crowd kneels in homage before Theoden. Aragorn kneels also. Grima rides out of Edoras. As Theoden turns to go back into the hall, he looks up.|2
#
# 954|Regie|A white flower comes into view, held up by a hand. It is released and spirals down to land among similar flowers, in front of a tomb.|2
#
# 956|Regie|Looks at Gandalf|2
#
# 962|Regie|Theoden starts to weep|2
#
# 966|Regie|Gandalf turns to go back to the hall and leaves Theoden to grieve in private. He spots two children on horseback. The boy collapses and falls off the horse. Later, inside the Golden Hall, the two children are eating at a table, and Eowyn is with them.|2
#
# 974|Regie|Leans forward and puts a hand on Theoden's chair. Theoden looks at his hand warily.|2
#
# 980|Regie|Gimli takes a bite of his bread as he watches the exchange between Aragorn and Theoden.|2
#
# 986|Regie|Gimli takes a drink and burps.|2
#
# 990|Regie|Scene shifts to outside Meduseld|2
#
# 994|Regie|People are moving about, gathering their belongings and preparing to move. Gandalf, Aragorn, Legolas and Gimli walk towards the stables.|2
#
# 1000|Regie|They enter the stables|2
#
# 1006|Regie|Turns to Shadowfax and strokes him|2
#
# 1008|Regie|Opens the stall gates|2
#
# 1010|Regie|Legolas jumps back as Gandalf rides out of the stable and over the plains of Rohan.|2
#
# 1014|Regie|Eowyn opens a chest in which lies a sword. She unsheathes it and begins to practice. She swings around and is met by Aragorn, who blocks her parry.|2
#
# 1018|Regie|With a swift move, Eowyn swings her sword and renders Aragorn vulnerable, gaining the upper hand.|2
#
# 1020|Regie|Stepping back and sheathing her sword.|2
#
# 1026|Regie|He sheaths his knife.|2
#
# 1028|Regie|He bows and Eowyn gazes after him as he walks away.|2
#
# 1032|Regie|The people of Rohan are moving out of Edoras towards Helm's Deep, with Theoden leading the way. At Isengard, Grima confers with Saruman, holding a cloth to his mouth.|2
#
# 1036|Regie|Saruman's eyebrows rise in response. He walks through the depths of Isengard and gives orders to an Orc.|2
#
# 1040|Regie|The Orc smiles. In a pit behind him, ferocious growls are heard and shadows dances.|2
#
# 1044|Regie|Gollum is trying to catch a fish in the river. He slips and falls, grasping at a slippery fish as he goes. Frodo and Sam follow behind.|2
#
# 1056|Regie|Glaring at SamHe walks past Sam and stops.|2
#
# 1064|Regie|Snapping at Sam|2
#
# 1066|Regie|Sam walks away slowly.|2
#
# 1068|Regie|With remorse|2
#
# 1070|Regie|Looks back at Frodo with tears in his eyes.|2
#
# 1072|Regie|Grows angry againHe walks away|2
#
# 1076|Regie|Frodo continues to walk away without looking back.|2
#
# 1080|Regie|Nighttime, Frodo and Sam are asleep. Gollum is crouching in a corner by himself.|2
#
# 1090|Regie|Tauntingly|2
#
# 1092|Regie|Covers his ears|2
#
# 1096|Regie|Shaking his head|2
#
# 1100|Regie|Starts to weep and whimper|2
#
# 1102|Regie|Cackles|2
#
# 1104|Regie|Weeping and in a small voice|2
#
# 1106|Regie|Fiercely|2
#
# 1108|Regie|Resolute|2
#
# 1110|Regie|Startled|2
#
# 1120|Regie|Louder|2
#
# 1122|Regie|Growls and bares his teeth|2
#
# 1126|Regie|Smeagol pants and then looks around.|2
#
# 1128|Regie|He hops around in joy and does a little dance.|2
#
# 1130|Regie|The next day, while the hobbits were resting, Smeagol comes back with two rabbits and drops them onto Frodo's lap.|2
#
# 1134|Regie|Frodo looks at up him with bloodshot eyes. He smiles at Smeagol and looks at Sam. Smeagol raises a fist in self-congratulation and dances around. He then picks up one of the rabbits and snaps the rabbit's back in front of Frodo.|2
#
# 1138|Regie|He bites and tears into the raw meat. Sam rushes over and snatches the rabbit out of Gollum's hands|2
#
# 1140|Regie|Holding up the two rabbits|2
#
# 1142|Regie|A pot of stew is simmering over a fire.|2
#
# 1144|Regie|Looking into the pot|2
#
# 1148|Regie|A faint calling sound catches the attention of Frodo.|2
#
# 1156|Regie|Sticks out his tongue in disgust|2
#
# 1158|Regie|He takes a sip of the stew|2
#
# 1160|Regie|scrambles up close to SamMakes sickeningly happy face.Hops away|2
#
# 1164|Regie|Frodo follows the source of the sound. Sam suddenly notices that Frodo is no longer in his sight.|2
#
# 1168|Regie|He goes in search of Frodo and finds him lying down near some bushes looking at a Haradrim army marching across the land. He moves to lie low beside Frodo. Smeagol also moves in beside Frodo.|2
#
# 1180|Regie|Suddenly grabs Frodo's arm|2
#
# 1182|Regie|Gigantic Oliphaunts appear, carrying soldiers and supplies on their backs.|2
#
# 1186|Regie|Smeagol slips away unnoticed.|2
#
# 1188|Regie|Looking around|2
#
# 1190|Regie|Suddenly, pandemonium breaks out from below; the soldiers are being ambushed. Cloaked rangers are firing deadly arrows at the soldiers and Oliphaunts from behind bushes. One of the Oliphaunts starts trumpeting and stomping towards Frodo and Sam, swinging his huge trunk and tusks. Faramir takes aim and shoots a soldier. He falls from the Oliphaunt and lands right behind Frodo and Sam, dead.|2
#
# 1194|Regie|Frodo runs right into a Gondorian Ranger, who grabs hold of him and throws him onto his back. Sam sees Frodo in danger and grapples for his sword|2
#
# 1198|Regie|He charges at Faramir but is grabbed by another ranger and thrown down. A sword appears at his throat. Faramir appears.|2
#
# 1204|Regie|Meanwhile, the Rohirrim refugees are heading towards Helm's Deep. Gimli is on a horse, chatting with Eowyn who is leading it by the reins.|2
#
# 1208|Regie|Eowyn smiles and looks back at Aragorn.|2
#
# 1210|Regie|Gestures and whispers|2
#
# 1214|Regie|Laughs gaily|2
#
# 1218|Regie|The horse suddenly rears up and gallops away as Eowyn loses her hold on the reins. Gimli falls off after a short distance and lands with a loud thump.|2
#
# 1222|Regie|Struggling to get up|2
#
# 1224|Regie|Eowyn helps Gimli up. She laughs as she brushes him off and looks back at Aragorn with the sun behind her and the wind in her hair. At that particular moment, Aragorn seems enchanted by Eowyn's light-hearted image. That night. Aragorn could not sleep and smokes his pipe as he thinks of Arwen.|2
#
# 1228|Regie|Aragorn is lying on a chaise in Rivendell. He opens his eyes and sees Arwen before him, smiling down at him.|2
#
# 1232|Regie|Bends down to kiss him|2
#
# 1234|Regie|She kisses him lightly on the lips and then steps away to look out upon Rivendell. Aragorn closes his eyes but for a while. He looks over at Arwen.|2
#
# 1238|Regie|Turns to look at Aragorn|2
#
# 1240|Regie|Walks over to Arwen|2
#
# 1246|Regie|Arwen hushes him, resting her fingers on his lips. As her hands moves down to rest on the Evenstar pendant around Aragorn's neck, he clasps her hand in his and they gaze into each other's eyes.|2
#
# 1250|Regie|They kiss.|2
#
# 1254|Regie|The next day, on the journey to Helm's Deep. Eowyn is walking alongside Aragorn.|2
#
# 1258|Regie|ARAGORN SMILES AND SAYS NOTHING.  Elrond is speaking to Aragorn in Rivendell, before he sets out with the Fellowship.|2
#
# 1270|Regie|Aragorn and Arwen are together before the Fellowship departs.|2
#
# 1278|Regie|He takes Arwen ...s hand to return the Evenstar necklace to her.|2
#
# 1282|Regie|Closes Aragorn's hand over the Evenstar|2
#
# 1284|Regie|Scene shifts back to Aragorn and Eowyn|2
#
# 1290|Regie|Gamling and Hama ride to the front. Legolas watches them as they pass.|2
#
# 1294|Regie|Their horses become restless.|2
#
# 1296|Regie|Looking around|2
#
# 1298|Regie|A warg scout appears on a slope above and charges at them. The warg attacks Hama and kills him.|2
#
# 1302|Regie|Just as it starts to turn on Gamling, Legolas runs over and kills the warg with an arrow. He then draws his knife and kills the Orc.|2
#
# 1304|Regie|Shouts to Aragorn|2
#
# 1308|Regie|Running back to Theoden|2
#
# 1310|Regie|Hearing the alarm, the villagers begin to cry and panic.|2
#
# 1316|Regie|Trying to mount Arod|2
#
# 1318|Regie|Gimli gets onto the horse with some help. Legolas gazes into the distance and sees many warg-riders coming fast towards them, kicking up dust trails as they go.|2
#
# 1320|Regie|To Eowyn|2
#
# 1326|Regie|Eowyn holds Theoden's gaze for a moment and then turn to attend to the villagers.|2
#
# 1328|Regie|To his men|2
#
# 1330|Regie|Tries to get Arod to moveArod moves off with Gimli seated rather unsteadily.|2
#
# 1332|Regie|To the villagers|2
#
# 1334|Regie|She looks back at the Rohirrim and sees Aragorn on Hasufel. They hold each other's gaze for a moment before Aragorn turns to join Theoden. Eowyn departs with the villagers in the opposite direction.|2
#
# 1336|Regie|Legolas takes aim at the distant target and fells a warg rider. He draws another arrow and kills another. Just as he reaches for a third arrow, he sees Theoden and company approaching. He quickly runs and mounts Arod with a smooth leap and joins in the fray with Gimli behind him on horseback.|2
#
# 1342|Regie|The Rohirrim and warg riders crash head on and the battle begins. Theoden and company hack away at the warg riders. In the midst of fighting, Gimli falls off Arod. He turns to find a warg growling at him.|2
#
# 1346|Regie|Just as the warg leaps at Gimli, Legolas kills it with one shot.|2
#
# 1348|Regie|Jumping back as the warg falls, outraged|2
#
# 1350|Regie|As Gimli swings his axe at another warg, it dies and falls onto Gimli, pinning him under.|2
#
# 1354|Regie|As he tries to lift the warg off him, an Orc leans over them both. Gimli kills him quickly, twisting his neck, and it lands on him also. Gimli sniffs at the Orc and makes a face. He tries to lift both the warg and Orc off him. Just then, another warg comes upon him and bares its teeth, ready to strike.|2
#
# 1356|Regie|Eyes widening|2
#
# 1358|Regie|Aragorn plucks a spear as he passes on horseback and throws it at the warg. It dies, landing on Gimli and adding to the pile on top of him.|2
#
# 1360|Regie|As the warg lands on him|2
#
# 1362|Regie|Theoden stabs at a warg rider. Aragorn is knocked off Hasufel and attacked by Sharku. Aragorn tries to kill the warg rider but Sharku blocks his attempt and grabs Aragorn by the neck, while the latter is half-dragged by the warg. In the struggle, Sharku is thrown off and he rips the Evenstar pendant from Aragorn's neck as he falls. Aragorn tries to let go of the warg but finds his wrist tangled with the saddle straps. He tries unsuccessfully to disentangle himself and is dragged closer and closer to the edge of a cliff at great speed. The warg runs right off the cliff and they both disappear over the edge. The battle is winding down as the Rohirrim finish off the last few wargs and Orcs.|2
#
# 1364|Regie|Looking around|2
#
# 1368|Regie|They come near to the cliff and hear Sharku wheezing and laughing|2
#
# 1370|Regie|Standing over the dying Orc|2
#
# 1372|Regie|coughLaughs evilly|2
#
# 1374|Regie|Looks towards the edge of the cliff, and grabs Sharku|2
#
# 1376|Regie|Sharku chortles and dies. Legolas looks down at Sharku's fist and finds the Evenstar pendant. He takes it, runs to the edge of the cliff and looks down to see the great drop and rushing waters below, with no sign of Aragorn. Gimli comes to stand beside him.|2
#
# 1378|Regie|To his men|2
#
# 1380|Regie|Legolas turns to Theoden, an expression of perplexed anger on his face.|2
#
# 1382|Regie|Puts a hand on Legolas' shoulder|2
#
# 1384|Regie|He leaves Legolas and Gimli to stare down at the river.|2
#
# 1388|Regie|The Rohan villagers are drawing close to Helm's Deep. Cries of relief are heard as the refuge is within sight.|2
#
# 1392|Regie|To Eowyn|2
#
# 1394|Regie|Eowyn embraces the woman and they walk on towards Helm's Deep. The gate is opened for the villagers. Many have already taken refuge within and are resting along the passage. Eothain and Freda run towards their mother.|2
#
# 1400|Regie|The three hug and cry with joy. Theoden and company returns from the battle with warg riders|2
#
# 1408|Regie|Eowyn rushes down to meet them|2
#
# 1410|Regie|Looking about|2
#
# 1412|Regie|Dismounting|2
#
# 1414|Regie|Going up to Eowyn|2
#
# 1420|Regie|Eowyn is shaken and raises teary eyes to Theoden. The latter looks down and then walks away, confirming her unasked question.|2
#
# 1424|Regie|At the battlements|2
#
# 1430|Regie|Walks down the steps and past a sewer gate|2
#
# 1432|Regie|Camera zooms in on the gate|2
#
# 1436|Regie|Camera turns to Grima and Saruman at Orthanc. Saruman is pouring some dark dry substances into a vessel. Grima is holding a lit candle in his hand.|2
#
# 1440|Regie|As he steps closer to the vessel, Saruman takes hold of Grima's hand and pushes the candle away from the vessel firmly.|2
#
# 1444|Regie|He walks away towards the balcony.|2
#
# 1446|Regie|Following Saruman|2
#
# 1452|Regie|Both of them came onto the balcony of the tower. Grima suddenly sees and hears the enormous armies laid out below in neat rows and is astounded and awed. He continues to hold the extinguished candle aloft as he gapes at the vast army below. A horn is sounded, announcing the appearance of Saruman. A loud cheer is heard from the army. Saruman raises a hand.|2
#
# 1456|Regie|The army cheers and roars.|2
#
# 1460|Regie|The camera keeps zooming out from the balcony over the incredible size of Saruman's army, past Uruk-hai, spears, and banners and yet more Uruk-hai. The camera focuses back on Saruman who then raises his hands in the air|2
#
# 1464|Regie|The army cheers and roars even louder.|2
#
# 1466|Regie|Sneers|2
#
# 1468|Regie|A tear flows down Grima's cheek. The Uruk-hai army began their march to Helm's Deep.|2
#
# 1472|Regie|Merry and Pippin are travelling through the forest, carried by Treebeard.|2
#
# 1480|Regie|The two hobbits climb higher up onto Treebeard for a better view.|2
#
# 1484|Regie|Pippin and Merry are now on top of Treebeard and they see a massive army moving across the land|2
#
# 1492|Regie|Aragorn is floating in the river, unconscious. He is washed ashore and dreams of Arwen.|2
#
# 1494|Regie|Kissing him on the lips|2
#
# 1496|Regie|A horse arrives and nudges Aragorn, turning him over and nuzzling him.|2
#
# 1498|Regie|MumblesHe grabs hold of Brego's mane, pulls himself onto the horse and rides slowly to Helms Deep.|2
#
# 1500|Regie|Arwen is lying on her bed, deep in thought.|2
#
# 1502|Regie|Coming into her room|2
#
# 1504|Regie|Arwen hears him and sits up.|2
#
# 1514|Regie|Walks towards window and looks out|2
#
# 1516|Regie|Arwen sees a vision of her future as Elrond speaks. She is dressed as a queen in mourning garb and looking down upon Aragorn, a crown on his brow, Anduril in his hand, and dead. Mourners are walking around the altar, paying their final respects. Arwen is weeping.|2
#
# 1520|Regie|The body of Aragorn is now cast as a monument in stone. Arwen stands before the monument, veiled and in black.|2
#
# 1524|Regie|Still veiled in black, Arwen is walking alone through the deserted woods of Lothlorien.|2
#
# 1526|Regie|Tuning to Arwen|2
#
# 1528|Regie|The vision ends and Arwen weeps with sadness and fear. Elrond comes to sit beside his daughter and raises a hand to her cheek.|2
#
# 1532|Regie|Crying and moving into her father's embrace|2
#
# 1534|Regie|Elves, cloaked and carrying a lantern each, are setting off from Rivendell on their journey to the West. Elrond looks on as Arwen leaves with them. Arwen turns back to look at her father one last time before she departs. Elrond continues to stare after her with an expression of resigned sadness.|2
#
# 1536|Regie|Elrond is standing by a window. He hears Galadriel speaking.|2
#
# 1538|Regie|Saruman is communicating with Sauron via the Palantir.View of Saruman's marching armyView of OsgiliathClose-up of Galadriel|2
#
# 1540|Regie|Close-up of the Ring spinning in slow motion|2
#
# 1544|Regie|We see Faramir and Gondorian rangers with the captured Frodo and Sam.|2
#
# 1548|Regie|Faramir and company have reached Henneth Ann'n. Frodo and Sam and being carries, blinded-folded into the cave.|2
#
# 1552|Regie|Close-up of Galadriel's luminous eyes with their deep pools of wisdom. We then see Elrond in his library, looking at the painting of Isildur facing down Sauron with the broken blade of Narsil.|2
#
# 1558|Regie|Scene returns to Henneth Ann'n. Faramir is conferring with his man. They unroll a map.|2
#
# 1562|Regie|Points at the map|2
#
# 1572|Regie|Tracing on the map|2
#
# 1574|Regie|The hobbits are unbound and blindfolds taken off them by Damrod and another ranger. Sam and Frodo find themselves in a cave behind a waterfall, with Damrod sitting behind them on a rock constantly watching them. Faramir comes up to them and sits.|2
#
# 1582|Regie|Frodo and Sam remain silent.|2
#
# 1594|Regie|The merest hesitation.|2
#
# 1596|Regie|Sam looks shifty-eyed and uncomfortable.|2
#
# 1600|Regie|Intently|2
#
# 1606|Regie|Shocked|2
#
# 1608|Regie|Pause|2
#
# 1612|Regie|Faramir is sitting alone, deep in thought. Suddenly someone comes up to him.|2
#
# 1614|Regie|whispers|2
#
# 1616|Regie|Frodo and Sam are sleeping. Frodo awakens as Faramir stands before him.|2
#
# 1620|Regie|Frodo gets up and follow. They come to the edge of the waterfall, overlooking the Forbidden Pool.|2
#
# 1622|Regie|Pointing down|2
#
# 1624|Regie|Frodo looks down and sees Gollum diving into the water.|2
#
# 1626|Regie|He gestures to archers hidden in the bushes.|2
#
# 1628|Regie|The Rangers notch their arrows|2
#
# 1632|Regie|Frodo looks stricken. Gollum emerges from the pool onto a rock. He holds a fish in his hand and starts singing, slapping the fish on the rock as he goes.|2
#
# 1634|Regie|singingWhacks the fish on the rockwhacksThe fish almost wriggles out of his grasp and he whacks it some more.|2
#
# 1636|Regie|Faramir has his hand raised to order his men to shoot. At the last moment, Frodo calls out.|2
#
# 1638|Regie|Faramir stops|2
#
# 1640|Regie|Faramir nods. Frodo descends to the Forbidden Pool and approaches Gollum who is gorging on the raw fish.|2
#
# 1642|Regie|Gollum turns round at Frodo's voice.|2
#
# 1644|Regie|Frodo gestures for Gollum to follow him.|2
#
# 1650|Regie|With the fish between his teeth, Gollum follows Frodo warily. Suddenly he looks up in alarm and is caught by Rangers.|2
#
# 1654|Regie|wails|2
#
# 1656|Regie|A black cloth is brought over Gollum's head. Frodo stares after them with a stricken expression as Faramir leads Gollum and his men away. Back in the cave, Gollum is thrown down to the ground. Crying, he crawls into a corner and curls up into ball.|2
#
# 1662|Regie|Cooing, his hand stroking his shoulder|2
#
# 1664|Regie|Sobbing|2
#
# 1668|Regie|Sobbing|2
#
# 1674|Regie|Hits his fist against the wall|2
#
# 1676|Regie|Whimpers|2
#
# 1680|Regie|Turns to Faramir with a ferocious expressionHe bares his teeth and growls|2
#
# 1684|Regie|Back in their holding area, Sam and Frodo are alone.|2
#
# 1692|Regie|They both stand as Faramir enters.|2
#
# 1694|Regie|Unsheathes his sword|2
#
# 1696|Regie|Faramir lifts the Ring from Frodo's neck with the tip of his sword.|2
#
# 1700|Regie|Frodo is backed up fearfully against the wall. The Ring whispers and Frodo falls into a trance. Suddenly, he grabs the Ring in his hand and jerks himself away.|2
#
# 1702|Regie|He runs away from Faramir|2
#
# 1706|Regie|Faramir stares at Frodo. Just then Damrod enters.|2
#
# 1714|Regie|He turns to leave.|2
#
# 1716|Regie|Sam looks after Faramir sadly.|2
#
# 1720|Regie|Aragorn is riding towards Helm's Deep. On the way, he sees an enormous Uruk-hai army marching with great speed. He quickly makes haste towards Helm's Deep and soon sees the refuge.|2
#
# 1722|Regie|Patting Brego on the neck|2
#
# 1724|Regie|He rides into Helm's Deep to the amazement of all.|2
#
# 1728|Regie|Pushing his way through the crowd.He sees Aragorn.He hugs Aragorn.|2
#
# 1732|Regie|Gimli gestures to the hall. As Aragorn makes his way in, he runs into Legolas who stands waiting.|2
#
# 1734|Regie|They smile. Legolas pauses and looks at Aragorn's wounds.|2
#
# 1736|Regie|To the side, Eowyn sees Aragorn and smiles joyously and with relief. Legolas takes Aragorn's hand and gives the Evenstar pendant. Aragorn looks at the Evenstar and claps Legolas on the shoulder.|2
#
# 1740|Regie|Eowyn looks on and smiles even as tears fill her eyes.|2
#
# 1742|Regie|Aragorn is in the keep, conferring with Theoden|2
#
# 1756|Regie|Walks away resolutely|2
#
# 1758|Regie|Along the passage behind the Deeping Wall.|2
#
# 1760|Regie|to Gamling|2
#
# 1762|Regie|Gamling nods and goes off. Theoden stands at the gate of Helm's Deep, speaking to Aragorn, Legolas and Gimli.|2
#
# 1770|Regie|Gimli seems miffed. Legolas claps a hand on Gimli's shoulder as he follows Aragorn and Theoden back in.|2
#
# 1776|Regie|Draws close to Aragorn|2
#
# 1784|Regie|He walks away, calling out orders|2
#
# 1788|Regie|Cutting him off|2
#
# 1790|Regie|to the soldiers|2
#
# 1792|Regie|Men rush to prepare for battle as flocks of carrion crows circle overhead.|2
#
# 1796|Regie|Treebeard walks through the forest carrying Merry and Pippin. He comes to a clearing and stops.|2
#
# 1806|Regie|Merry and Pippin turns round as they hear movement from the forest around them. They see many more Ents like Treebeard gathering.|2
#
# 1810|Regie|Merry licks his lips in anticipation.|2
#
# 1814|Regie|Back at Helm's Deep, the women and children are being led into the caves.|2
#
# 1822|Regie|Old men and young lads are being drafted for war. The women and children say their tearful and reluctant farewells as their fathers, husbands and sons are led away by soldiers. In the armoury, weapons are being distributed. Aragorn picks up a battered sword, looks at it and tosses it back.|2
#
# 1828|Regie|The men around them fell silent. Legolas speaks to Aragorn.|2
#
# 1834|Regie|He pauses and then walks away. Legolas makes as if to go after him.|2
#
# 1836|Regie|Puts a hand on Legolas|2
#
# 1840|Regie|In the hall|2
#
# 1850|Regie|Puts armour onto Theoden|2
#
# 1852|Regie|The villagers are handed their weapons. An oversized helmet is placed on a wide-eyed boy. Another stares at the axe that he is handed with frightened eyes. Another child wearing oversized chain mail takes up a huge shield. Theoden stands inside the main hall of the keep, his back to the entrance where a bright white light is streaming through.|2
#
# 1858|Regie|Everyone is getting ready for war at the battlements. Aragorn is sitting on the steps. He sees a young lad in armour holding a sword looking around nervously.|2
#
# 1864|Regie|Aragorn gives the battered sword a few swings.|2
#
# 1868|Regie|He hands the sword back to Haleth and leans close to him, putting a hand on his shoulder.|2
#
# 1874|Regie|Back at the armoury, Aragorn dons his battle gear. His sword is handed to him as he reaches for it. He nods and accepts the sword from Legolas.|2
#
# 1880|Regie|They smile and clap one another on the shoulders. They look at Gimli as he walks up to them, struggling with his chain mail.|2
#
# 1882|Regie|He drops the bundle and the chain mail lands with its length right to the floor.|2
#
# 1884|Regie|Aragorn and Legolas bite back smiles. Just then, a horn sounds in the background|2
#
# 1886|Regie|They run out to the battlements.|2
#
# 1888|Regie|The guards look down in wonderment.|2
#
# 1890|Regie|to another guard|2
#
# 1894|Regie|An army of Lothlorien Elves march up the Causeway into the Hornburg. They are led by Haldir. The Rohirrim soldiers look upon them in wonderment and delight as they pass.|2
#
# ...
#
# 1904|Regie|Legolas and Haldir clasp each other on the shoulder.|2
#
# 1906|Regie|Turning to Theoden|2
#
# 1908|Regie|Men and Elves are in their positions on the battlements of Helm's Deep. The sounds of a marching army move closer and closer. The women and children in the caves hear the sounds overhead and are frightened. Mothers draw their children close and try to sooth crying babies. The men and Elves look out into the darkness, lit by the thousands of torches carried by the huge advancing Uruk-hai army and the light bouncing off their armour. With a row of Elf archers, Gimli is standing beside Legolas behind a wall, only the top of his helmet visible.|2
#
# 1910|Regie|Grumbling and straining to look above the wall.|2
#
# 1912|Regie|Legolas smirks. Aragorn approaches and stands beside them|2
#
# 1916|Regie|Thunder sounds and lightning flashes, revealing the sea of approaching Uruk-hai.|2
#
# 1922|Regie|The marching and thumping grows louder and louder. Lightning flashes and it begins to rain. While the Uruk-hai army continues to march at the fortress, an Uruk-hai leader steps on a rock outcrop.|2
#
# 1924|Regie|Aragorn is giving commands to the Elf warriors.|2
#
# 1928|Regie|The Uruk-hai leader raises his swords and commands his army to stop with a terrifying animalic cry. The Uruks stop and growl in anticipation of the upcoming battle and slaughter|2
#
# 1930|Regie|Jumping and straining to see|2
#
# 1932|Regie|Looks at Gimli with a grin|2
#
# 1934|Regie|Laughs good-naturedly|2
#
# 1936|Regie|The Uruk Leader cries out once, encouraging the Uruk-hai to start roaring and thumping their spears furiously.The women and children in the caves huddle together in fear. Suddenly, Aldor, the old man next to Haleth, loses his grip and releases his arrow prematurely, shooting an Uruk-hai in the neck.|2
#
# 1940|Regie|The Uruk-hai army stop their roaring and thumping. With a hollow groan, the Uruk that was shot collapsed to the ground. The other Uruk-hai bare their teeth and roar with anger. With a cry, the Uruk-hai leader thrusts his weapon in the air and the Uruk-hai army starts charging.|2
#
# 1946|Regie|The Elves notch their arrow and aim.|2
#
# 1952|Regie|Arrows rain down on the Uruk-hai below, killing many.|2
#
# 1958|Regie|to the men|2
#
# 1966|Regie|More arrows are released. But the Uruk-hai army keep advancing, with more replacing those fallen.|2
#
# 1970|Regie|Impatiently|2
#
# 1972|Regie|The Uruk-hai start to load ladders onto the walls, pushing them up with their long spears.|2
#
# 1976|Regie|The Elves draw their blades in preparation for combat. The first ladders are almost reaching the walls with big nasty Uruk Berserkers on top of them.|2
#
# 1982|Regie|Close combat begins as the Uruk-hai climb over the wall.|2
#
# 1984|Regie|Holding up two fingers|2
#
# 1988|Regie|OutragedHe turns to a Uruk just climbing over the wall, whacking it in the groin with his axe and killing it as it falls.|2
#
# 1990|Regie|Fires two arrows|2
#
# 1994|Regie|The Ent Moot is still in progress. The Ents sway a little as they continue to deliberate. Merry and Pippin are sitting a distance away. Suddenly, Treebeard nods and turns to the hobbits.|2
#
# 1996|Regie|Gesturing|2
#
# 1998|Regie|Long pause with his eyes closed.|2
#
# 2000|Regie|Angles his head in query|2
#
# 2006|Regie|impatiently|2
#
# 2008|Regie|Waving a hand|2
#
# 2012|Regie|Merry and Pippin roll their eyes in disgruntlement.|2
#
# 2016|Regie|Gimli is standing on the wall between two ladders, hacking away at Uruk-hai as they come up|2
#
# 2020|Regie|Camera pans over the Uruk-hai below and turns to the Causeway. A group of Uruk-hai is advancing on the Causeway towards the gate in tortoise formation, using their broad shields to block off attacks.|2
#
# 2022|Regie|Directs the Elf archers to aim at the Uruk-hai column.|2
#
# 2024|Regie|The Elf archers release their arrows. The Uruk-hai at the sides are shot and fall down the Causeway. But the column keeps advancing.|2
#
# 2028|Regie|At the bottom of the Deeping Wall, two spiky bombs are lodge in the sluice gate. The rest opens a path and an Uruk-hai carrying a torch starts to run towards the sluice gate. Aragorn spots the Uruk-hai.|2
#
# 2030|Regie|Legolas shoots the Uruk-hai in the shoulder but the latter keeps going|2
#
# 2032|Regie|Legolas shoots the Uruk again. It stumbles and then throws it self and the torch at the bombs. An enormous explosion is set off, blowing away a large part of the wall. Rock, debris and bodies are thrown up. Aragorn is also thrown back by the force of the explosion and on the ground, knocked out. Theoden looks on in shock as the Uruk-hai streams in past the Deeping Walls.|2
#
# 2036|Regie|Gimli sees the Uruk-hai charging in with Aragorn in their path. With a cry, he jumps down from the wall and lands on the Uruk-hai army, taking them out as he stands.|2
#
# 2040|Regie|He is soon overpowered. Aragorn gets up and sees Gimli falling.|2
#
# 2042|Regie|He yells to the Elves behind him|2
#
# 2044|Regie|The arrows take out the first group of Uruk-hai coming through the hole in the wall.|2
#
# 2048|Regie|Aragorn leads the Elves in a charge towards the Uruk-hai streaming in. He rushes to Gimli's side and picks him up. At the top of the battlements, Legolas grabs a shield and sends it sliding across the ground. He then hops onto it and surfs down the steps, releasing three arrows as he goes, and kicking the shield to stab an Uruk-hai as he lands at the bottom.|2
#
# 2052|Regie|At the Ent Moot|2
#
# 2060|Regie|The Ents look at one another, taken back|2
#
# 2064|Regie|Merry is putting on his jacket. Pippin approaches him slowly|2
#
# 2068|Regie|Looking into the distance.Turns to Pippin and puts a hand on his shoulder|2
#
# 2070|Regie|Pippin looks after Merry as he walks away.|2
#
# 2078|Regie|Haldir nods and turns back. Gimli is being carried away, kicking and struggling as he goes|2
#
# 2080|Regie|Protesting|2
#
# 2082|Regie|HALDIR HACKS AT A FEW URUK AS HE TURNS TOWARDS THE GATE. SUDDENLY, HE IS STABBED IN HIS ARM.|2
#
# 2084|Regie|and looks down as his wound in seeming disbelief. An Uruk-hai comes up from behind him unnoticed and slices him on the neck. As Haldir goes down, he looks around him and sees his kin fallen among dead Uruk-hai.|2
#
# 2086|Regie|Sees Haldir fallingHe runs up the steps to Haldir's side and catches him and he collapses. Haldir's head rolls back, his eyes empty and unseeing. Aragorn bows his head in grief. Then with a cry, he jumps onto a ladder and swings down to the ground, killing as he goes.|2
#
# 2092|Regie|Drawing his sword|2
#
# 2094|Regie|Theoden and his commanders come to the gate, which is under heavy attack. The Uruk-hai are knocking down the gate and hacking through the broken wood. Theoden stabs at an Uruk-hai and receives a lance in his shoulder, blocked by his armour. Grimacing in pain, Theoden continues to stab at the Uruk until led away by Gamling.|2
#
# 2100|Regie|Runs up and stabs away at the Uruk-hai through the broken gate|2
#
# 2110|Regie|Aragorn and Gimli slip out a side exit and stand on a ledge just to the side of the main gate. Aragorn peeks over, seeing the large band of Uruk-hai storming the gate.|2
#
# 2116|Regie|Gimli takes a peek and then steps back.|2
#
# 2118|Regie|Mumbles|2
#
# 2124|Regie|Aragorn nods slowly and then turns to grab the Dwarf.|2
#
# 2126|Regie|Gimli stays Aragorn's hand|2
#
# 2130|Regie|He tosses Gimli to the head of the Causeway and then leaps over.|2
#
# 2132|Regie|Making quick work of killing the Uruk-hai|2
#
# 2134|Regie|On the other side of the gate|2
#
# 2148|Regie|Men are bracing the gate with wood and nails. Aragorn and Gimli continue to fight off the Uruk-hai just outside. Meanwhile the Uruk-hai load and fires enormous hooks over the battlements. Hundred of Uruk-hai climb onto super-ladders as they are pulled up towards the walls, the super-ladders locking onto the edge of the battlements with their steel grips. Legolas takes aim as another super-ladder is being pulled up and shoots away one of the ropes. The ladder falls back onto the Uruk-hai army.|2
#
# 2152|Regie|Through a crack in the gate|2
#
# 2154|Regie|Legolas calls to them from the top of the battlements|2
#
# 2156|Regie|He throws them a rope|2
#
# 2158|Regie|Aragorn grabs Gimli in one hand and the rope with the other as they are pulled up the wall. Just then the Uruk-hai load and fires enormous hooks over the battlements. Hundred of Uruk-hai climb onto super-ladders as they are pulled up towards the walls, the super-ladders locking onto the edge of the battlements with their steel grips. Legolas takes aim as another super-ladder is being pulled up and shoots away one of the ropes. The ladder falls back onto the Uruk-hai army.|2
#
# 2174|Regie|They all run towards the keep, Legolas firing two arrows into the Uruk-hai army as he goes.|2
#
# 2178|Regie|Treebeard is walking through the forest, carrying Merry and Pippin. The hobbits look dejected.|2
#
# 2182|Regie|Pippin suddenly looks up with a gleam in his eyes.|2
#
# 2184|Regie|Treebeard comes to a stop.|2
#
# 2198|Regie|Faramir and company draws close to Osgiliath.|2
#
# 2204|Regie|With tears in his eyes|2
#
# 2206|Regie|Faramir hesitates for a moment.|2
#
# 2208|Regie|He presses them on|2
#
# 2212|Regie|Frodo and Sam are pushed on towards Osgiliath|2
#
# 2216|Regie|Treebeard, Merry and Pippin come to the southern edge of the forest.|2
#
# 2218|Regie|He sees the desolated landscape of tree stumps that used to be forested grounds|2
#
# 2222|Regie|With tears in his eyesHis gaze turns to the treeless Isengard and its smoking caverns|2
#
# 2224|Regie|He lets out a ferocious roar that echoes through the forest|2
#
# 2228|Regie|Merry and Pippin turn around as they hear rumbles from the forest. They see many Ents emerging and marching towards them|2
#
# 2236|Regie|Osgiliath is still under siege as Faramir and company arrives, dodging arrows and falling rocks.|2
#
# 2240|Regie|Frodo suddenly seems stricken|2
#
# 2248|Regie|Frodo sees that Sam is speaking to him but he hears nothing. His senses are overcome.|2
#
# 2252|Regie|Sam breaks away as they are being led away.|2
#
# 2258|Regie|A boulder crashes into a tower overhead and shatters it. Suddenly, Frodo's eyes roll up and he stares at Faramir strangely.|2
#
# 2262|Regie|In a faraway voice|2
#
# 2264|Regie|Looking upHe grabs the hobbits and thrusts them into a corner.To his men|2
#
# 2268|Regie|Banners of the White Hand are flying from the battlements of Helm's Deep. The Hornburg is overrun with Uruk-hai. Theoden and company are in the hall of the keep.|2
#
# 2272|Regie|Carrying a table with Legolas to shore up the door of the hall|2
#
# 2274|Regie|In the Glittering Caves, the women and children cry in fear as they hear the battering ram banging on the door.|2
#
# 2278|Regie|There is no answer.|2
#
# 2286|Regie|Pause|2
#
# 2288|Regie|A light of determination shines in his eyes|2
#
# 2294|Regie|Aragorn looks up at a window to see faint light streaming through. He recalls Gandalf's words.|2
#
# 2300|Regie|Gimli runs up the steps to the horn of Helm Hammerhand|2
#
# 2304|Regie|He mounts his horse and puts on his helmet. The sound of the horn rumbles through Helm's Deep as Gimli blows with gusto.|2
#
# 2308|Regie|Theoden leads the charge out of the keep into the Hornburg, slashing away at the Uruk-hai as they go. Without pause, they storm out of the gate and down the Causeway, right into the column of waiting Uruk-hai. In the midst of battle, Aragorn looks east and sees a white rider against the rising sun|2
#
# 2314|Regie|Coming up from behindHe raises a hand|2
#
# 2316|Regie|Riders move up behind Eomer.|2
#
# 2318|Regie|Looking to the east|2
#
# 2322|Regie|The Rohirrim and the White Rider charge down the slope. Half the Uruk-hai army turns to face the challenge, bearing their spears down towards the riders. As the riders draw closer, the sun rises behind them, momentarily blinding the Uruk-hai who raise the hands and spears to shield their eyes. The riders crash right into the Uruk-hai and engage them in battle.|2
#
# 2326|Regie|The Ents are stomping over Isengard, swinging their huge limbs, throwing and stamping on Orcs and rolling huge boulders over the ground. An Ent is pulled down with chains by some Orcs, who immediately jump on and hacks away at his wooden limbs. Saruman rushes out onto the balcony of Orthanc and stares at the pandemonium in incredulity. Merry and Pippin also throws stones at Orcs, their aims true.|2
#
# 2332|Regie|Two Ents rock a wooden structure and push it over into the caverns below, smashing against the rock. Some Orcs fire flamed-tipped arrows at an Ent, setting him on fire. Saruman continues to look about from his balcony, helpless. Some Ents are now breaking away at a dam.|2
#
# 2336|Regie|The dam is broken and Saruman looks up to see the river rushing down the slope towards Isengard, washing away Orcs and wooden structures in its path.|2
#
# 2338|Regie|The hobbits tighten their hold on top of Treebeard|2
#
# 2342|Regie|Treebeard braces himself against the flood. As the water rushes over Isengard, an Ent rushes in and thrusts his burning body into the water. The water rushes into the caverns, washing away the bridges, mechanisms and structures within.|2
#
# 2346|Regie|Frodo walks slowly away from the safe corner. Gondorian Rangers are still running about, defending their stations.|2
#
# 2350|Regie|SLOW MOTION Frodo walks up some stairs and stands on a bridge. A Nazgul on a Fell beast emerges in front of him. Frodo stares at the Nazgul, fixated. Feeling the call of the Ring, he holds it up. Faramir watches the unfolding tableau from below. As Frodo moves to put the Ring on his finger and the Nazgul flies closer and closer, Sam runs up and knocks Frodo over. Faramir releases an arrow and shoots the Fell Beast. Frodo and Sam roll down the stairs. As they come to a stop at the bottom, Frodo holds Sam in a death grip, yells and points Sting at his throat, his eyes livid with madness and anger that someone would try to take the Ring away.|2
#
# 2354|Regie|With tears running down his face|2
#
# 2356|Regie|The madness fades and recognition returns to Frodo's eyes. He realises what he nearly did and is overcome. Stumbling backwards, he collapses against a wall and Sting falls to the ground with a clang. Sam gets up slowly.|2
#
# 2358|Regie|Slowly and with despair|2
#
# 2360|Regie|Getting up slowlyHe stands and leans against a wall, looking out into the distance.Images of the riders winning the battle against the Uruk-hai at Helm's Deep|2
#
# 2362|Regie|He raises his sword with a victorious cry|2
#
# 2364|Regie|The women and children welcome the men as they return. Eowyn runs up to Aragorn and embraces him, crying tears of relief.Isengard is flooded. Merry and Pippin looks on from their perch on Treebeard. On the balcony, Saruman stumbles back into his chamber|2
#
# 2370|Regie|Standing in a corner, even Gollum seems moved. Faramir walks over and comes to kneel in front of Frodo|2
#
# 2378|Regie|Sam shakes the ranger's hand from his shoulder. Frodo looks up at Faramir with gladness. Over in the realm of Rohan, Gandalf, Theoden and company ride to the top of a slope, looking towards the Mountain of Fire in the distance.|2
#
# 2382|Regie|Frodo and Sam are walking through the woods, away from Osgiliath.|2
#
# 2392|Regie|Frodo turns to look at Sam.|2
#
# 2398|Regie|smilingHe turns to walk on|2
#
# 2400|Regie|DreamilyHe gives his backpack a heave and follows Frodo|2
#
# 2402|Regie|Gollum is crouching a short distance away|2
#
# 2414|Regie|Twists the branch of a tree|2
#
# 2416|Regie|Scuttles and hides behind a tree|2
#
# 2420|Regie|Bites on his finger and nods eagerly|2
#
# 2424|Regie|Backs away against a tree|2
#
# 2426|Regie|He looks in the direction of the hobbits|2
#
# 2432|Regie|Softly and sinisterly|2
#
# 2440|Regie|He pops out from hiding in front of the hobbits.|2
#
# 2444|Regie|He turns to walk on, with Frodo and Sam following behind.|2
#
# 2448|Regie|Camera pans up over the forest and Ephel D'ath to reveal the desolation of Mordor. To the left of the frame is the glowing Eye of Sauron atop Barad-dur, and to the right of the frame is the fiery Mount Doom. Three Fell Beasts circle the dark skies. Lightning flashes as the scene fades to black.|2

# %% [markdown]
# ### Regieanweisungen als zusammenhängender Text

# %%
# Tabellen mit Regieanweisungen laden
regie_1 = pd.read_csv('data/lotr_skript_1_regie.csv', sep='|')
regie_2 = pd.read_csv('data/lotr_skript_2_regie.csv', sep='|')
regie_3 = pd.read_csv('data/lotr_skript_3_regie.csv', sep='|')

# %%
# Funktion um Regieanweisungen als zusammenhängenden Text aus der Tabelle zu extrahieren
def get_regie_text(regie_df, filmNr):

    # Anzahl der Rows
    length = len(regie_df)

    # Range
    range = np.arange(0, length, 1)

    # empty Textvariable
    text = ""

    # Text als String
    for index in range:
        rowText = regie_df["Text"].values[index]
        text = text + f'{rowText} '

    # save to file
    filename = f'lotr_skript_{filmNr}_regie.txt'
    # Datei löschen, falls sie existiert:
    if os.path.exists(f'data/{filename}'):
        os.remove(f'data/{filename}')

    with open(f'data/{filename}', 'a') as f:
        f.write(text)
        # text in lower case
        # f.write(text.lower())
        print(f'File {filename} saved.')

# %%
# Regieanweisungen zu Skript 1 als Text
get_regie_text(regie_1, 1)

# Regieanweisungen zu Skript 2 als Text
get_regie_text(regie_2, 2)

# Regieanweisungen zu Skript 3 als Text
get_regie_text(regie_3, 3)
# Out:
# File lotr_skript_1_regie.txt saved.
# File lotr_skript_2_regie.txt saved.
# File lotr_skript_3_regie.txt saved.

# %% [markdown]
# ## 2.) Dialogtexte zu Skript 1, 2, 3

# %% [markdown]
# **Datenquelle:** bearbeitete (reduzierte) Tabelle von James Tauber
#
# **Was wurde geändert?** (händisch in Excel)
# * i-Tags gelöscht
# * eckige Klammern gelöscht
# * "VO" in Speaker-Spalte gelöscht
# * Passagen auf Elbisch
#     * wenn ÜS hintendran in runden Klammern: Elbisch gelöscht, aber Übersetzung aus Klammern behalten
#     * wenn ÜS in Spalte Translation: Elbischer Text in Subtitle-Spalte durch ÜS aus Translations-Spalte ersetzt
# * Spalte "Spoken text if different from subtitles" wurde übernommen, d.h. Text in Subtitle-Spalte wurde durch den Text aus dieser Spalte ersetzt
# * sonstige Anweisungen in runden Klammern gelöscht
# * Spalten "START" und "END" mit den Time Codes wurden gelöscht
# * Rows mit "TITLE" in der Sprecherspalte

# %% [markdown]
# ### Alter Code zu Skript 2

# %%
#lotr_1 = requests.get('https://imsdb.com/scripts/Lord-of-the-Rings-Fellowship-of-the-Ring,-The.html')
lotr_2 = requests.get('https://imsdb.com/scripts/Lord-of-the-Rings-The-Two-Towers.html')
#lotr_3 = requests.get('https://imsdb.com/scripts/Lord-of-the-Rings-Return-of-the-King.html')

scripts_2 = [lotr_2]

# %%
def get_scripts():
    # Schleife für jedes Script
    for movie, script in enumerate(scripts_2, 1):
        # webscrape text
        soup = BeautifulSoup(script.text, 'lxml')
        all_character_tags = soup.find('pre')
        
        # convert scraped bs4 element tags to string
        text= str(all_character_tags)
        
        # delete all tags
        text= re.sub(r'</?[a-zA-Z]+>', '', text)
        
        # split intoTextblocs 
        # Problem: mehrere Trenner - \r\n\r\n und \r\n \r\n)
        blocs = re.split(r'(\r\n\s?\r\n)', text)
        
        # delete empty blocs (does not work yet!!!!)
        # nice to have, but not necessarily needed
        # blocs = [i for i in blocs if i != '\r\n \r\n' or i != '\r\n\r\n']

        # print(blocs)
        
        # PRINT ALL BLOCS
        #for num, bloc in enumerate(blocs):
         #   print(num, bloc)
        
        # PRINT ONLY REGIEANWEISUNGEN
        #counter = 0
        #for num, bloc in enumerate(blocs):
            # matches Regieanweisungen, d.h. alle Blöcke, die direkt mit [ beginnen
            #if(re.match(r'^\s*\[', bloc)):
               # counter += 1
               # print(num, bloc)
        #print(f'Anzahl der Regieanweisungen: {counter}')
        # Ergenbis: 363 (ohne die Regieanweisungen, die direkt hinter demTextstehen!)
        # Gesamtzahl an Regieanweisungen: 671 (Ergebnis der Suche nach [ in Skript 2)
        
        # PRINT ONLY SPRECHERTEXT
        #counter = 0
        #for num, bloc in enumerate(blocs):
           #  matches Sprechertext, d.h. alle Blöcke, die nicht mit [ beginnen
            #if(not re.match(r'^\s*\[', bloc)):
               # counter += 1
                # Sprechername ausgeben
                #if (re.match(r'^.*(?=(\r\n))', bloc)):
                   # name = re.match(r'^.*(?=(\r\n))', bloc).group(0)
                   # print(f'Name: {name}')
                # Sprechertext ausgeben
               # print(num, bloc)
                
       # print(f'Anzahl der Sprechertexte: {counter}')
        
        # WRITE TO CSV
        
        # Dateiname festlegen
        filename = f'lotr_skript2_test.csv'

        # Datei löschen, falls sie existiert:
        if os.path.exists(f'data/{filename}'):
            os.remove(f'data/{filename}')
            
            
        with open(f'data/{filename}', 'a') as f:
            # Spaltenüberschriften
            f.write(f'Nr.|Sprecher/Regie|Text|Filmnr.\n')
            print(f'Nr.|Sprecher/Regie|Text|Filmnr.\n')
                
            # Blöcke durchgehen
            for num, bloc in enumerate(blocs):
                # Leerzeichen entfernen und Fragezeichen ersetzen (erzeugt beim Ausführen sonst Unicode-Error)
                bloc = bloc.replace("�", "%")   
                
                # match Regieanweisungen d.h. alle Blöcke, die direkt mit [ beginnen
                if(re.match(r'^\s*\[', bloc)):
                    # remove whitespace
                    regieText = bloc.strip()
                    regieText = re.sub(r'\r\n', '', regieText) # Zeilenumbrüche innerhalb des Texts
                    regieText = re.sub(r'\s+', ' ', regieText) # mehrfache Leerzeichen werden zu einem
                    
                    # write to CSV
                    # Bsp: 1 | Regie | Frodo jumps. |                  
                    f.write(f'{num}|Regie|{regieText}|2\n')
                    print(f'{num}|Regie|{regieText}|2\n')
                    
                # match Sprechertext, d.h. alle Blöcke, die NICHT direkt mit [ beginnen
                elif(not re.match(r'^\s*\[', bloc)):
                    # überflüssiger whitespace vor dem Namen entfernen
                    # positives Lookahead, matched jegliche Art whitespace vor dem ersten Buchstaben
                    sprecherText = re.sub(r'^\s*(?=([a-zA-Z]))', "", bloc)
                    
                    # matched alles vor dem ersten Zeilenumbruch, d.h. den Sprechernamen
                    if (re.match(r'^.*(?=(\r\n))', sprecherText)):
                        # Name ohne Whitespace aus demTextherausziehen
                        # group(0) wird benötigt, um auf denTextim Match-Objekt zuzugreifen, das von re.match zurückgegeben wird
                        name = re.match(r'^.*(?=(\r\n))', sprecherText).group(0).strip()
                        
                        # alles vor dem ersten Zeilenumbruch (inkl. Name wird gelöscht)
                        sprecherText = re.sub(r'^.*\r\n', '', sprecherText)
                        sprecherText = sprecherText.strip()
                        sprecherText = re.sub(r'\r\n', '', sprecherText) # Zeilenumbrüche innerhalb des Texts
                        sprecherText = re.sub(r'\s+', ' ', sprecherText) # mehrfache Leerzeichen werden zu einem
                        
                        # write to CSV
                        # only write if name is not empty (otherwise there will be empty rows in between)
                        if(name != ""):
                            f.write(f'{num}|{name}|{sprecherText}|2\n')
                            print(f'{num}|{name}|{sprecherText}|2\n')
                    else:
                        f.write(f'{num}|Sprechertext|{sprecherText}|2 \n')
                        print(f'{num}|Sprechertext|{sprecherText}|2\n')
                
get_scripts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7612/4120921857.py in <module>
#     111                         print(f'{num}|Sprechertext|{sprecherText}|2\n')
#     112
# --> 113 get_scripts()
#
# ~\AppData\Local\Temp/ipykernel_7612/4120921857.py in get_scripts()
#       1 def get_scripts():
#       2     # Schleife für jedes Script
# ----> 3     for movie, script in enumerate(scripts_2, 1):
#       4         # webscrape text
#       5         soup = BeautifulSoup(script.text, 'lxml')
#
# NameError: name 'scripts_2' is not defined

# %% [markdown]
# ### Alte Codeschnipsel

# %%
# replacement notes - examples 

 # 930 CAMERA CIRCLES SUMMIT:
                # CAMERA CIRCLES SUMMIT: MORE AND MORE TREES are hauled down and
                
                # 1067 PAN ONTO:
                # ringwraiths close behind PAN ONTO: 2 more ringwrait
                
                # 1709 PAN OFF:
                # PAN OFF: DENETHOR'S DEATH PLUNGE to the ROHIRRIM
                
                # 1071 CRANE DOWN:
                # CRANE DOWN: As the White Horse races towards Camera, 
                
                # 1622 Slow motion:
                # Slow motion: As the Balrog falls, he lashes out with his whip of fire... Slow motion: The thongs of the whip lash 
                
                # 1743 QUICK CUTS:
                # QUICK CUTS: LURTZ is quickly armored...
                
                # BLACK SCREEN: und BLACK SCREEN und BLACK SCREEN . . . (3 und 6 Skript 3)
                
                # 44 SETTLE ON:
                # SETTLE ON: FRODO and SAM in a FILTHY CULVERT. 
                
                # 122 PUSH IN:
                # PUSH IN: EOWYN standing alone outside the GOLDEN HALL
                
                # 660 PULL BACK:
                # PULL BACK: GANDALF hurries to the BATTLEMENT
                
                # 977 CAMERA CRANES to REVEAL:
                # CAMERA CRANES to REVEAL: THOUSANDS of MEN and HORSES!
                
                # 1224 QUICK BEAT:
                # QUICK BEAT: ARAGORN RAISES ANDURIL
                
                # 1437 TRACKING BACK: 
                # TRACKING BACK: with FRODO as he careers blindly 
                
                # 2397 TRACKING:
                # TRACKING: Passing under a beautiful ELVEN ARCHWAY 
                
                # 1533 REVEAL ON:
                # REVEAL ON: SAMWISE GAMGEE stands before the GIANT SPIDER 
                
                # 2294 SOARING UP:
                # SOARING UP: to REVEAL the COURT OF THE KINGS
                
                # 2332 MATCHING MOVE:
                # MATCHING MOVE: Revealing HOBBITON bathed in a WARM SUNSET 
                
                # 2450 Screenplay by: Fran Walsh, Philippa Boyens, Peter Jackson

# %%
# delete irrelevant information
        # voice over and cont'd
        #text = re.sub(r'\s*\(V.O.\)\s*\(cont\'d\)', '', text)
        #text = re.sub(r'\s*V/0', '', text)
        #text = re.sub(r'\s*\( V .O .\)\s*\(c on t\' d \)', '', text)
        #text = re.sub(r'\s*\(cont\'d\)', '', text)
        #text = re.sub(r'\s*\(c ont \'d \)', '', text)
        #text = re.sub(r'\s*\(c ont\' d\)','', text)
        #text = re.sub(r'\s*\(V.O.\)\s*\(CONT\'D\)', '', text)
        #text = re.sub(r'\s*\(CONT\'D\)', '', text)
        #text = re.sub(r'\s*\(V.O.\)', '', text)
        #text = re.sub(r'\s*\(0.S.\)', '', text)
        #text = re.sub(r'\s*\( O . S . \)', '', text)
        #text = re.sub(r'\s*\(O.S.\)', '', text)

# %%
# info related to page turns
        #text = re.sub(r'\s*Final Revision - October, 2003 [0-9]+.', '', text)
        #text = re.sub(r'\s*\(CONTINUED\)\s*[0-9]*\.?', '', text)
        #text = re.sub(r'\s*\(M�RE\)', '', text)
        #text = re.sub(r'\s*\(MORE\)', '', text)
    
        #text = re.sub(r'CONTINUED:\s\(\s?[0-9]\s?\)', '\n', text)
        #text = re.sub(r'CONTINUED:', '\r\n\r\n', text)
        
        # matches page numbers (that do not have "continued" before or after it)
        # but does not match the only number in the text: "1296...a very good year" by only matching if there is not more than one .
        #text = re.sub(r'\s*[0-9]{1,3}\.[^\.]\s*', '\r\n\r\n', text)

# %%
# Sätze zusammenführen (wenn Text in Zelle auf "..." endet und nächste Zelle mit "..." beginnt)
subtitle_column = dialog_1["SUBTITLE TEXT"]
for num, element in enumerate(subtitle_column.array):
        if(not pd.isna(element) and num < 1793):
                nextElement = subtitle_column.array[num+1]
                if(re.search(r'\.\.\.$', element)and re.search(r'^\.\.\.', nextElement)):
                    element = f'{element} {nextElement}'
                #print(num, subtitle_column.array[num], subtitle_column.array[num+1])
        # re.search takes all lines of input string into account, re.match only the first line
        # check if string ends with "..."
        #thisElement = str(dialog_1["SUBTITLE TEXT"].iloc[[num]])
        #nextElement = str(dialog_1["SUBTITLE TEXT"].iloc[[num +1]])
        #if(re.search(r'\.\.\.$', thisElement) and re.search(r'^\.\.\.', nextElement)):
        #if(re.search(r'\.\.\.$', thisElement)):
            #print(dialog_1["SUBTITLE TEXT"].iloc[[num, num +1]])
# check if next x rows start with "..."
# concat all those rows
#data["Name"]= data["Name"].str.cat(new, sep =", ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23276/2766184149.py in <module>
#       1 # Sätze zusammenführen (wenn Text in Zelle auf "..." endet und nächste Zelle mit "..." beginnt)
# ----> 2 subtitle_column = dialog_1["SUBTITLE TEXT"]
#       3 for num, element in enumerate(subtitle_column.array):
#       4         if(not pd.isna(element) and num < 1793):
#       5                 nextElement = subtitle_column.array[num+1]
#
# NameError: name 'dialog_1' is not defined

# %%
# filter lines that contain speech
speech = lotr[(lotr["Sprecher/Regie"] != "Regie")]

# remove text INSIDE square brackets (these are stage directions and unwanted)

for index, row in speech.iterrows():
    # remove text inside square brackets AND ALSO' brackets themselves
    speech.at[index, "Text"] = re.sub("\[[^\]]*\]", "", speech.at[index, "Text"])
    # strip to remove whitespace in beginning and end
    speech.at[index, "Text"] = speech.at[index, "Text"].strip()

# print lines for control
for index, row in speech.iterrows():
    #if "[" in row["Text"]:
        print(index, row["Text"])

# reset index and Nr.-column
count = 1
for index, row in speech.iterrows():
    speech.at[index, "Nr."] = count
    count += 1
speech.reset_index(drop=True, inplace=True)
# Out:
# 11 You cannot pass!
# 12 Gandalf!
# 13 I am a servant of the Secret Fire, wielder of the Flame of Anor!
# 15 Argh! Go back to the shadow. The Dark Fire will not avail you, Flame of Udun!  YOU SHALL NOT... PASS!!!
# 17 Argh!
# 19 No! No!
# 20 Gandalf!
# 21 Fly, you fools!
# 23 Noooooooooooooooo!!!!
# 25 Gaaandaaaaalf!!
# 27 Gandalf!
# 28 What is it, Mr. Frodo?
# 29 Nothing. Just a dream.
# 31 Mordor. The one place in Middle-earth we don't want to see any closer, and the one place we're trying to get to. It's just where we can'tt get. Let's face it, Mr. Frodo, we're lost. I don't think Gandalf meant for us to come this way.
# 32 He didn't mean for a lot of things to happen, Sam... but they did.
# 34 Mr. Frodo? It's the Ring, isn't it?
# 35 It's getting heavier.
# 36 What food have we got left?
# 37 Well, let me see.  Oh yes, lovely Lembas bread. And look!  More lembas bread.
# 39 I don't usually hold with foreign food, but this Elvish stuff, it's not bad.
# 40 Nothing ever dampens your spirits, does it Sam?
# 42 Those rain clouds might.
# 44 This looks strangely familiar.
# 45 It's because we've been here before! We're going in circles.
# 46 Ah! What's that 'orrid stink? I'll warrant there's a nasty bog nearby. Can you smell it?
# 47 Yes. I can smell it.  We're not alone.
# 49 The thieves! The thieves! The filthy little thieves! Where is it? Where isss it? They stole it from us. My preciousss.  Curse them! We hates them! It's ours, it is... and we wantssss it!
# 51 This is Sting. You've seen it before, haven't you... Gollum! Release him or I'll cut your throat!
# 53 It burns! It burns us! It freezes! Nasty Elves twisted it. Take it off us!
# 54 Quiet you!
# 56 It's hopeless! Every Orc in Mordor's going to hear this racket! Let's just tie him up and leave him.
# 57 No! That would kill us! Kill us!
# 58 It's no more than you deserve!
# 59 Maybe he does deserve to die, but now that I see him, I do pity him.
# 60 We be nice to them if they be nice to us. Take it off us. We swears to do what you wants. We swears.
# 61 There's no promise you can make that I can trust.
# 62 We swears to serve the master of the preciousss. We swears on... on the precious. *Gollum. Gollum.*
# 63 The Ring is treacherous. It will hold you to your word.
# 64 Yes... on the preciousss. On the preciousss.
# 65 I don't believe you!  Get down! I said, down!
# 67 Sam!
# 68 He's trying to trick us! We let him go he'll throttle us in our sleep!
# 70 You know the way to Mordor?
# 71 Yes...
# 72 You've been there before?
# 73 Yes...
# 75 You will lead us to the Black Gate.
# 79 Merry. Merry!
# 81 What is it? What do you smell?
# 82 Man-flesh.
# 83 Aragorn!
# 84 They've picked up our trail! Let's move!
# 87 Their pace has quickened.  They must have caught our scent. Hurry!
# 88 Come on, Gimli!
# 89 Three days' and nights' pursuit. No food. No rest. And no sign of our quarry but what bare rock can tell.
# 91 Not idly do the leaves of Lorien fall.
# 92 They may yet be alive.
# 93 Less than a day ahead of us. Come!
# 95 Come, Gimli! We are gaining on them!
# 96 I am wasted on cross-country! We dwarves are natural sprinters! Very dangerous over short distances!
# 99 Rohan. Home of the horse-lords. There is something strange at work here. Some evil gives speed to these creatures, sets its will against us.
# 101 Legolas, what do your Elf eyes see?
# 102 The Uruks turn northeast. They're taking the hobbits to Isengard!
# 103 Saruman.
# 106 The world is changing.  Who now has the strength to stand against the armies of Isengard and Mordor? To stand against the might of Sauron and Saruman and the union of the two towers?
# 108 Together, my lord Sauron, we shall rule this Middle-earth.
# 110 The old world will burn in the fires of industry. The forests will fall. A new order will rise. We will drive the machine of war with the sword and the spear and the iron fists of the Orc. We have only to remove those who oppose us.
# 112 The horsemen took your land. They drove your people into the hills to scratch a living off rocks.
# 113 Murderers!
# 114 Take back the lands they stole from you! Burn every village!
# 115 Argh!!
# 117 It will begin in Rohan. Too long have these peasants stood against you. But no more.
# 119 Eothain! Eothain! You take your sister. You'll go faster with just two.
# 120 Papa says Eothain must not ride Garulf, he is too big for him!
# 121 Listen to me. You must ride to Edoras and raise the alarm. Do you understand me?
# 122 Yes, Ma!
# 123 I don't wanna leave! I don't wanna go, Mama!
# 124 Freda, I will find you there.
# 126 Quickly!
# 128 Go child!
# 130 Rohan, my lord, is ready to fall.
# 133 Theodred!
# 136 Your son is badly wounded, my lord.
# 137 That is a lie!  Saruman the White has ever been our friend and ally.
# 138 Grima. Grima. My son...? Grima...?
# 139 Orcs are roaming freely across our lands. Unchecked. Unchallenged. Killing at will. Orcs bearing the white hand of Saruman.
# 140 Why do you lay these troubles on an already troubled mind. Can you not see? Your uncle is wearied by your malcontent, your war-mongering.
# 141 War-mongering?
# 143 How long is it since Saruman bought you? What was the promised price, Grima? When all the men are dead you will take your share of the treasure?
# 145 Too long have you watched my sister, too long have you haunted her steps.
# 147 You see much Eomer, Son of Eomund. Too much.  You are banished forthwith from the kingdom of Rohan. Under pain of death!
# 150 Keep breathing! That's the key! Breathe! Ho!
# 151 They've run as if the very whips of their masters were behind them.
# 153 We're not going no further till we've had a breather!
# 154 Get a fire going!
# 156 Merry! Merry!
# 157 I think... we might have made a mistake leaving the Shire, Pippin.
# 159 What's making that noise?
# 160 It's the trees.
# 161 What?
# 162 Do you remember the Old Forest? On the borders of Buckland? Folk used to say that there was something in the water that made the trees grow tall... and come alive.
# 163 Alive?
# 164 Trees that could whisper. Talk to each other. Even move.
# 165 I'm starving. We ain't 'ad nothin' but maggoty bread for three stinkin' days!
# 166 Yeah. Why can'tt we have some meat?  What about them? They're fresh.
# 167 They are not for eating!
# 168 What about their legs? They don't need those. Ooh! They look tasty!
# 169 Get back, scum!
# 171 Carve them up!
# 172 Just a mouth full.
# 173 No!
# 175 Looks like meat's back on the menu, boys!!
# 177 Pippin, let's go.
# 179 Go on, call for help. Squeal! No one's gonna save you now!
# 181 Pippin!
# 183 ARGH!!!
# 186 A red sun rises. Blood has been spilled this night.
# 188 Riders of Rohan, what news from the Mark?
# 190 What business does an Elf, a man and a Dwarf have in the Riddermark? Speak quickly!
# 191 Give me your name, Horsemaster, and I shall give you mine.
# 193 I would cut off your head, Dwarf, if it stood but a little higher from the ground.
# 195 You would die before your stroke fell!
# 197 I am Aragorn, son of Arathorn. This is Gimli, son of Gloin and Legolas of the Woodland realm. We are friends of Rohan and of Theoden, your king.
# 198 Theoden no longer recognizes friend from foe.  Not even his own kin.
# 200 Saruman has poisoned the mind of the king and claimed lordship over these lands. My company are those loyal to Rohan. And for that, we are banished. The White Wizard is cunning. He walks here and there, they say, as an old man, hooded and cloaked. And everywhere his spies slip past our nets.
# 201 We are not spies. We track a party of Uruk-hai westward across the plain. They've taken two of our friends captive.
# 202 But there were two hobbits. Did you see two hobbits with them?
# 203 They would be small, only children to your eyes.
# 204 We left none alive. We piled the carcasses and burned them.
# 205 Dead?
# 206 I am sorry.
# 209 Look for your friends. But do not trust to hope, it has forsaken these lands.  We ride north!
# 211 It's one of their wee belts.
# 212 Hiro 'th' ab 'wanath... (May they find peace in death)
# 213 AAARRGGHH!!!
# 214 We failed them.
# 216 A hobbit lay here, and the other.  They crawled.
# 218 Their hands were bound.  Their bonds were cut.
# 219 They ran over here. They were followed.
# 221 The belt!
# 223 Run!
# 224 The tracks lead away from the battle...  into Fangorn Forest.
# 226 Fangorn. What madness drove them in there?
# 229 Did we lose him?  I think we lost him.
# 231 I'm gonna rip out your filthy little innards! Come here!
# 233 Trees! Climb a tree!
# 235 He's gone.
# 237 Merry!
# 239 Hooooo...
# 240 Argh!!
# 242 Let's put a maggot-hole in your belly.
# 243 Run, Merry!
# 245 Little Orcs! Burarum...
# 246 It's talking, Merry. The tree is talking!
# 247 Tree?! I am no tree. I am an Ent.
# 248 A treeherder! A shepherd of the forest.
# 249 Don't talk to it, Merry. Don't encourage it.
# 250 Treebeard, some call me.
# 251 And whose side are you on?
# 252 Side? I am on nobody's side because nobody's on my side, little Orc. Nobody cares for the woods anymore.
# 253 We're not Orcs. We're Hobbits!
# 254 Hobbits? Never heard of a hobbit before. Sounds like Orc mischief to me!  They come with fire, they come with axes. Gnawing, biting, breaking, hacking, burning! Destroyers and usurpers, curse them!
# 255 No, you don't understand. We're Hobbits... Halflings! Shirefolk!
# 256 Maybe you are and maybe you aren't. The White Wizard will know.
# 257 The White Wizard?
# 258 Saruman.
# 262 See, see, we have led you out! Hurry hobbitses hurry. Very lucky we find you.
# 264 Nice hobbit.
# 266 Whoa, it's a bog! He's led us into a swamp!
# 267 A swamp, yes, yes. Come, master. We will take you on safe paths through the mist. Come, hobbits, come. We go quickly.
# 269 I found it, I did. The way through the marshes. Orcs don't use it. Orcs don't know it. They go round for miles and miles. Come quickly. Swift and quick as shadows we must be.
# 271 There are dead things! Dead faces in the water!
# 272 All dead. All rotten. Elves and men and orcses. A great battle long ago.  The Dead Marshes. Yes, yes that is their name. This way. Don't follow the lights.
# 274 Ohh!
# 275 Careful now, or hobbits go down to join the dead ones and light little candles of their own.
# 277 Frodo!
# 279 Gollum...
# 280 Don't follow the lights!
# 281 Mr. Frodo! Are you alright?
# 285 Sooo bright. Sooo beautiful.  our preciousss...
# 286 What did you say?
# 287 Master should be resting. Master needs to keep up his strength.
# 288 Who are you?
# 289 Mustn't ask us. Not its business. *Gollum, Gollum*
# 290 Gandalf told me you were one of the River Folk.
# 291 Cold be heart and hand and bone. Cold be travellers far from home.
# 292 He said your life was a sad story.
# 293 They do not see what lies ahead, when sun has failed and moon is dead.
# 294 You were not so very different from a hobbit once, were you... Smeagol?
# 295 What did you call me?
# 296 That was your name once, wasn't it? A long time ago.
# 297 My name... My name... S... S...Smeagol.
# 299 Argh!!
# 300 Black Riders!
# 301 Hide! Hide!
# 302 Argh!
# 304 Argh!!
# 305 C'mon Frodo! C'mon!
# 307 Quick! They will see us! They will see us!
# 308 I thought they were dead!
# 309 Dead? No, you cannot kill them. No.
# 311 Wraiths! Wraiths on wings! They are calling for it. They are calling for the preciousss.
# 313 Mr. Frodo! It's alright. I'm here.
# 315 Hurry, hobbits. The Black Gate is very close.
# 318 Ptui! Orc blood.
# 319 These are strange tracks.
# 320 The air is so close in here.
# 321 This forest is old. Very old. Full of memory... and anger.
# 323 The trees are speaking to each other.
# 324 Gimli!
# 325 Huh?
# 326 Lower your axe.
# 327 Oh.
# 328 Aragorn, nad n' ennas! (Something is out there.)
# 329 Man cenich? (What do you see?)
# 331 The White Wizard approaches.
# 332 Do not let him speak. He will put a spell on us.
# 334 We must be quick.
# 336 You are tracking the footsteps of two young hobbits.
# 337 Where are they?
# 338 They passed this way the day before yesterday. They met someone they did not expect. Does that comfort you?
# 339 Who are you? Show yourself!
# 341 It cannot be. You fell.
# 342 Through fire and water.  From the lowest dungeon to the highest peak, I fought with the Balrog of Morgoth.
# 344 Until at last, I threw down my enemy and smote his ruin upon the mountainside.
# 346 Darkness took me. And I strayed out of thought and time.  Stars wheeled overhead and everyday was as long as a life-age of the earth. But it was not the end. I felt life in me again.
# 348 I've been sent back until my task is done.
# 349 Gandalf!
# 350 Gandalf? Yes... That's what they used to call me. Gandalf the Grey. That was my name.
# 351 Gandalf!
# 352 I am Gandalf the White.  And I come back to you now at the turn of the tide.
# 354 One stage of your journey is over, another begins. War has come to Rohan. We must ride to Edoras with all speed.
# 356 That is one of the Mearas, unless my eyes are cheated by some spell.
# 358 Shadowfax.  He's the lord of all horses and he's been my friend through many dangers.
# 362 My home lies deep in the forest near the roots of the mountain. I told Gandalf I would keep you safe and safe is where I'll keep you. The trees have grown wild and dangerous. Anger festers in their hearts. They will harm you if they can. There are too few of us now. Too few of us Ents left to manage them.
# 365 The Black Gate of Mordor.
# 367 Oh save us. My ol' Gaffer'd have a thing or two to say if he could see us now.
# 368 Master says to show him the way into Mordor, so good Smeagol does. Master says so.
# 369 I did.
# 371 That's it then. We cannot get past that.
# 373 Look! The gate, it's opening! I can see a way down.
# 375 Sam, no!
# 376 Argh!!
# 378 Master!
# 380 I do not ask you to come with me, Sam.
# 381 I know, Mr Frodo. I doubt even these Elvish cloaks will hide us in there.
# 383 Now!
# 385 No! No, no master! They catch you! They catch you! Don't take it to him! He wants the preciousss. Always he's looking for it! And the preciousss is wanting to go back to him. But we mustn't let him have it.
# 387 No!  There's another way. More secret. A dark way.
# 388 Why haven't you spoken of this before?!
# 389 Because Master did not ask!
# 390 He's up to something.
# 391 Are you saying there's another way into Mordor?
# 392 Yes. There is a path, and some stairs, and then...a tunnel.
# 393 He's led us this far, Sam.
# 394 Mr. Frodo, no.
# 395 He's been true to his word.
# 396 No!
# 397 Lead the way, Smeagol.
# 398 Good Smeagol always helps.
# 401 Edoras and the Golden Hall of Meduseld. There dwells Theoden, King of Rohan, whose mind is overthrown. Saruman's hold over King Theoden is now very strong.
# 404 Will you not go to him?  Will you do nothing?
# 406 Be careful what you say. Do not look for welcome here.
# 410 Oh, he ... he must have died sometime in the night. What a tragedy for the king to lose his only son and heir.
# 412 I understand his passing is hard to accept, especially now that your brother has deserted you.
# 413 Leave me alone, snake!
# 414 Oh, but you are alone! Who knows what you have spoken to the darkness. In bitter watches of the night, when all your life seems to shrink, the walls of your bower closing in about you, like a hutch to trammel some wild thing in.
# 416 So fair, so cold, like a morning of pale spring still clinging to winter's chill.
# 418 Your words are poison!
# 420 You'll find more cheer in a graveyard.
# 422 Ah.
# 423 I cannot allow you before Theoden-King so armed, Gandalf Greyhame. By order of Grima Wormtongue.
# 425 Your staff.
# 426 Hmm?  Oh. You would not part an old man from his walking stick?
# 428 My lord, Gandalf the Grey is coming. He's a herald of woe.
# 429 The courtesy of your hall is somewhat lessened of late, Theoden King.
# 431 He's not welcome.
# 432 Why should I welcome you, Gandalf Stormcrow?
# 433 A just question, my liege.  Late is the hour in which this conjurer chooses to appear. Lathspell spell I name him. Ill news is an ill guest.
# 434 Be silent! Keep your forked tongue behind you teeth. I have not passed through fire and death to bandy crooked words with a witless worm!
# 435 His staff!  I told you to take the wizard's staff!
# 437 Theoden, son of Thengel, too long have you sat in the shadows.
# 439 I would stay still, if I were you.
# 440 Hearken to me! I release you from the spell.
# 441 Hahahhhahahahah!  You have no power here, Gandalf the Grey!
# 443 Argh!
# 444 I will draw you, Saruman, as poison is drawn from a wound.
# 446 Wait.
# 447 If I go. . . Theoden dies.
# 449 You did not kill me, you will not kill him!
# 450 Rohan is mine!
# 451 Be gone!!
# 453 I know your face. Eowyn Eowyn.
# 455 Gandalf?
# 456 Breathe the free air again, my friend.
# 458 Dark have been my dreams of late.
# 459 Your fingers would remember their old strength better... if they grasped your sword.
# 461 Argh!  I've only ever served you, my lord!
# 462 Your leechcraft would have had me crawling on all fours like a beast!
# 463 Send me not from your side.
# 465 No, my lord! No, my lord. Let him go. Enough blood has been spilled on his account.
# 467 Get out of my way!
# 468 Hail, Theoden king!
# 470 Where is Theodred? Where is my son?
# 473 Simbelmyn'. Ever has it grown on the tombs of my forebearers.  Now it shall cover the grave of my son. Alas, that these evil days should be mine. The young perish and the old linger. That I should live to see the last days of my house.
# 474 Theodred's death was not of your making.
# 475 No parent should have to bury their child.
# 477 He was strong in life. His spirit will find its way to the halls of your fathers. Westu h'l. Fer'u, Theodred, Fer'u. (Be-thou well. Go-thou, Theodred, go-thou.)
# 479 They had no warning. They were unarmed. Now the wildmen are moving through the Westfold, burning as they go. Rick, cot and tree.
# 480 Where's mama?
# 481 Shh...
# 482 This is but a taste of the terror that Saruman will unleash. All the more potent for he is driven now by fear of Sauron. Ride out and meet him head on. Draw him away from your women and children.  You must fight.
# 483 You have two thousand good men riding north as we speak. Eomer is loyal to you. His men will return and fight for their king.
# 484 They will be three hundred leagues from here by now. Eomer cannot help us. I know what it is that you want of me. But I will not bring further death to my people. I will not risk open war.
# 486 Open war is upon you. Whether you would risk it or not.
# 487 When last I looked, Theoden, not Aragorn, was king of Rohan.
# 489 Then what is the king's decision?
# 491 By order of the king, the city must empty. We make for the refuge of Helm's Deep. Do not burden yourselves with treasures. Take only what provisions you need.
# 493 Helm's Deep! They flee to the mountains when they should stand and fight. Who will defend them if not their king.
# 494 He's only doing what he thinks is best for his people. Helm's Deep has saved them in the past.
# 496 There is no way out of that ravine. Theoden is walking into a trap. He thinks he's leading them to safety. What they will get is a massacre. Theoden has a strong will but I fear for him. I fear for the survival of Rohan. He will need you before the end, Aragorn. The people of Rohan will need you. The defences HAVE to hold.
# 497 They will hold.
# 498 The Grey Pilgrim... that's what they used to call me. Three hundred lives of men I've walked this earth and now I have no time. With luck, my search will not be in vain. Look to my coming at first light on the fifth day. At dawn, look to the East.
# 499 Go.
# 503 You have some skill with a blade.
# 505 Women of this country learned long ago: Those without swords may still die upon them. I fear neither death nor pain.
# 506 What do you fear, my lady?
# 507 A cage. To stay behind bars until use and old age accept them and all chance of valor has gone beyond recall or desire.
# 508 You are a daughter of kings, a shieldmaiden of Rohan.  I do not think that would be your fate.
# 512 Theoden will not stay at Edoras. It's vulnerable, he knows this. He will expect an attack on the city. They will flee to Helm's Deep, the great fortress of Rohan. It is a dangerous road to take through the mountains. They will be slow. They will have women and children with them.
# 514 Send out your warg riders.
# 518 Hey Stinker! Don't go getting too far ahead!
# 519 Why do you do that?
# 520 What?
# 521 Call him names; run him down all the time.
# 522 Because ... because that's what he is, Mr. Frodo. There's naught left in 'im but lies and deceit. It's the Ring he wants. It's all he cares about.
# 523 You have no idea what it did to him. What it's still doing to him.  I want to help him, Sam...
# 524 Why?
# 525 Because I have to believe he can come back.
# 526 You can'tt save him, Mr. Frodo.
# 527 What do you know about it? Nothing!
# 529 I'm sorry, Sam. I don't know why I said that.
# 530 I do. It's the Ring. You can't take your eyes off it. I've seen you. You're not eating. You barely sleep. It's taken a hold of you, Mr Frodo. You have to fight it!
# 531 I know what I have to do Sam. The Ring was entrusted to me! It's my task! Mine! My own!
# 532 Can't you hear yourself? Don't you know who you sound like?
# 536 We wants it. We needs it. Must have the precioussss. They stole it from us. Sneaky little hobbitsesss. Wicked, trickssssy, falssse!
# 537 No! Not Master.
# 538 Yes, precious. False. They will cheat you, hurt you, lie.
# 539 Master's my friend.
# 540 You don't have any friends. Nobody likes YOU...
# 541 Not listening. I'm not listening.
# 542 You're a liar and a thief.
# 543 Nope.
# 544 Murderer!
# 545 Go away.
# 546 Go away!  HAHAHAHA!!
# 547 I hate you. I hate you!
# 548 Where would you be without me? *Gollum, gollum*. I saved us. It was me. We survived because of me!
# 549 Not anymore.
# 550 What did you say?
# 551 Master looks after us now. We don't need you.
# 552 What?
# 553 Leave now and never come back.
# 554 No!!
# 555 Leave now and never come back!
# 556 Arrrgh!!!
# 557 LEAVE. NOW. AND. NEVER. COME. BACK!
# 559 We... we told him to go away! And away he goes, preciousss.  Gone, gone, gone! Smeagol is free!
# 561 Look! Look! See what Smeagol finds! Hehehe! Hahaha!
# 563 They are young. They are tender. They are nice. Yes they are! Eat them! Eat them!
# 565 You'll make him sick, you will, behaving like that!  There's only one way to eat a brace of coneys.
# 567 Argh!! What's it doing! Stupid fat hobbit! It ruins it!
# 568 What's to ruin? There's hardly any meat on them.
# 570 What we need is a few good taters.
# 571 What's taters, preciousss? What's taters uh?
# 572 PO-TAY-TOES! Boil them. Mash them. Stick them in a stew. Lovely big golden chips with a nice piece of fried fish....
# 573 Pbbbttt!!
# 574 Even you couldn't say no to that.
# 575 Oh yes we could! Spoil nice fish...  Give it to usss rrraw... and wrrriggling!  You keep nasty chips.
# 576 You're hopeless.
# 578 Mr. Frodo?
# 580 Who are they?
# 581 Wicked men. Servants of Sauron. They are called to Mordor. The Dark One is gathering all armies to him. It won't be long now. He will soon be ready.
# 582 Ready to do what?
# 583 To make his war. The last war that will cover all the world in shadow.
# 584 We've got to get moving. Come on, Sam.
# 585 Mr Frodo! Look! It's an Oliphaunt!
# 587 No one at home will believe this...
# 589 Smeagol?
# 591 We've lingered here too long. Come on, Sam!
# 593 Ah!
# 595 Bind their hands.
# 598 It's true you don't see many Dwarf women. And in fact, they are so alike in voice and appearance, haha that they're often mistaken for Dwarf men.
# 600 It's the beards....
# 601 And this, in turn, has given rise to the belief that there are no Dwarf women. And that dwarves just spring out of holes in the ground!
# 602 Hahahaha!!
# 603 Hehehe! Which is of course ridiculous. Whoa!!
# 605 It's alright, it's alright. Nobody panic. That was deliberate. It was deliberate.
# 607 The light of the Evenstar does not wax and wane' It is mine to give to whom I will... Like my heart. Go to sleep...
# 609 I am asleep. This is a dream.
# 610 Then it is a good dream. Sleep.
# 612 Min l' pennich nin i aur hen telitha. (You told me once that this day would come.)
# 613 ' i vethed... n' i onnad. Boe bedich go Frodo. Han b'd l'n. (This is not the end... it is the beginning. You must go with Frodo. That is your path.)
# 614 Dolen i v'd o nin. (My path is hidden from me.)
# 615 Si peliannen i v'd na dail l'n. Si boe '-dhannathach. (It is already laid before your feet. You cannot falter now.)
# 616 Arwen ...
# 618 Ae '-esteliach nad... estelio han. Estelio ammen. (If you trust nothing else... trust this. Trust us.)
# 623 Our time here is ending. Arwen ...s time is ending. Let her go. Let her take the ship into the west. Let her bear away her love for you to the Undying Lands. There it will be evergreen.
# 624 But never more than a memory.
# 625 I will not leave my daughter here to die.
# 626 She stays because she still has hope.
# 627 She stays for YOU! She belongs with her people!
# 629 Idhren emmen menna gui ethwel. Hae o auth a n'r a naeth. (You have a chance for another life. Away from war... grief... despair.)
# 630 Why are you saying this?
# 631 I am mortal; you are Elfkind. It was a dream, Arwen, nothing more.
# 633 This belongs to you.
# 634 It was a gift. Keep it.
# 636 She is sailing to the Undying Lands, with all that is left of her kin.
# 638 What is it? Hama?
# 640 I'm not sure.
# 642 Wargs!
# 644 Argh!  A scout!
# 645 What is it? What do you see?
# 646 Wargs! We are under attack!
# 648 Get them out of here!
# 649 All riders to the head of the column!
# 650 Come on, get me up here, I'm a rider! Argh!
# 652 You must lead the people to Helm's Deep. And make haste!
# 653 I can fight!
# 654 No! You must do this... for me.
# 656 Follow me! Yah!
# 657 Forward. I mean, charge forward! March forward!  That's it! Go on!
# 658 Make for the lower ground! Stick together!
# 661 Argh!!
# 662 CHARGE!!
# 664 Bring your pretty face to my axe!
# 666 Argh! That one counts as mine!
# 668 Argh! Stinking creature. Argh!
# 670 Ooh..!
# 672 Oooh!!
# 674 Aragorn!
# 675 Aragorn?
# 677 Tell me what happened and I will ease your passing.
# 678 He's  dead.  Took a little tumble off the cliff.
# 679 You lie!
# 681 Get the wounded on horses. The wolves of Isengard will return. Leave the dead.
# 683 Come.
# 687 Helm's Deep! At last! There it is!
# 688 We're safe, my lady! Thank you!
# 690 Mama!
# 691 Eothain! Freda!
# 693 Make way for Theoden!
# 694 Sire!
# 695 Make way for the king!
# 697 So few. So few of you have returned.
# 698 Our people are safe. We have paid for it with many lives.
# 699 My lady...
# 700 Lord Aragorn, where is he?
# 701 He fell...
# 705 Draw all our forces behind the wall. Bar the gate, and set a watch on the surround.
# 706 What of those who cannot fight, my lord? The women and children?
# 707 Get them into the caves.  Saruman's arm would have grown long indeed if he thinks he can reach us here.
# 709 Helm's Deep has one weakness. Its outer wall is solid rock but for a small culvert at its base which is little more than a drain.
# 711 How? How can fire undo stone? What kind of device could bring down the wall?
# 713 If the wall is breached, Helm's Deep will fall.
# 715 Even if it is breached, it would take a number beyond reckoning, thousands to storm the keep.
# 716 Tens of thousands.
# 717 But, my lord, there is no such force.
# 719 A new power is rising. Its victory is at hand!
# 721 This night, the land will be stained with the blood of Rohan! March to Helms Deep! Leave none alive!
# 723 To war!!
# 725 There will be no dawn for Men.
# 729 Look! There's smoke to the south!
# 730 There is always smoke rising from Isengard these days.
# 731 Isengard?
# 733 There was a time when Saruman would walk in my woods. But now he has a mind of metal and wheels. He no longer cares for growing things.
# 735 What is it?
# 736 It's Saruman's army! The war has started.
# 739 May the grace of the Valar protect you.
# 741 Brego.
# 743 Arwen.
# 745 Tollen i l'. I chair gwannar na Valannor. Si bado, no c'rar. (Arwen, it is time. The ships are leaving for Valinor. Go now... before it is too late.)
# 746 I have made my choice.
# 747 He is not coming back. Why do you linger here when there is no hope?
# 748 There is still hope.
# 749 If Aragorn survives this war, you will still be parted. If Sauron is defeated, and Aragorn made king and all that you hope for comes true, you will still have to taste the bitterness of mortality. Whether by the sword or the slow decay of time, Aragorn will die.
# 751 And there will be no comfort for you. No comfort to ease the pain of his passing. He will come to death, an image of the splendor of the kings of men in glory undimmed before the breaking of the world.
# 753 But you, my daughter, you will linger on in darkness and in doubt. As nightfall in winter that comes without a star. Here you will dwell, bound to your grief, under the fading trees, until all the world is changed and the long years of your life are utterly spent.
# 755 Arwen... there is nothing for you here, only death.
# 757 A im, '-'erin veleth l'n? (Do I not also have your love?)
# 758 Gerich meleth n'n, ada. (You have my love, father)
# 761 I amar prestar aen... han mathon ne nen, han mathon ne chae a han nostan ned gwilith. (The world has changed... I feel it in the water, I feel it in the earth, I smell it in the air.) The power of the enemy is growing.  Sauron will use his puppet Saruman to destroy the people of Rohan. Isengard has been unleashed.  The eye of Sauron now turns to Gondor, the last free kingdom of men.  His war on this country will come swiftly. He senses the Ring is close. The strength of the Ringbearer is failing. In his heart, Frodo begins to understand.  The quest will claim his life. You know this. You have foreseen it. It is the risk we all took.
# 763 In the gathering dark, the will of the Ring grows strong. It works hard now to find its way back into the hands of men.
# 765 Men, who are so easily seduced by its power. The young captain of Gondor has but to extend his hands, take the Ring for his own and the world will fall. It is close now, so close to achieving its goal.
# 767 For Sauron will have dominion of all life on this Earth, even unto the ending of the world. The time of the Elves is over.
# 769 Do we leave Middle-earth to its fate? Do we let them stand alone?
# 772 What news?
# 773 Our scouts report Saruman has attacked Rohan. Theoden's people have fled to Helm's Deep.  But we must look to our own borders. Faramir, Orcs are on the move. Sauron is marshalling an army. Easterlings and Southrons are passing through the Black Gate.
# 774 How many?
# 775 Some thousands. More come every day.
# 776 Who's covering the river to the north?
# 777 We pulled 500 men at Osgiliath, but if the city is attacked, we won't hold it.
# 778 Saruman attacks from Isengard. Sauron from Mordor. The fight will come to men on both fronts. Gondor is weak. Sauron will strike us soon. And he will strike hard. He knows now we do not have the strength to repel him.
# 780 My men tell me that you are Orc spies.
# 781 Spies?! Now wait just a minute!
# 782 Well if you're not spies, then who are you?
# 784 Speak.
# 785 We are hobbits of the Shire. Frodo Baggins is my name and this is Samwise Gamgee.
# 786 Your bodyguard?
# 787 His gardener.
# 788 And where is your skulking friend? That gangrel creature. He had an ill-favoured look.
# 789 There was no other.
# 791 We set out from Rivendell with seven companions. One we lost in Moria. Two were my kin. A Dwarf there was also, and an Elf. And two men, Aragorn, son of Arathorn, and Boromir of Gondor.
# 792 You're a friend of Boromir?
# 793 Yes... for my part.
# 794 It will grieve you then to learn that he is dead.
# 795 Dead? How? When?
# 796 As one of his companions, I'd hoped you would tell me.  He was my brother.
# 799 Captain Faramir.  We found the third one.
# 801 You must come with me. Now.
# 803 Down there.
# 805 To enter the forbidden pool bears the penalty of death.  They wait for my command.
# 807 Shall I shoot?
# 809 The rock and pool is nice and cool, so juicy sweet! I only wish  to catch a fish , so juicy sweet!
# 811 Wait!  This creature is bound to me. And I to him. He is our guide. Please, let me go down to him.
# 813 Smeagol.  Master is here. Come, Smeagol. Trust master. Come!
# 815 We must go now?
# 816 Smeagol, you must trust master. Follow me, come on. Come. Come, Smeagol. Nice Smeagol. That's it. Come on.
# 818 Don't hurt him! Smeagol don't struggle! Smeagol listen to me!
# 819 Master!!
# 821 No! No!
# 822 Where are you leading them? Answer me!
# 823 Smeagol... Why does it cry, Smeagol?
# 824 Cruel men hurts us. Master trickst us.
# 825 Of course he did. I told you he was tricksy. I told you he was false.
# 826 Master is our friend... our friend.
# 827 Master betrayed us.
# 828 No, not its business. Leave us alone!
# 829 Filthy little hobbitses. They stole it from us.
# 830 No... No!
# 831 What did they steal?
# 832 Myyy PRECIOUSSS!!  Aaaarrrggghhh!!!
# 835 We have to get out of here. You go. Go, now! You can do it. Use the Ring, Mr. Frodo. Just this once. Put it on. Disappear.
# 836 I can'tt. You were right, Sam. You tried to tell me, but ... I'm sorry. The Ring's taking me Sam. If I put it on, he'll find me. He'll see.
# 837 Mr. Frodo...
# 839 So... this is the answer to all the riddles. Here in the wild I have you. Two halflings and a host of men at my call. The Ring of power within my grasp.
# 841 A chance for Faramir, captain of Gondor, to show his quality.
# 843 No!!
# 844 Stop it! Leave him alone! Don't you understand? He's got to destroy it. That's where we're going. Into Mordor. To the mountain of fire.
# 846 Osgiliath is under attack. They call for reinforcements.
# 847 Please. It's such a burden. Will you not help him?
# 848 Captain?
# 849 Prepare to leave. The Ring will go to Gondor.
# 853 Mae carnen, Brego, mellon n'n. (Well done, Brego, my friend)
# 855 He's alive!
# 856 Where is he? Where is he? Get out of the way. I'm gonna kill him!  You are the luckiest, the canniest and the most reckless man I ever knew!  Bless you, laddie!
# 857 Gimli, where is the king?
# 859 Le ab-dollen. (You're late.)  You look terrible.
# 861 Hannon le. (Thank you.)
# 864 A great host, you say?
# 865 All Isengard is emptied
# 866 How many?
# 867 Ten thousand strong at least.
# 868 Ten thousand?!
# 869 It is an army bred for a single purpose: to destroy the world of men. They will be here by nightfall.
# 870 Let them come!
# 872 I want every man and strong lad able to bear arms to be ready for battle by nightfall.
# 874 We will cover the causeway and the gate from above. No army has ever breached the Deeping Wall or set foot inside the Hornburg.
# 875 This is no rabble of mindless Orcs. These are Uruk-hai. Their armor is thick and their shields broad.
# 876 I have fought many wars, Master Dwarf. I know how to defend my own keep.
# 878 They will break upon this fortress like water on rock. Saruman's hordes will pillage and burn, we've seen it before. Crops can be resown; homes rebuilt. Within these walls, we will outlast them.
# 879 They do not come to destroy Rohan's crops or villages. They come to destroy its people. Down to the last child.
# 880 What would you have me do? Look at my men. Their courage hangs by a thread. If this is to be our end, then I would have them make such an end as to be worthy of remembrance.
# 881 Send out riders, my lord. You must call for aid.
# 882 And who will come? Elves? Dwarves? We are not so lucky in our friends as you. The old alliances are dead.
# 883 Gondor will answer.
# 884 Gondor? Where was Gondor when the Westfold fell? Where was Gondor when our enemies closed in around us? Where was Gon' ' No, my lord Aragorn, we are alone.  Get the women and children into the caves.
# 885 We need more time to lay provisions for a siege, lord.
# 886 There is no time. War is upon us!
# 887 Secure the gate!
# 891 We Ents have not troubled about the wars of men and wizards for a very long time. But now something is about to happen that has not happened for an age... Ent Moot.
# 892 What's that?
# 893 'Tis a gathering.
# 894 A gathering of what?
# 896 Beech, oak, chestnut, ash... Good, good, good. Many have come. Now we must decide if the Ents will go to war.
# 900 Move back! Move to the caves!
# 901 Keep moving!
# 902 Quickly now!
# 904 Farmer, farriers, stable boys. These are no soldiers.
# 905 Most have seen too many winters.
# 906 Or too few. Look at them. They're frightened. I can see it in their eyes.  Boe a h'n: neled herain dan caer menig! (And they should be... Three hundred against ten thousand!)
# 907 Si beriathar h'n. Amar n' ned Edoras. (They have more hope of defending themselves here than at Edoras.)
# 908 Aragorn, men i ndagor. H'n '-... ortheri. Natha daged aen! (Aragorn, we are warriors. They cannot win this fight. They are all going to die!)
# 909 Then I shall die as one them!
# 910 Let him go, lad. Let him be.
# 913 Every villager able to wield a sword has been sent to the armory. My lord?
# 914 Who am I, Gamling?
# 915 You are our king, sire.
# 916 And do you trust your king?
# 917 Your men, my lord, will follow you to whatever end.
# 919 To whatever end. Where is the horse and the rider? Where is the horn that was blowing? They have passed like rain on the mountains. Like wind in the meadow. The days have gone down in the west. Behind the hills, into shadow. How did it come to this?
# 922 Give me your sword. What is your name?
# 923 Haleth, son of Hama, my lord. The men are saying that we will not live out the night. They say that it is hopeless..
# 925 This is a good sword, Haleth, son of Hama.
# 927 There is always hope.
# 930 We have trusted you this far. You have not led us astray. Forgive me. I was wrong to despair.
# 931 '-moe edhored, Legolas. (There is nothing to forgive, Legolas.)
# 933 If we had more time I'd get this adjusted.  It's a little tight across the chest.
# 935 That is no Orc horn.
# 937 Send for the king. Open the gate!
# 938 Open the gate!
# 940 How is this possible?
# 941 I bring word from Elrond of Rivendell. An alliance once existed between Elves and men. Long ago we fought and died together.  We come to honor that allegiance.
# 942 Mae govannen, Haldir. (Welcome, Haldir)
# 943 You are most welcome!
# 945 We are proud to fight alongside men, once more.
# 947 You could have picked a better spot.
# 949 Well lad, whatever luck you live by, let's hope it lasts the night.
# 951 Your friends are with you, Aragorn.
# 952 Let's hope they last the night.
# 955 A Eruch'n, '-dano i faelas a hyn an uben tanatha le faelas! (Show them no mercy! For you shall receive none!)
# 957 What's happening out there?
# 958 Shall I describe it to you?  Or would you like me to find you a box?
# 959 Hehehehe!!
# 961 Dartho! (Hold!)
# 963 So it begins.
# 964 Tangado halad! (Prepare to fire!)
# 966 Faeg i-varv d'n na lanc a nu ranc. (Their armor is weak at the neck and beneath the arms.)
# 967 Leithio i philinn! (Release the arrows!)
# 969 Did they hit anything?
# 970 Give them a volley.
# 971 Fire!
# 973 Fire!
# 976 Fire!
# 977 Send them to me! C'mon!
# 979 Pendraid! (Ladders!)
# 981 Swords! Swords!
# 982 Good!
# 984 Legolas, two already!
# 985 I'm on seventeen!
# 986 Argh! I'll have no pointy-ear outscoring me!
# 987 Nineteen!
# 990 Merry!
# 991 We have just agreed.
# 992 Yes?
# 993 I have told your names to the Ent moot and we have agreed ... you are not Orcs.
# 994 Well, that's good news.
# 995 And what about Saruman? Have you come to a decision about HIM?
# 996 Now don't be hasty, Master Meriadoc.
# 997 Hasty? Our friends are out there! They need our help! They cannot fight this war on their own.
# 998 War, yes. It affects us all. But you must understand, young hobbit. It takes a loong time to say anything in ooold Entish.  And we never say anything unless it is worth taking a looong time to say.
# 1001 Seventeen! Eighteen! Nineteen! Twenty! Twenty-one! Twenty-two!
# 1003 Na fennas! (Causeway!)
# 1005 Is this it? Is this all you can conjure, Saruman?
# 1007 Togo hon dad, Legolas! (Bring him down, Legolas!)  Dago hon! Dago hon! (Kill him! Kill him!)
# 1009 Brace the Gate! Hold them! Stand firm!
# 1011 Aragorn!! Argh!
# 1013 Gimli!  Hado i philinn! (Hurl the arrows!)
# 1015 Herio! (Charge!)
# 1019 The Ents cannot hold back this storm. We must weather such things as we have always done.
# 1020 How can that be your decision?!
# 1021 This is not our war.
# 1022 But you're part of this world! Aren't you?!  You must help, please! You must do something!
# 1023 You are young and brave, Master Merry. But your part in this tale is over. Go back to your home.
# 1025 Maybe Treebeard's right. We don't belong here, Merry. It's too big for us. What can we do in the end? We've got the Shire. Maybe we should go home.
# 1026 The fires of Isengard will spread. And the woods of Tuckborough and Buckland will burn. And all that was once green and good in this world will be gone.  There won't be a Shire, Pippin.
# 1029 Aragorn! Fall back to the Keep! Get your men out of there!
# 1030 Na Barad! Na Baraad! Haldir, na Barad! (To the Keep! Pull back to the Keep! Haldir, to the Keep!)
# 1032 What are you doing? Argh! What are you stopping for!
# 1035 HALDIR!!
# 1036 Brace the gate!
# 1037 Hold them!
# 1038 To the gate! Draw your swords!
# 1040 Make way! We cannot hold much longer.
# 1041 Hold them!
# 1042 How long do you need?
# 1043 Brace the gate!
# 1044 As long as you can give me!
# 1045 Gimli!
# 1046 Timbers! Brace the Gate!
# 1048 Come on! We can take them!
# 1049 It's a long way.
# 1051 Toss me.
# 1052 What?
# 1053 I cannot jump the distance! You'll have to toss me!
# 1055 Oh!  Don't tell the Elf.
# 1056 Not a word.
# 1058 ARGH!!
# 1060 Shore up the door!
# 1061 Make way!
# 1062 Follow me to the barricade.
# 1063 Watch our backs!
# 1064 Throw another one over here!
# 1065 Higher!
# 1067 Hold fast the gate!]
# 1068 Gimli! Aragorn! Get out of there!
# 1070 Aragorn!
# 1072 Pull everybody back! Pull them back!
# 1073 Fall back! Fall back!
# 1074 They've broken through! The castle is breached. Retreat!
# 1075 Fall back!
# 1076 Retreat!
# 1077 Hurry! Inside! Get them inside!
# 1078 Into the Keep!
# 1082 I will leave you at the western borders of the forest. You can make your way north to your homeland from there.
# 1084 Wait! Stop! Stop!  Turn around. Turn around. Take us south!
# 1085 South? But that will lead you past Isengard.
# 1086 Yes. Exactly. If we go south we can slip past Saruman unnoticed. The closer we are to danger, the farther we are from harm. It's the last thing he'll expect.
# 1087 Mmmm. That doesn't make sense to me. But then, you are very small. Perhaps you're right. South it is then. Hold on, little Shirelings. I always like going south. Somehow it feels like going down hill.
# 1088 Are you mad? We'll be caught!
# 1089 No we won't. Not this time.
# 1092 Look! Osgiliath burns!
# 1093 Mordor has come.
# 1094 The Ring will not save Gondor. It has only the power to destroy. Please, let me go.
# 1096 Hurry.
# 1097 Faramir, you must let me go!
# 1101 And a little family of field mice that climb up sometimes and they tickle me awfully. They're always trying to get somewhere where they ... Oh!!  Many of these trees were my friends. Creatures I had known from nut and acorn.
# 1102 I'm sorry, Treebeard.
# 1103 They had voices of their own.  Saruman! A wizard should know better!
# 1105 There is no curse in Elvish, Entish or the tongues of men for this treachery. My business is with Isengard tonight. With rock and stone!
# 1107 Yes!
# 1108 Hoorarooom... Come my friends. The Ents are going to war. It is likely that we go to our doom. Last march of the Ents!
# 1111 Faramir, Orcs have taken the eastern shore. Their numbers are too great. By nightfall we'll be overrun.
# 1113 Mr Frodo!
# 1114 It's calling to him, Sam. His eye is almost on me.
# 1115 Hold on, Mr. Frodo. You'll be alright...
# 1117 Take them to my father. Tell him Faramir sends a mighty gift. A weapon that will change our fortunes in this war.
# 1119 Do you want to know what happened to Boromir? You want to know why your brother died? He tried to take the Ring from Frodo! After swearing an oath to protect him, he tried to kill him! The Ring drove your brother mad!
# 1120 Watch out!
# 1122 Mr Frodo?
# 1123 They're here. They've come.
# 1124 NAZG'L!!  Stay here. Keep out of sight.  Take cover!
# 1127 The fortress is taken. It is over.
# 1128 You said this fortress would never fall while your men defend it! They still defend it! They have died defending it!
# 1130 They are breaking in!
# 1131 Is there no other way for the women and children to get out of the caves?  Is there no other way?
# 1132 There is one passage. It leads into the mountains. But they will not get far. The Uruk-hai are too many.
# 1133 Send word for the women and children to make for the mountain pass. And barricade the entrance.
# 1134 So much death. What can men do against such reckless hate?
# 1135 Ride out with me. Ride out and meet them.
# 1136 For death and glory.
# 1137 For Rohan. For your people.
# 1138 The sun is rising.
# 1140 Look to my coming at first light on the fifth day. At dawn, look to the east.
# 1141 Yes. Yes! The horn of Helm Hammerhand shall sound in the deep one last time!
# 1142 Yes!
# 1143 Let this be the hour when we draw swords together. Fell deeds awake. Now for wrath! Now for ruin! And a red dawn!
# 1145 FORTH EORLINGAS!!
# 1147 Gandalf.
# 1148 Theoden king stands alone.
# 1149 Not alone.  Rohirrim!!
# 1151 Eomer!
# 1152 To the king!
# 1156 Yes!
# 1157 A hit. A fine hit!
# 1159 Break the dam! Release the river!
# 1161 Pippin, hold on!
# 1162 Hold on, little hobbits!
# 1166 What are you doing? Where are you going?!
# 1168 Aaarrgghh!!!
# 1169 It's me. It's your Sam. Don't you know your Sam?
# 1171 I can'tt do this, Sam.
# 1172 I know. It's all wrong. By rights we shouldn't even be here. But we are.  It's like in the great stories, Mr. Frodo. The ones that really mattered. Full of darkness and danger they were. And sometimes you didn't want to know the end. Because how could the end be happy?  How could the world go back to the way it was when so much bad had happened?
# 1173 Victory! We have victory!
# 1174 But in the end, it's only a passing thing, this shadow.  Even darkness must pass. A new day will come.  And when the sun shines it will shine out the clearer. Those were the stories that stayed with you. That meant something, even if you were too small to understand why. But I think, Mr. Frodo, I do understand. I know now. Folk in those stories had lots of chances of turning back only they didn't. They kept going because they were holding on to something.
# 1175 What are we holding on to, Sam?
# 1176 There's some good in this world, Mr. Frodo. And it's worth fighting for.
# 1178 I think at last we understand one another, Frodo Baggins.
# 1179 You know the laws of our country, the laws of your father. If you let them go, your life will be forfeit.
# 1180 Then it is forfeit. Release them.
# 1182 Sauron's wrath will be terrible, his retribution swift. The battle for Helm's Deep is over. The battle for Middle-earth is about to begin. All our hopes now lie with two little hobbits. Somewhere in the wilderness.
# 1184 I wonder if we'll ever be put into songs or tales.
# 1185 What?
# 1186 I wonder if people will ever say, 'let's hear about Frodo and the Ring.' And they'll say 'yes, that's one of my favorite stories. Frodo was really courageous, wasn't he, dad.' 'Yes, my boy, the most famousest of hobbits. And that's saying alot.'
# 1187 Huh, you left out one of the chief characters : Samwise the Brave. I want to hear more about Sam.
# 1189 Frodo wouldn't have got far without Sam.
# 1190 Now Mr. Frodo, you shouldn't make fun. I was being serious.
# 1191 So was I.
# 1192 Samwise the Brave.
# 1194 Smeagol!
# 1195 We're not gonna wait for you. Come on!
# 1196 Master... Master looks after us. Master wouldn't hurt us.
# 1197 Master broke his promise.
# 1198 Don't ask Smeagol. Poor, poor Smeagol.
# 1199 Master betrayed us! Wicked, tricksy, false. We ought to wring his filthy little neck.  Kill him! Kill him! Kill them both. And then we take the precious and we be the master.
# 1200 The fat hobbit, he knows. Eyes always watching.
# 1201 Then we stabs them out. Put out his eyeses. And make HIM crawl.
# 1202 Yes! Yes! Yes!
# 1203 Kill them both.
# 1204 Yes! No no!  It's too risky, it's too risky.
# 1206 Where's he gone? Hey Gollum, where are you?
# 1207 Smeagol?
# 1208 We could let HER do it.
# 1209 Yes. She could do it.
# 1210 Yes, precious she could. And then we takes it once they're dead.
# 1211 Once they're dead.
# 1212 Shh.
# 1213 Come on, hobbits. Long ways to go yet. Smeagol will show you the way.
# 1215 Follow me.

# %%
# remove elvish (and westron) original lines and keep translation  

for index, row in speech.iterrows():
    # condition: must contain bracket
    if "(" in row["Text"]:
        # remove content outside brackets, regex expression idea from 41686d6564's answer at https://stackoverflow.com/questions/64740437/remove-text-outside-of-bracket
        speech.at[index, "Text"] = re.sub("[^[()]+(?=[(]|$)", "", speech.at[index, "Text"])
        # remove brackets
        speech.at[index, "Text"] = re.sub("[()]", "", speech.at[index, "Text"])
        # strip to remove whitespace in beginning and end
        speech.at[index, "Text"] = speech.at[index, "Text"].strip()

# print for control    
for index, row in speech.iterrows():
    print(index, row["Text"])
# Out:
# 0 You cannot pass!
# 1 Gandalf!
# 2 I am a servant of the Secret Fire, wielder of the Flame of Anor!
# 3 Argh! Go back to the shadow. The Dark Fire will not avail you, Flame of Udun!  YOU SHALL NOT... PASS!!!
# 4 Argh!
# 5 No! No!
# 6 Gandalf!
# 7 Fly, you fools!
# 8 Noooooooooooooooo!!!!
# 9 Gaaandaaaaalf!!
# 10 Gandalf!
# 11 What is it, Mr. Frodo?
# 12 Nothing. Just a dream.
# 13 Mordor. The one place in Middle-earth we don't want to see any closer, and the one place we're trying to get to. It's just where we can'tt get. Let's face it, Mr. Frodo, we're lost. I don't think Gandalf meant for us to come this way.
# 14 He didn't mean for a lot of things to happen, Sam... but they did.
# 15 Mr. Frodo? It's the Ring, isn't it?
# 16 It's getting heavier.
# 17 What food have we got left?
# 18 Well, let me see.  Oh yes, lovely Lembas bread. And look!  More lembas bread.
# 19 I don't usually hold with foreign food, but this Elvish stuff, it's not bad.
# 20 Nothing ever dampens your spirits, does it Sam?
# 21 Those rain clouds might.
# 22 This looks strangely familiar.
# 23 It's because we've been here before! We're going in circles.
# 24 Ah! What's that 'orrid stink? I'll warrant there's a nasty bog nearby. Can you smell it?
# 25 Yes. I can smell it.  We're not alone.
# 26 The thieves! The thieves! The filthy little thieves! Where is it? Where isss it? They stole it from us. My preciousss.  Curse them! We hates them! It's ours, it is... and we wantssss it!
# 27 This is Sting. You've seen it before, haven't you... Gollum! Release him or I'll cut your throat!
# 28 It burns! It burns us! It freezes! Nasty Elves twisted it. Take it off us!
# 29 Quiet you!
# 30 It's hopeless! Every Orc in Mordor's going to hear this racket! Let's just tie him up and leave him.
# 31 No! That would kill us! Kill us!
# 32 It's no more than you deserve!
# 33 Maybe he does deserve to die, but now that I see him, I do pity him.
# 34 We be nice to them if they be nice to us. Take it off us. We swears to do what you wants. We swears.
# 35 There's no promise you can make that I can trust.
# 36 We swears to serve the master of the preciousss. We swears on... on the precious. *Gollum. Gollum.*
# 37 The Ring is treacherous. It will hold you to your word.
# 38 Yes... on the preciousss. On the preciousss.
# 39 I don't believe you!  Get down! I said, down!
# 40 Sam!
# 41 He's trying to trick us! We let him go he'll throttle us in our sleep!
# 42 You know the way to Mordor?
# 43 Yes...
# 44 You've been there before?
# 45 Yes...
# 46 You will lead us to the Black Gate.
# 47 Merry. Merry!
# 48 What is it? What do you smell?
# 49 Man-flesh.
# 50 Aragorn!
# 51 They've picked up our trail! Let's move!
# 52 Their pace has quickened.  They must have caught our scent. Hurry!
# 53 Come on, Gimli!
# 54 Three days' and nights' pursuit. No food. No rest. And no sign of our quarry but what bare rock can tell.
# 55 Not idly do the leaves of Lorien fall.
# 56 They may yet be alive.
# 57 Less than a day ahead of us. Come!
# 58 Come, Gimli! We are gaining on them!
# 59 I am wasted on cross-country! We dwarves are natural sprinters! Very dangerous over short distances!
# 60 Rohan. Home of the horse-lords. There is something strange at work here. Some evil gives speed to these creatures, sets its will against us.
# 61 Legolas, what do your Elf eyes see?
# 62 The Uruks turn northeast. They're taking the hobbits to Isengard!
# 63 Saruman.
# 64 The world is changing.  Who now has the strength to stand against the armies of Isengard and Mordor? To stand against the might of Sauron and Saruman and the union of the two towers?
# 65 Together, my lord Sauron, we shall rule this Middle-earth.
# 66 The old world will burn in the fires of industry. The forests will fall. A new order will rise. We will drive the machine of war with the sword and the spear and the iron fists of the Orc. We have only to remove those who oppose us.
# 67 The horsemen took your land. They drove your people into the hills to scratch a living off rocks.
# 68 Murderers!
# 69 Take back the lands they stole from you! Burn every village!
# 70 Argh!!
# 71 It will begin in Rohan. Too long have these peasants stood against you. But no more.
# 72 Eothain! Eothain! You take your sister. You'll go faster with just two.
# 73 Papa says Eothain must not ride Garulf, he is too big for him!
# 74 Listen to me. You must ride to Edoras and raise the alarm. Do you understand me?
# 75 Yes, Ma!
# 76 I don't wanna leave! I don't wanna go, Mama!
# 77 Freda, I will find you there.
# 78 Quickly!
# 79 Go child!
# 80 Rohan, my lord, is ready to fall.
# 81 Theodred!
# 82 Your son is badly wounded, my lord.
# 83 That is a lie!  Saruman the White has ever been our friend and ally.
# 84 Grima. Grima. My son...? Grima...?
# 85 Orcs are roaming freely across our lands. Unchecked. Unchallenged. Killing at will. Orcs bearing the white hand of Saruman.
# 86 Why do you lay these troubles on an already troubled mind. Can you not see? Your uncle is wearied by your malcontent, your war-mongering.
# 87 War-mongering?
# 88 How long is it since Saruman bought you? What was the promised price, Grima? When all the men are dead you will take your share of the treasure?
# 89 Too long have you watched my sister, too long have you haunted her steps.
# 90 You see much Eomer, Son of Eomund. Too much.  You are banished forthwith from the kingdom of Rohan. Under pain of death!
# 91 Keep breathing! That's the key! Breathe! Ho!
# 92 They've run as if the very whips of their masters were behind them.
# 93 We're not going no further till we've had a breather!
# 94 Get a fire going!
# 95 Merry! Merry!
# 96 I think... we might have made a mistake leaving the Shire, Pippin.
# 97 What's making that noise?
# 98 It's the trees.
# 99 What?
# 100 Do you remember the Old Forest? On the borders of Buckland? Folk used to say that there was something in the water that made the trees grow tall... and come alive.
# 101 Alive?
# 102 Trees that could whisper. Talk to each other. Even move.
# 103 I'm starving. We ain't 'ad nothin' but maggoty bread for three stinkin' days!
# 104 Yeah. Why can'tt we have some meat?  What about them? They're fresh.
# 105 They are not for eating!
# 106 What about their legs? They don't need those. Ooh! They look tasty!
# 107 Get back, scum!
# 108 Carve them up!
# 109 Just a mouth full.
# 110 No!
# 111 Looks like meat's back on the menu, boys!!
# 112 Pippin, let's go.
# 113 Go on, call for help. Squeal! No one's gonna save you now!
# 114 Pippin!
# 115 ARGH!!!
# 116 A red sun rises. Blood has been spilled this night.
# 117 Riders of Rohan, what news from the Mark?
# 118 What business does an Elf, a man and a Dwarf have in the Riddermark? Speak quickly!
# 119 Give me your name, Horsemaster, and I shall give you mine.
# 120 I would cut off your head, Dwarf, if it stood but a little higher from the ground.
# 121 You would die before your stroke fell!
# 122 I am Aragorn, son of Arathorn. This is Gimli, son of Gloin and Legolas of the Woodland realm. We are friends of Rohan and of Theoden, your king.
# 123 Theoden no longer recognizes friend from foe.  Not even his own kin.
# 124 Saruman has poisoned the mind of the king and claimed lordship over these lands. My company are those loyal to Rohan. And for that, we are banished. The White Wizard is cunning. He walks here and there, they say, as an old man, hooded and cloaked. And everywhere his spies slip past our nets.
# 125 We are not spies. We track a party of Uruk-hai westward across the plain. They've taken two of our friends captive.
# 126 But there were two hobbits. Did you see two hobbits with them?
# 127 They would be small, only children to your eyes.
# 128 We left none alive. We piled the carcasses and burned them.
# 129 Dead?
# 130 I am sorry.
# 131 Look for your friends. But do not trust to hope, it has forsaken these lands.  We ride north!
# 132 It's one of their wee belts.
# 133 May they find peace in death
# 134 AAARRGGHH!!!
# 135 We failed them.
# 136 A hobbit lay here, and the other.  They crawled.
# 137 Their hands were bound.  Their bonds were cut.
# 138 They ran over here. They were followed.
# 139 The belt!
# 140 Run!
# 141 The tracks lead away from the battle...  into Fangorn Forest.
# 142 Fangorn. What madness drove them in there?
# 143 Did we lose him?  I think we lost him.
# 144 I'm gonna rip out your filthy little innards! Come here!
# 145 Trees! Climb a tree!
# 146 He's gone.
# 147 Merry!
# 148 Hooooo...
# 149 Argh!!
# 150 Let's put a maggot-hole in your belly.
# 151 Run, Merry!
# 152 Little Orcs! Burarum...
# 153 It's talking, Merry. The tree is talking!
# 154 Tree?! I am no tree. I am an Ent.
# 155 A treeherder! A shepherd of the forest.
# 156 Don't talk to it, Merry. Don't encourage it.
# 157 Treebeard, some call me.
# 158 And whose side are you on?
# 159 Side? I am on nobody's side because nobody's on my side, little Orc. Nobody cares for the woods anymore.
# 160 We're not Orcs. We're Hobbits!
# 161 Hobbits? Never heard of a hobbit before. Sounds like Orc mischief to me!  They come with fire, they come with axes. Gnawing, biting, breaking, hacking, burning! Destroyers and usurpers, curse them!
# 162 No, you don't understand. We're Hobbits... Halflings! Shirefolk!
# 163 Maybe you are and maybe you aren't. The White Wizard will know.
# 164 The White Wizard?
# 165 Saruman.
# 166 See, see, we have led you out! Hurry hobbitses hurry. Very lucky we find you.
# 167 Nice hobbit.
# 168 Whoa, it's a bog! He's led us into a swamp!
# 169 A swamp, yes, yes. Come, master. We will take you on safe paths through the mist. Come, hobbits, come. We go quickly.
# 170 I found it, I did. The way through the marshes. Orcs don't use it. Orcs don't know it. They go round for miles and miles. Come quickly. Swift and quick as shadows we must be.
# 171 There are dead things! Dead faces in the water!
# 172 All dead. All rotten. Elves and men and orcses. A great battle long ago.  The Dead Marshes. Yes, yes that is their name. This way. Don't follow the lights.
# 173 Ohh!
# 174 Careful now, or hobbits go down to join the dead ones and light little candles of their own.
# 175 Frodo!
# 176 Gollum...
# 177 Don't follow the lights!
# 178 Mr. Frodo! Are you alright?
# 179 Sooo bright. Sooo beautiful.  our preciousss...
# 180 What did you say?
# 181 Master should be resting. Master needs to keep up his strength.
# 182 Who are you?
# 183 Mustn't ask us. Not its business. *Gollum, Gollum*
# 184 Gandalf told me you were one of the River Folk.
# 185 Cold be heart and hand and bone. Cold be travellers far from home.
# 186 He said your life was a sad story.
# 187 They do not see what lies ahead, when sun has failed and moon is dead.
# 188 You were not so very different from a hobbit once, were you... Smeagol?
# 189 What did you call me?
# 190 That was your name once, wasn't it? A long time ago.
# 191 My name... My name... S... S...Smeagol.
# 192 Argh!!
# 193 Black Riders!
# 194 Hide! Hide!
# 195 Argh!
# 196 Argh!!
# 197 C'mon Frodo! C'mon!
# 198 Quick! They will see us! They will see us!
# 199 I thought they were dead!
# 200 Dead? No, you cannot kill them. No.
# 201 Wraiths! Wraiths on wings! They are calling for it. They are calling for the preciousss.
# 202 Mr. Frodo! It's alright. I'm here.
# 203 Hurry, hobbits. The Black Gate is very close.
# 204 Ptui! Orc blood.
# 205 These are strange tracks.
# 206 The air is so close in here.
# 207 This forest is old. Very old. Full of memory... and anger.
# 208 The trees are speaking to each other.
# 209 Gimli!
# 210 Huh?
# 211 Lower your axe.
# 212 Oh.
# 213 Something is out there.
# 214 What do you see?
# 215 The White Wizard approaches.
# 216 Do not let him speak. He will put a spell on us.
# 217 We must be quick.
# 218 You are tracking the footsteps of two young hobbits.
# 219 Where are they?
# 220 They passed this way the day before yesterday. They met someone they did not expect. Does that comfort you?
# 221 Who are you? Show yourself!
# 222 It cannot be. You fell.
# 223 Through fire and water.  From the lowest dungeon to the highest peak, I fought with the Balrog of Morgoth.
# 224 Until at last, I threw down my enemy and smote his ruin upon the mountainside.
# 225 Darkness took me. And I strayed out of thought and time.  Stars wheeled overhead and everyday was as long as a life-age of the earth. But it was not the end. I felt life in me again.
# 226 I've been sent back until my task is done.
# 227 Gandalf!
# 228 Gandalf? Yes... That's what they used to call me. Gandalf the Grey. That was my name.
# 229 Gandalf!
# 230 I am Gandalf the White.  And I come back to you now at the turn of the tide.
# 231 One stage of your journey is over, another begins. War has come to Rohan. We must ride to Edoras with all speed.
# 232 That is one of the Mearas, unless my eyes are cheated by some spell.
# 233 Shadowfax.  He's the lord of all horses and he's been my friend through many dangers.
# 234 My home lies deep in the forest near the roots of the mountain. I told Gandalf I would keep you safe and safe is where I'll keep you. The trees have grown wild and dangerous. Anger festers in their hearts. They will harm you if they can. There are too few of us now. Too few of us Ents left to manage them.
# 235 The Black Gate of Mordor.
# 236 Oh save us. My ol' Gaffer'd have a thing or two to say if he could see us now.
# 237 Master says to show him the way into Mordor, so good Smeagol does. Master says so.
# 238 I did.
# 239 That's it then. We cannot get past that.
# 240 Look! The gate, it's opening! I can see a way down.
# 241 Sam, no!
# 242 Argh!!
# 243 Master!
# 244 I do not ask you to come with me, Sam.
# 245 I know, Mr Frodo. I doubt even these Elvish cloaks will hide us in there.
# 246 Now!
# 247 No! No, no master! They catch you! They catch you! Don't take it to him! He wants the preciousss. Always he's looking for it! And the preciousss is wanting to go back to him. But we mustn't let him have it.
# 248 No!  There's another way. More secret. A dark way.
# 249 Why haven't you spoken of this before?!
# 250 Because Master did not ask!
# 251 He's up to something.
# 252 Are you saying there's another way into Mordor?
# 253 Yes. There is a path, and some stairs, and then...a tunnel.
# 254 He's led us this far, Sam.
# 255 Mr. Frodo, no.
# 256 He's been true to his word.
# 257 No!
# 258 Lead the way, Smeagol.
# 259 Good Smeagol always helps.
# 260 Edoras and the Golden Hall of Meduseld. There dwells Theoden, King of Rohan, whose mind is overthrown. Saruman's hold over King Theoden is now very strong.
# 261 Will you not go to him?  Will you do nothing?
# 262 Be careful what you say. Do not look for welcome here.
# 263 Oh, he ... he must have died sometime in the night. What a tragedy for the king to lose his only son and heir.
# 264 I understand his passing is hard to accept, especially now that your brother has deserted you.
# 265 Leave me alone, snake!
# 266 Oh, but you are alone! Who knows what you have spoken to the darkness. In bitter watches of the night, when all your life seems to shrink, the walls of your bower closing in about you, like a hutch to trammel some wild thing in.
# 267 So fair, so cold, like a morning of pale spring still clinging to winter's chill.
# 268 Your words are poison!
# 269 You'll find more cheer in a graveyard.
# 270 Ah.
# 271 I cannot allow you before Theoden-King so armed, Gandalf Greyhame. By order of Grima Wormtongue.
# 272 Your staff.
# 273 Hmm?  Oh. You would not part an old man from his walking stick?
# 274 My lord, Gandalf the Grey is coming. He's a herald of woe.
# 275 The courtesy of your hall is somewhat lessened of late, Theoden King.
# 276 He's not welcome.
# 277 Why should I welcome you, Gandalf Stormcrow?
# 278 A just question, my liege.  Late is the hour in which this conjurer chooses to appear. Lathspell spell I name him. Ill news is an ill guest.
# 279 Be silent! Keep your forked tongue behind you teeth. I have not passed through fire and death to bandy crooked words with a witless worm!
# 280 His staff!  I told you to take the wizard's staff!
# 281 Theoden, son of Thengel, too long have you sat in the shadows.
# 282 I would stay still, if I were you.
# 283 Hearken to me! I release you from the spell.
# 284 Hahahhhahahahah!  You have no power here, Gandalf the Grey!
# 285 Argh!
# 286 I will draw you, Saruman, as poison is drawn from a wound.
# 287 Wait.
# 288 If I go. . . Theoden dies.
# 289 You did not kill me, you will not kill him!
# 290 Rohan is mine!
# 291 Be gone!!
# 292 I know your face. Eowyn Eowyn.
# 293 Gandalf?
# 294 Breathe the free air again, my friend.
# 295 Dark have been my dreams of late.
# 296 Your fingers would remember their old strength better... if they grasped your sword.
# 297 Argh!  I've only ever served you, my lord!
# 298 Your leechcraft would have had me crawling on all fours like a beast!
# 299 Send me not from your side.
# 300 No, my lord! No, my lord. Let him go. Enough blood has been spilled on his account.
# 301 Get out of my way!
# 302 Hail, Theoden king!
# 303 Where is Theodred? Where is my son?
# 304 Simbelmyn'. Ever has it grown on the tombs of my forebearers.  Now it shall cover the grave of my son. Alas, that these evil days should be mine. The young perish and the old linger. That I should live to see the last days of my house.
# 305 Theodred's death was not of your making.
# 306 No parent should have to bury their child.
# 307 Be-thou well. Go-thou, Theodred, go-thou.
# 308 They had no warning. They were unarmed. Now the wildmen are moving through the Westfold, burning as they go. Rick, cot and tree.
# 309 Where's mama?
# 310 Shh...
# 311 This is but a taste of the terror that Saruman will unleash. All the more potent for he is driven now by fear of Sauron. Ride out and meet him head on. Draw him away from your women and children.  You must fight.
# 312 You have two thousand good men riding north as we speak. Eomer is loyal to you. His men will return and fight for their king.
# 313 They will be three hundred leagues from here by now. Eomer cannot help us. I know what it is that you want of me. But I will not bring further death to my people. I will not risk open war.
# 314 Open war is upon you. Whether you would risk it or not.
# 315 When last I looked, Theoden, not Aragorn, was king of Rohan.
# 316 Then what is the king's decision?
# 317 By order of the king, the city must empty. We make for the refuge of Helm's Deep. Do not burden yourselves with treasures. Take only what provisions you need.
# 318 Helm's Deep! They flee to the mountains when they should stand and fight. Who will defend them if not their king.
# 319 He's only doing what he thinks is best for his people. Helm's Deep has saved them in the past.
# 320 There is no way out of that ravine. Theoden is walking into a trap. He thinks he's leading them to safety. What they will get is a massacre. Theoden has a strong will but I fear for him. I fear for the survival of Rohan. He will need you before the end, Aragorn. The people of Rohan will need you. The defences HAVE to hold.
# 321 They will hold.
# 322 The Grey Pilgrim... that's what they used to call me. Three hundred lives of men I've walked this earth and now I have no time. With luck, my search will not be in vain. Look to my coming at first light on the fifth day. At dawn, look to the East.
# 323 Go.
# 324 You have some skill with a blade.
# 325 Women of this country learned long ago: Those without swords may still die upon them. I fear neither death nor pain.
# 326 What do you fear, my lady?
# 327 A cage. To stay behind bars until use and old age accept them and all chance of valor has gone beyond recall or desire.
# 328 You are a daughter of kings, a shieldmaiden of Rohan.  I do not think that would be your fate.
# 329 Theoden will not stay at Edoras. It's vulnerable, he knows this. He will expect an attack on the city. They will flee to Helm's Deep, the great fortress of Rohan. It is a dangerous road to take through the mountains. They will be slow. They will have women and children with them.
# 330 Send out your warg riders.
# 331 Hey Stinker! Don't go getting too far ahead!
# 332 Why do you do that?
# 333 What?
# 334 Call him names; run him down all the time.
# 335 Because ... because that's what he is, Mr. Frodo. There's naught left in 'im but lies and deceit. It's the Ring he wants. It's all he cares about.
# 336 You have no idea what it did to him. What it's still doing to him.  I want to help him, Sam...
# 337 Why?
# 338 Because I have to believe he can come back.
# 339 You can'tt save him, Mr. Frodo.
# 340 What do you know about it? Nothing!
# 341 I'm sorry, Sam. I don't know why I said that.
# 342 I do. It's the Ring. You can't take your eyes off it. I've seen you. You're not eating. You barely sleep. It's taken a hold of you, Mr Frodo. You have to fight it!
# 343 I know what I have to do Sam. The Ring was entrusted to me! It's my task! Mine! My own!
# 344 Can't you hear yourself? Don't you know who you sound like?
# 345 We wants it. We needs it. Must have the precioussss. They stole it from us. Sneaky little hobbitsesss. Wicked, trickssssy, falssse!
# 346 No! Not Master.
# 347 Yes, precious. False. They will cheat you, hurt you, lie.
# 348 Master's my friend.
# 349 You don't have any friends. Nobody likes YOU...
# 350 Not listening. I'm not listening.
# 351 You're a liar and a thief.
# 352 Nope.
# 353 Murderer!
# 354 Go away.
# 355 Go away!  HAHAHAHA!!
# 356 I hate you. I hate you!
# 357 Where would you be without me? *Gollum, gollum*. I saved us. It was me. We survived because of me!
# 358 Not anymore.
# 359 What did you say?
# 360 Master looks after us now. We don't need you.
# 361 What?
# 362 Leave now and never come back.
# 363 No!!
# 364 Leave now and never come back!
# 365 Arrrgh!!!
# 366 LEAVE. NOW. AND. NEVER. COME. BACK!
# 367 We... we told him to go away! And away he goes, preciousss.  Gone, gone, gone! Smeagol is free!
# 368 Look! Look! See what Smeagol finds! Hehehe! Hahaha!
# 369 They are young. They are tender. They are nice. Yes they are! Eat them! Eat them!
# 370 You'll make him sick, you will, behaving like that!  There's only one way to eat a brace of coneys.
# 371 Argh!! What's it doing! Stupid fat hobbit! It ruins it!
# 372 What's to ruin? There's hardly any meat on them.
# 373 What we need is a few good taters.
# 374 What's taters, preciousss? What's taters uh?
# 375 PO-TAY-TOES! Boil them. Mash them. Stick them in a stew. Lovely big golden chips with a nice piece of fried fish....
# 376 Pbbbttt!!
# 377 Even you couldn't say no to that.
# 378 Oh yes we could! Spoil nice fish...  Give it to usss rrraw... and wrrriggling!  You keep nasty chips.
# 379 You're hopeless.
# 380 Mr. Frodo?
# 381 Who are they?
# 382 Wicked men. Servants of Sauron. They are called to Mordor. The Dark One is gathering all armies to him. It won't be long now. He will soon be ready.
# 383 Ready to do what?
# 384 To make his war. The last war that will cover all the world in shadow.
# 385 We've got to get moving. Come on, Sam.
# 386 Mr Frodo! Look! It's an Oliphaunt!
# 387 No one at home will believe this...
# 388 Smeagol?
# 389 We've lingered here too long. Come on, Sam!
# 390 Ah!
# 391 Bind their hands.
# 392 It's true you don't see many Dwarf women. And in fact, they are so alike in voice and appearance, haha that they're often mistaken for Dwarf men.
# 393 It's the beards....
# 394 And this, in turn, has given rise to the belief that there are no Dwarf women. And that dwarves just spring out of holes in the ground!
# 395 Hahahaha!!
# 396 Hehehe! Which is of course ridiculous. Whoa!!
# 397 It's alright, it's alright. Nobody panic. That was deliberate. It was deliberate.
# 398 The light of the Evenstar does not wax and wane' It is mine to give to whom I will... Like my heart. Go to sleep...
# 399 I am asleep. This is a dream.
# 400 Then it is a good dream. Sleep.
# 401 You told me once that this day would come.
# 402 This is not the end... it is the beginning. You must go with Frodo. That is your path.
# 403 My path is hidden from me.
# 404 It is already laid before your feet. You cannot falter now.
# 405 Arwen ...
# 406 If you trust nothing else... trust this. Trust us.
# 407 Our time here is ending. Arwen ...s time is ending. Let her go. Let her take the ship into the west. Let her bear away her love for you to the Undying Lands. There it will be evergreen.
# 408 But never more than a memory.
# 409 I will not leave my daughter here to die.
# 410 She stays because she still has hope.
# 411 She stays for YOU! She belongs with her people!
# 412 You have a chance for another life. Away from war... grief... despair.
# 413 Why are you saying this?
# 414 I am mortal; you are Elfkind. It was a dream, Arwen, nothing more.
# 415 This belongs to you.
# 416 It was a gift. Keep it.
# 417 She is sailing to the Undying Lands, with all that is left of her kin.
# 418 What is it? Hama?
# 419 I'm not sure.
# 420 Wargs!
# 421 Argh!  A scout!
# 422 What is it? What do you see?
# 423 Wargs! We are under attack!
# 424 Get them out of here!
# 425 All riders to the head of the column!
# 426 Come on, get me up here, I'm a rider! Argh!
# 427 You must lead the people to Helm's Deep. And make haste!
# 428 I can fight!
# 429 No! You must do this... for me.
# 430 Follow me! Yah!
# 431 Forward. I mean, charge forward! March forward!  That's it! Go on!
# 432 Make for the lower ground! Stick together!
# 433 Argh!!
# 434 CHARGE!!
# 435 Bring your pretty face to my axe!
# 436 Argh! That one counts as mine!
# 437 Argh! Stinking creature. Argh!
# 438 Ooh..!
# 439 Oooh!!
# 440 Aragorn!
# 441 Aragorn?
# 442 Tell me what happened and I will ease your passing.
# 443 He's  dead.  Took a little tumble off the cliff.
# 444 You lie!
# 445 Get the wounded on horses. The wolves of Isengard will return. Leave the dead.
# 446 Come.
# 447 Helm's Deep! At last! There it is!
# 448 We're safe, my lady! Thank you!
# 449 Mama!
# 450 Eothain! Freda!
# 451 Make way for Theoden!
# 452 Sire!
# 453 Make way for the king!
# 454 So few. So few of you have returned.
# 455 Our people are safe. We have paid for it with many lives.
# 456 My lady...
# 457 Lord Aragorn, where is he?
# 458 He fell...
# 459 Draw all our forces behind the wall. Bar the gate, and set a watch on the surround.
# 460 What of those who cannot fight, my lord? The women and children?
# 461 Get them into the caves.  Saruman's arm would have grown long indeed if he thinks he can reach us here.
# 462 Helm's Deep has one weakness. Its outer wall is solid rock but for a small culvert at its base which is little more than a drain.
# 463 How? How can fire undo stone? What kind of device could bring down the wall?
# 464 If the wall is breached, Helm's Deep will fall.
# 465 Even if it is breached, it would take a number beyond reckoning, thousands to storm the keep.
# 466 Tens of thousands.
# 467 But, my lord, there is no such force.
# 468 A new power is rising. Its victory is at hand!
# 469 This night, the land will be stained with the blood of Rohan! March to Helms Deep! Leave none alive!
# 470 To war!!
# 471 There will be no dawn for Men.
# 472 Look! There's smoke to the south!
# 473 There is always smoke rising from Isengard these days.
# 474 Isengard?
# 475 There was a time when Saruman would walk in my woods. But now he has a mind of metal and wheels. He no longer cares for growing things.
# 476 What is it?
# 477 It's Saruman's army! The war has started.
# 478 May the grace of the Valar protect you.
# 479 Brego.
# 480 Arwen.
# 481 Arwen, it is time. The ships are leaving for Valinor. Go now... before it is too late.
# 482 I have made my choice.
# 483 He is not coming back. Why do you linger here when there is no hope?
# 484 There is still hope.
# 485 If Aragorn survives this war, you will still be parted. If Sauron is defeated, and Aragorn made king and all that you hope for comes true, you will still have to taste the bitterness of mortality. Whether by the sword or the slow decay of time, Aragorn will die.
# 486 And there will be no comfort for you. No comfort to ease the pain of his passing. He will come to death, an image of the splendor of the kings of men in glory undimmed before the breaking of the world.
# 487 But you, my daughter, you will linger on in darkness and in doubt. As nightfall in winter that comes without a star. Here you will dwell, bound to your grief, under the fading trees, until all the world is changed and the long years of your life are utterly spent.
# 488 Arwen... there is nothing for you here, only death.
# 489 Do I not also have your love?
# 490 You have my love, father
# 491 The world has changed... I feel it in the water, I feel it in the earth, I smell it in the air.
# 492 In the gathering dark, the will of the Ring grows strong. It works hard now to find its way back into the hands of men.
# 493 Men, who are so easily seduced by its power. The young captain of Gondor has but to extend his hands, take the Ring for his own and the world will fall. It is close now, so close to achieving its goal.
# 494 For Sauron will have dominion of all life on this Earth, even unto the ending of the world. The time of the Elves is over.
# 495 Do we leave Middle-earth to its fate? Do we let them stand alone?
# 496 What news?
# 497 Our scouts report Saruman has attacked Rohan. Theoden's people have fled to Helm's Deep.  But we must look to our own borders. Faramir, Orcs are on the move. Sauron is marshalling an army. Easterlings and Southrons are passing through the Black Gate.
# 498 How many?
# 499 Some thousands. More come every day.
# 500 Who's covering the river to the north?
# 501 We pulled 500 men at Osgiliath, but if the city is attacked, we won't hold it.
# 502 Saruman attacks from Isengard. Sauron from Mordor. The fight will come to men on both fronts. Gondor is weak. Sauron will strike us soon. And he will strike hard. He knows now we do not have the strength to repel him.
# 503 My men tell me that you are Orc spies.
# 504 Spies?! Now wait just a minute!
# 505 Well if you're not spies, then who are you?
# 506 Speak.
# 507 We are hobbits of the Shire. Frodo Baggins is my name and this is Samwise Gamgee.
# 508 Your bodyguard?
# 509 His gardener.
# 510 And where is your skulking friend? That gangrel creature. He had an ill-favoured look.
# 511 There was no other.
# 512 We set out from Rivendell with seven companions. One we lost in Moria. Two were my kin. A Dwarf there was also, and an Elf. And two men, Aragorn, son of Arathorn, and Boromir of Gondor.
# 513 You're a friend of Boromir?
# 514 Yes... for my part.
# 515 It will grieve you then to learn that he is dead.
# 516 Dead? How? When?
# 517 As one of his companions, I'd hoped you would tell me.  He was my brother.
# 518 Captain Faramir.  We found the third one.
# 519 You must come with me. Now.
# 520 Down there.
# 521 To enter the forbidden pool bears the penalty of death.  They wait for my command.
# 522 Shall I shoot?
# 523 The rock and pool is nice and cool, so juicy sweet! I only wish  to catch a fish , so juicy sweet!
# 524 Wait!  This creature is bound to me. And I to him. He is our guide. Please, let me go down to him.
# 525 Smeagol.  Master is here. Come, Smeagol. Trust master. Come!
# 526 We must go now?
# 527 Smeagol, you must trust master. Follow me, come on. Come. Come, Smeagol. Nice Smeagol. That's it. Come on.
# 528 Don't hurt him! Smeagol don't struggle! Smeagol listen to me!
# 529 Master!!
# 530 No! No!
# 531 Where are you leading them? Answer me!
# 532 Smeagol... Why does it cry, Smeagol?
# 533 Cruel men hurts us. Master trickst us.
# 534 Of course he did. I told you he was tricksy. I told you he was false.
# 535 Master is our friend... our friend.
# 536 Master betrayed us.
# 537 No, not its business. Leave us alone!
# 538 Filthy little hobbitses. They stole it from us.
# 539 No... No!
# 540 What did they steal?
# 541 Myyy PRECIOUSSS!!  Aaaarrrggghhh!!!
# 542 We have to get out of here. You go. Go, now! You can do it. Use the Ring, Mr. Frodo. Just this once. Put it on. Disappear.
# 543 I can'tt. You were right, Sam. You tried to tell me, but ... I'm sorry. The Ring's taking me Sam. If I put it on, he'll find me. He'll see.
# 544 Mr. Frodo...
# 545 So... this is the answer to all the riddles. Here in the wild I have you. Two halflings and a host of men at my call. The Ring of power within my grasp.
# 546 A chance for Faramir, captain of Gondor, to show his quality.
# 547 No!!
# 548 Stop it! Leave him alone! Don't you understand? He's got to destroy it. That's where we're going. Into Mordor. To the mountain of fire.
# 549 Osgiliath is under attack. They call for reinforcements.
# 550 Please. It's such a burden. Will you not help him?
# 551 Captain?
# 552 Prepare to leave. The Ring will go to Gondor.
# 553 Well done, Brego, my friend
# 554 He's alive!
# 555 Where is he? Where is he? Get out of the way. I'm gonna kill him!  You are the luckiest, the canniest and the most reckless man I ever knew!  Bless you, laddie!
# 556 Gimli, where is the king?
# 557 You're late.
# 558 Thank you.
# 559 A great host, you say?
# 560 All Isengard is emptied
# 561 How many?
# 562 Ten thousand strong at least.
# 563 Ten thousand?!
# 564 It is an army bred for a single purpose: to destroy the world of men. They will be here by nightfall.
# 565 Let them come!
# 566 I want every man and strong lad able to bear arms to be ready for battle by nightfall.
# 567 We will cover the causeway and the gate from above. No army has ever breached the Deeping Wall or set foot inside the Hornburg.
# 568 This is no rabble of mindless Orcs. These are Uruk-hai. Their armor is thick and their shields broad.
# 569 I have fought many wars, Master Dwarf. I know how to defend my own keep.
# 570 They will break upon this fortress like water on rock. Saruman's hordes will pillage and burn, we've seen it before. Crops can be resown; homes rebuilt. Within these walls, we will outlast them.
# 571 They do not come to destroy Rohan's crops or villages. They come to destroy its people. Down to the last child.
# 572 What would you have me do? Look at my men. Their courage hangs by a thread. If this is to be our end, then I would have them make such an end as to be worthy of remembrance.
# 573 Send out riders, my lord. You must call for aid.
# 574 And who will come? Elves? Dwarves? We are not so lucky in our friends as you. The old alliances are dead.
# 575 Gondor will answer.
# 576 Gondor? Where was Gondor when the Westfold fell? Where was Gondor when our enemies closed in around us? Where was Gon' ' No, my lord Aragorn, we are alone.  Get the women and children into the caves.
# 577 We need more time to lay provisions for a siege, lord.
# 578 There is no time. War is upon us!
# 579 Secure the gate!
# 580 We Ents have not troubled about the wars of men and wizards for a very long time. But now something is about to happen that has not happened for an age... Ent Moot.
# 581 What's that?
# 582 'Tis a gathering.
# 583 A gathering of what?
# 584 Beech, oak, chestnut, ash... Good, good, good. Many have come. Now we must decide if the Ents will go to war.
# 585 Move back! Move to the caves!
# 586 Keep moving!
# 587 Quickly now!
# 588 Farmer, farriers, stable boys. These are no soldiers.
# 589 Most have seen too many winters.
# 590 And they should be... Three hundred against ten thousand!
# 591 They have more hope of defending themselves here than at Edoras.
# 592 Aragorn, we are warriors. They cannot win this fight. They are all going to die!
# 593 Then I shall die as one them!
# 594 Let him go, lad. Let him be.
# 595 Every villager able to wield a sword has been sent to the armory. My lord?
# 596 Who am I, Gamling?
# 597 You are our king, sire.
# 598 And do you trust your king?
# 599 Your men, my lord, will follow you to whatever end.
# 600 To whatever end. Where is the horse and the rider? Where is the horn that was blowing? They have passed like rain on the mountains. Like wind in the meadow. The days have gone down in the west. Behind the hills, into shadow. How did it come to this?
# 601 Give me your sword. What is your name?
# 602 Haleth, son of Hama, my lord. The men are saying that we will not live out the night. They say that it is hopeless..
# 603 This is a good sword, Haleth, son of Hama.
# 604 There is always hope.
# 605 We have trusted you this far. You have not led us astray. Forgive me. I was wrong to despair.
# 606 There is nothing to forgive, Legolas.
# 607 If we had more time I'd get this adjusted.  It's a little tight across the chest.
# 608 That is no Orc horn.
# 609 Send for the king. Open the gate!
# 610 Open the gate!
# 611 How is this possible?
# 612 I bring word from Elrond of Rivendell. An alliance once existed between Elves and men. Long ago we fought and died together.  We come to honor that allegiance.
# 613 Welcome, Haldir
# 614 You are most welcome!
# 615 We are proud to fight alongside men, once more.
# 616 You could have picked a better spot.
# 617 Well lad, whatever luck you live by, let's hope it lasts the night.
# 618 Your friends are with you, Aragorn.
# 619 Let's hope they last the night.
# 620 Show them no mercy! For you shall receive none!
# 621 What's happening out there?
# 622 Shall I describe it to you?  Or would you like me to find you a box?
# 623 Hehehehe!!
# 624 Hold!
# 625 So it begins.
# 626 Prepare to fire!
# 627 Their armor is weak at the neck and beneath the arms.
# 628 Release the arrows!
# 629 Did they hit anything?
# 630 Give them a volley.
# 631 Fire!
# 632 Fire!
# 633 Fire!
# 634 Send them to me! C'mon!
# 635 Ladders!
# 636 Swords! Swords!
# 637 Good!
# 638 Legolas, two already!
# 639 I'm on seventeen!
# 640 Argh! I'll have no pointy-ear outscoring me!
# 641 Nineteen!
# 642 Merry!
# 643 We have just agreed.
# 644 Yes?
# 645 I have told your names to the Ent moot and we have agreed ... you are not Orcs.
# 646 Well, that's good news.
# 647 And what about Saruman? Have you come to a decision about HIM?
# 648 Now don't be hasty, Master Meriadoc.
# 649 Hasty? Our friends are out there! They need our help! They cannot fight this war on their own.
# 650 War, yes. It affects us all. But you must understand, young hobbit. It takes a loong time to say anything in ooold Entish.  And we never say anything unless it is worth taking a looong time to say.
# 651 Seventeen! Eighteen! Nineteen! Twenty! Twenty-one! Twenty-two!
# 652 Causeway!
# 653 Is this it? Is this all you can conjure, Saruman?
# 654 Bring him down, Legolas!Kill him! Kill him!
# 655 Brace the Gate! Hold them! Stand firm!
# 656 Aragorn!! Argh!
# 657 Hurl the arrows!
# 658 Charge!
# 659 The Ents cannot hold back this storm. We must weather such things as we have always done.
# 660 How can that be your decision?!
# 661 This is not our war.
# 662 But you're part of this world! Aren't you?!  You must help, please! You must do something!
# 663 You are young and brave, Master Merry. But your part in this tale is over. Go back to your home.
# 664 Maybe Treebeard's right. We don't belong here, Merry. It's too big for us. What can we do in the end? We've got the Shire. Maybe we should go home.
# 665 The fires of Isengard will spread. And the woods of Tuckborough and Buckland will burn. And all that was once green and good in this world will be gone.  There won't be a Shire, Pippin.
# 666 Aragorn! Fall back to the Keep! Get your men out of there!
# 667 To the Keep! Pull back to the Keep! Haldir, to the Keep!
# 668 What are you doing? Argh! What are you stopping for!
# 669 HALDIR!!
# 670 Brace the gate!
# 671 Hold them!
# 672 To the gate! Draw your swords!
# 673 Make way! We cannot hold much longer.
# 674 Hold them!
# 675 How long do you need?
# 676 Brace the gate!
# 677 As long as you can give me!
# 678 Gimli!
# 679 Timbers! Brace the Gate!
# 680 Come on! We can take them!
# 681 It's a long way.
# 682 Toss me.
# 683 What?
# 684 I cannot jump the distance! You'll have to toss me!
# 685 Oh!  Don't tell the Elf.
# 686 Not a word.
# 687 ARGH!!
# 688 Shore up the door!
# 689 Make way!
# 690 Follow me to the barricade.
# 691 Watch our backs!
# 692 Throw another one over here!
# 693 Higher!
# 694 Hold fast the gate!]
# 695 Gimli! Aragorn! Get out of there!
# 696 Aragorn!
# 697 Pull everybody back! Pull them back!
# 698 Fall back! Fall back!
# 699 They've broken through! The castle is breached. Retreat!
# 700 Fall back!
# 701 Retreat!
# 702 Hurry! Inside! Get them inside!
# 703 Into the Keep!
# 704 I will leave you at the western borders of the forest. You can make your way north to your homeland from there.
# 705 Wait! Stop! Stop!  Turn around. Turn around. Take us south!
# 706 South? But that will lead you past Isengard.
# 707 Yes. Exactly. If we go south we can slip past Saruman unnoticed. The closer we are to danger, the farther we are from harm. It's the last thing he'll expect.
# 708 Mmmm. That doesn't make sense to me. But then, you are very small. Perhaps you're right. South it is then. Hold on, little Shirelings. I always like going south. Somehow it feels like going down hill.
# 709 Are you mad? We'll be caught!
# 710 No we won't. Not this time.
# 711 Look! Osgiliath burns!
# 712 Mordor has come.
# 713 The Ring will not save Gondor. It has only the power to destroy. Please, let me go.
# 714 Hurry.
# 715 Faramir, you must let me go!
# 716 And a little family of field mice that climb up sometimes and they tickle me awfully. They're always trying to get somewhere where they ... Oh!!  Many of these trees were my friends. Creatures I had known from nut and acorn.
# 717 I'm sorry, Treebeard.
# 718 They had voices of their own.  Saruman! A wizard should know better!
# 719 There is no curse in Elvish, Entish or the tongues of men for this treachery. My business is with Isengard tonight. With rock and stone!
# 720 Yes!
# 721 Hoorarooom... Come my friends. The Ents are going to war. It is likely that we go to our doom. Last march of the Ents!
# 722 Faramir, Orcs have taken the eastern shore. Their numbers are too great. By nightfall we'll be overrun.
# 723 Mr Frodo!
# 724 It's calling to him, Sam. His eye is almost on me.
# 725 Hold on, Mr. Frodo. You'll be alright...
# 726 Take them to my father. Tell him Faramir sends a mighty gift. A weapon that will change our fortunes in this war.
# 727 Do you want to know what happened to Boromir? You want to know why your brother died? He tried to take the Ring from Frodo! After swearing an oath to protect him, he tried to kill him! The Ring drove your brother mad!
# 728 Watch out!
# 729 Mr Frodo?
# 730 They're here. They've come.
# 731 NAZG'L!!  Stay here. Keep out of sight.  Take cover!
# 732 The fortress is taken. It is over.
# 733 You said this fortress would never fall while your men defend it! They still defend it! They have died defending it!
# 734 They are breaking in!
# 735 Is there no other way for the women and children to get out of the caves?  Is there no other way?
# 736 There is one passage. It leads into the mountains. But they will not get far. The Uruk-hai are too many.
# 737 Send word for the women and children to make for the mountain pass. And barricade the entrance.
# 738 So much death. What can men do against such reckless hate?
# 739 Ride out with me. Ride out and meet them.
# 740 For death and glory.
# 741 For Rohan. For your people.
# 742 The sun is rising.
# 743 Look to my coming at first light on the fifth day. At dawn, look to the east.
# 744 Yes. Yes! The horn of Helm Hammerhand shall sound in the deep one last time!
# 745 Yes!
# 746 Let this be the hour when we draw swords together. Fell deeds awake. Now for wrath! Now for ruin! And a red dawn!
# 747 FORTH EORLINGAS!!
# 748 Gandalf.
# 749 Theoden king stands alone.
# 750 Not alone.  Rohirrim!!
# 751 Eomer!
# 752 To the king!
# 753 Yes!
# 754 A hit. A fine hit!
# 755 Break the dam! Release the river!
# 756 Pippin, hold on!
# 757 Hold on, little hobbits!
# 758 What are you doing? Where are you going?!
# 759 Aaarrgghh!!!
# 760 It's me. It's your Sam. Don't you know your Sam?
# 761 I can'tt do this, Sam.
# 762 I know. It's all wrong. By rights we shouldn't even be here. But we are.  It's like in the great stories, Mr. Frodo. The ones that really mattered. Full of darkness and danger they were. And sometimes you didn't want to know the end. Because how could the end be happy?  How could the world go back to the way it was when so much bad had happened?
# 763 Victory! We have victory!
# 764 But in the end, it's only a passing thing, this shadow.  Even darkness must pass. A new day will come.  And when the sun shines it will shine out the clearer. Those were the stories that stayed with you. That meant something, even if you were too small to understand why. But I think, Mr. Frodo, I do understand. I know now. Folk in those stories had lots of chances of turning back only they didn't. They kept going because they were holding on to something.
# 765 What are we holding on to, Sam?
# 766 There's some good in this world, Mr. Frodo. And it's worth fighting for.
# 767 I think at last we understand one another, Frodo Baggins.
# 768 You know the laws of our country, the laws of your father. If you let them go, your life will be forfeit.
# 769 Then it is forfeit. Release them.
# 770 Sauron's wrath will be terrible, his retribution swift. The battle for Helm's Deep is over. The battle for Middle-earth is about to begin. All our hopes now lie with two little hobbits. Somewhere in the wilderness.
# 771 I wonder if we'll ever be put into songs or tales.
# 772 What?
# 773 I wonder if people will ever say, 'let's hear about Frodo and the Ring.' And they'll say 'yes, that's one of my favorite stories. Frodo was really courageous, wasn't he, dad.' 'Yes, my boy, the most famousest of hobbits. And that's saying alot.'
# 774 Huh, you left out one of the chief characters : Samwise the Brave. I want to hear more about Sam.
# 775 Frodo wouldn't have got far without Sam.
# 776 Now Mr. Frodo, you shouldn't make fun. I was being serious.
# 777 So was I.
# 778 Samwise the Brave.
# 779 Smeagol!
# 780 We're not gonna wait for you. Come on!
# 781 Master... Master looks after us. Master wouldn't hurt us.
# 782 Master broke his promise.
# 783 Don't ask Smeagol. Poor, poor Smeagol.
# 784 Master betrayed us! Wicked, tricksy, false. We ought to wring his filthy little neck.  Kill him! Kill him! Kill them both. And then we take the precious and we be the master.
# 785 The fat hobbit, he knows. Eyes always watching.
# 786 Then we stabs them out. Put out his eyeses. And make HIM crawl.
# 787 Yes! Yes! Yes!
# 788 Kill them both.
# 789 Yes! No no!  It's too risky, it's too risky.
# 790 Where's he gone? Hey Gollum, where are you?
# 791 Smeagol?
# 792 We could let HER do it.
# 793 Yes. She could do it.
# 794 Yes, precious she could. And then we takes it once they're dead.
# 795 Once they're dead.
# 796 Shh.
# 797 Come on, hobbits. Long ways to go yet. Smeagol will show you the way.
# 798 Follow me.
